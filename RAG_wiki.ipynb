# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/UpstageAI/cookbook/blob/main/cookbooks/upstage/Solar-Full-Stack LLM-101/05_3_OracleDB.ipynb">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # RAG + Wikipedia (for MMLU)

# %%
# set parameters

file = open("info/api.txt", "r")
api_key = file.read()
file.close()
file = open("info/path.txt", "r")
data_path = file.read()
file.close()
file = open("info/user.txt", "r")
user = file.read()
file.close()

import torch
device = "cuda:0" if torch.cuda.is_available() else "cpu"
print('Device:', device)
# Out:
# Device: cuda:0

# %%
import wikipediaapi

# user는 내 아이디 같은 거
wiki_wiki = wikipediaapi.Wikipedia(f'{user}', 'en')

# %%
from langchain_upstage import UpstageEmbeddings

# 쿼리 전용 임베딩 모델
query_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-query")
# 문장 전용 임베딩 모델
passage_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-passage")

# %% [markdown]
# ## 1. build DB (using Wikipida)

# %% [markdown]
# ### what is the main topic & specific topic of query

# %%
# read mmlu_pro.csv file
import pandas as pd
import os

def read_data(data_path):
    data = pd.read_csv(data_path)
    prompts = data['prompts']
    answers = data['answers']
    # returns two lists: prompts and answers
    return prompts, answers

prompts, answers = read_data(os.path.join(data_path, 'mmlu_pro.csv'))

# %%
testdata = pd.read_csv(data_path+'mmlu_pro.csv')
testdata
# Out:
#                                                  prompts answers
# 0      QUESTION0) The symmetric group $S_n$ has $\n\f...     (A)
# 1      QUESTION1) Let V be the set of all real polyno...     (H)
# 2      QUESTION2) Let A be the set of all ordered pai...     (E)
# 3      QUESTION3) A tank initially contains a salt so...     (I)
# 4      QUESTION4) A total of 30 players will play bas...     (B)
# ...                                                  ...     ...
# 12097  QUESTION12252) A hot mild steel rod is placed ...     (J)
# 12098  QUESTION12253) The cost of making the correct ...     (H)
# 12099  QUESTION12254) Consider the evaporation of liq...     (F)
# 12100  QUESTION12255) Air (100°F, 1atm) is flowing at...     (I)
# 12101  QUESTION12256) The frequency range of a commer...     (F)
#
# [12102 rows x 2 columns]

# %%
nowtest = pd.DataFrame(columns=['index', 'embed_ques', 'question', 'prompts', 'answers', 'topic_b', 'topic_s', 'b_wiki', 's_wiki'])

for index, row in testdata.iterrows():
    if index % 500 != 0 : continue # 일단 실험할 땐 500개 단위로 끊어서 가져옴
    q = row.prompts
    a = row.answers
    question = q.partition('(A)')[0]
    question = question.partition(') ')[2]
    q = q.partition(') ')[2]
    try : 
        embedded_query = query_embeddings.embed_query(question) # 질문만 받아와서 embedding 하기
        nowtest.loc[len(nowtest)] = {'index':index, 'embed_ques' : embedded_query, 'question' : question, 'prompts' : q, 'answers' : a, 'topic_b': None, 'topic_s': None, 'b_wiki': None, 's_wiki':None}

    except :
        print(f'pass: {index}')
        continue

# %%
nowtest
# Out:
#     index                                         embed_ques  \
# 0       0  [-0.013031005859375, -0.00452423095703125, -0....
# 1     500  [-0.006580352783203125, 0.0008025169372558594,...
# 2    1000  [-0.018035888671875, -0.00658416748046875, -0....
# 3    1500  [-0.01137542724609375, -0.002910614013671875, ...
# 4    2000  [-0.00925445556640625, -0.036468505859375, -0....
# 5    2500  [-0.0265960693359375, -0.005367279052734375, 0...
# 6    3000  [-0.0291748046875, 0.0171051025390625, 0.00342...
# 7    3500  [-0.01071929931640625, -0.02410888671875, -0.0...
# 8    4000  [-0.03466796875, -0.01006317138671875, -0.0077...
# 9    4500  [0.00843048095703125, -0.0082244873046875, -0....
# 10   5000  [0.0022335052490234375, -0.020660400390625, -0...
# 11   5500  [-0.00537109375, -0.01837158203125, -0.0255126...
# 12   6000  [-0.00293731689453125, -0.001552581787109375, ...
# 13   6500  [0.016082763671875, -0.0182647705078125, 0.003...
# 14   7000  [0.00039958953857421875, 0.009185791015625, -0...
# 15   7500  [-0.024871826171875, 0.00011593103408813477, -...
# 16   8000  [-0.00498199462890625, -0.024871826171875, -0....
# 17   8500  [0.0213775634765625, -0.00409698486328125, -0....
# 18   9000  [0.001068115234375, -0.0204620361328125, 0.003...
# 19   9500  [-0.0034198760986328125, -0.01226806640625, -0...
# 20  10000  [-0.034576416015625, -0.0258331298828125, -0.0...
# 21  10500  [-0.0008339881896972656, -0.00543212890625, -0...
# 22  11000  [-0.0202484130859375, -0.0183868408203125, -0....
# 23  11500  [0.0041351318359375, 0.00785064697265625, 0.00...
# 24  12000  [0.003444671630859375, -0.0190887451171875, -0...
#
#                                              question  \
# 0   The symmetric group $S_n$ has $\n\factorial{n}...
# 1   ________________reflect a purchaser's high lev...
# 2   A developer is the owner of a parcel of land i...
# 3   A defendant, a nurse at a nursing home, is cha...
# 4   In time-out, a disruptive child who wants to s...
# 5   Research has shown a possible connection betwe...
# 6   The nucleotide sequence of a DNA molecule is 5...
# 7   The $J=2$ to 3 rotational transition in a cert...
# 8   For a certain liquid which obeysTrouton'srule,...
# 9   A gas in two dimensions is enclosed in a recta...
# 10  In what ways does gender shape the conceptuali...
# 11  Ralph purchases garden fertilizer at the nearb...
# 12  The houses of the future may allow you to oper...
# 13  One of the most common reasons for stoma forma...
# 14  The population of country X is exactly the sam...
# 15  What are the three major controls which the Fe...
# 16  An experiment is to be conducted to determine ...
# 17  Determine the number of positive real zero of ...
# 18  When food is exposed to gamma radiation, the f...
# 19  In the reaction _5B^11 + _2He^4 \ding{217} _7N...
# 20  The dew point (the temperature at which the wa...
# 21  Based on the paper “SoK: SSL and HTTPS: Revisi...
# 22  Hume claims that a person who is unaffected by...
# 23  The received signal at the end of a communicat...
# 24  Medium 1 has k_1 = 1.5 and extends to the left...
#
#                                               prompts answers topic_b topic_s  \
# 0   The symmetric group $S_n$ has $\n\factorial{n}...     (A)    None    None
# 1   ________________reflect a purchaser's high lev...     (G)    None    None
# 2   A developer is the owner of a parcel of land i...     (B)    None    None
# 3   A defendant, a nurse at a nursing home, is cha...     (I)    None    None
# 4   In time-out, a disruptive child who wants to s...     (G)    None    None
# 5   Research has shown a possible connection betwe...     (E)    None    None
# 6   The nucleotide sequence of a DNA molecule is 5...     (F)    None    None
# 7   The $J=2$ to 3 rotational transition in a cert...     (B)    None    None
# 8   For a certain liquid which obeysTrouton'srule,...     (D)    None    None
# 9   A gas in two dimensions is enclosed in a recta...     (D)    None    None
# 10  In what ways does gender shape the conceptuali...     (F)    None    None
# 11  Ralph purchases garden fertilizer at the nearb...     (D)    None    None
# 12  The houses of the future may allow you to oper...     (F)    None    None
# 13  One of the most common reasons for stoma forma...     (A)    None    None
# 14  The population of country X is exactly the sam...     (D)    None    None
# 15  What are the three major controls which the Fe...     (G)    None    None
# 16  An experiment is to be conducted to determine ...     (H)    None    None
# 17  Determine the number of positive real zero of ...     (I)    None    None
# 18  When food is exposed to gamma radiation, the f...     (G)    None    None
# 19  In the reaction _5B^11 + _2He^4 \ding{217} _7N...     (E)    None    None
# 20  The dew point (the temperature at which the wa...     (D)    None    None
# 21  Based on the paper “SoK: SSL and HTTPS: Revisi...     (A)    None    None
# 22  Hume claims that a person who is unaffected by...     (C)    None    None
# 23  The received signal at the end of a communicat...     (F)    None    None
# 24  Medium 1 has k_1 = 1.5 and extends to the left...     (I)    None    None
#
#    b_wiki s_wiki
# 0    None   None
# 1    None   None
# 2    None   None
# 3    None   None
# 4    None   None
# 5    None   None
# 6    None   None
# 7    None   None
# 8    None   None
# 9    None   None
# 10   None   None
# 11   None   None
# 12   None   None
# 13   None   None
# 14   None   None
# 15   None   None
# 16   None   None
# 17   None   None
# 18   None   None
# 19   None   None
# 20   None   None
# 21   None   None
# 22   None   None
# 23   None   None
# 24   None   None

# %%
nowtest.question[1]
# Out:
# "________________reflect a purchaser's high level of involvement in the purchase decision. There is high perceived risk in these decisions so consumers spend a great deal of time, care, and energy searching, formulating, and making the final decision.\n"

# %% [markdown]
# ### 질문 주고, topic 뽑아내기 (using Solar)
# zero-shot으로 노선 변경

# %%
from langchain_core.prompts import PromptTemplate
from langchain_upstage import ChatUpstage


llm = ChatUpstage(api_key = api_key)

prompt_template = PromptTemplate.from_template(
    '''
    
    Answer according to the conditions : 
    1. Return a broad topic for the given [Sentence].
    2. Respond with ONLY ONE English Word that correspond to [Answer].
    3. DO NOT response ANY OTHER CHARACTERS.

    [Sentence] {question}
    The broad topic is

    '''

)
chain_broad = prompt_template | llm


broad_topics = []
for idx, row in nowtest.iterrows() : ############### 일단 지금은 100개 단위로 띄엄띄엄 test 중
    response = chain_broad.invoke({"question": row.question}) # 선지 전까지 받아오기
    broad_topics.append(response.content)
    nowtest.loc[idx, 'topic_b'] = response.content

broad_topics
# Out:
# ['Algebra',
#  'Decision Making',
#  'Real Estate Law',
#  'Evidence',
#  'Discipline',
#  'Mental Disorders',
#  'Biology',
#  'Spectroscopy',
#  'Chemistry',
#  'Physics',
#  'Gender',
#  'Decision-making',
#  'Future\n\nThe houses of the future may allow you to operate virtually everything in the house from a central terminal; such a house is already in production and is referred to as',
#  'Disease.',
#  'Economics',
#  'Economics',
#  'Health',
#  'Calculus',
#  'Food',
#  'Nuclear Physics',
#  'Atmosphere',
#  'Cryptography',
#  'Empathy',
#  'Communication',
#  'Physics']

# %%
from langchain_core.prompts import PromptTemplate
from langchain_upstage import ChatUpstage


llm = ChatUpstage(api_key = api_key)

prompt_template = PromptTemplate.from_template(
    '''
    
    Answer according to the conditions :
    1. Return a specific topic for the given [Sentence].
    2. Respond with ONLY ONE English Word that correspond to [Answer].
    3. DO NOT response ANY OTHER CHARACTERS.

    [Sentence] {question}
    The specific topic is

    '''

)
chain_speci = prompt_template | llm


specific_topics = []

for idx, row in nowtest.iterrows() : ############### 일단 지금은 100개 단위로 띄엄띄엄 test 중
    response = chain_broad.invoke({"question": row.question}) # 선지 전까지 받아오기
    specific_topics.append(response.content)
    nowtest.loc[idx, 'topic_s'] = response.content

specific_topics
# Out:
# ['Mathematics',
#  'Decision Making',
#  'RealEstate',
#  'Legal',
#  'Discipline',
#  'Mental Disorders',
#  'Biology',
#  'Spectroscopy',
#  'thermodynamics',
#  'Physics',
#  'Gender',
#  'Locational',
#  '\nSmart Home',
#  'Disease',
#  'Economics',
#  'Economy',
#  'health',
#  'Calculus',
#  'radiation',
#  'Nuclear.',
#  'Physics',
#  'Security',
#  'Empathy',
#  'Communication',
#  'Physics']

# %%
nowtest
# Out:
#     index                                         embed_ques  \
# 0       0  [-0.013031005859375, -0.00452423095703125, -0....
# 1     500  [-0.006580352783203125, 0.0008025169372558594,...
# 2    1000  [-0.018035888671875, -0.00658416748046875, -0....
# 3    1500  [-0.01137542724609375, -0.002910614013671875, ...
# 4    2000  [-0.00925445556640625, -0.036468505859375, -0....
# 5    2500  [-0.0265960693359375, -0.005367279052734375, 0...
# 6    3000  [-0.0291748046875, 0.0171051025390625, 0.00342...
# 7    3500  [-0.01071929931640625, -0.02410888671875, -0.0...
# 8    4000  [-0.03466796875, -0.01006317138671875, -0.0077...
# 9    4500  [0.00843048095703125, -0.0082244873046875, -0....
# 10   5000  [0.0022335052490234375, -0.020660400390625, -0...
# 11   5500  [-0.00537109375, -0.01837158203125, -0.0255126...
# 12   6000  [-0.00293731689453125, -0.001552581787109375, ...
# 13   6500  [0.016082763671875, -0.0182647705078125, 0.003...
# 14   7000  [0.00039958953857421875, 0.009185791015625, -0...
# 15   7500  [-0.024871826171875, 0.00011593103408813477, -...
# 16   8000  [-0.00498199462890625, -0.024871826171875, -0....
# 17   8500  [0.0213775634765625, -0.00409698486328125, -0....
# 18   9000  [0.001068115234375, -0.0204620361328125, 0.003...
# 19   9500  [-0.0034198760986328125, -0.01226806640625, -0...
# 20  10000  [-0.034576416015625, -0.0258331298828125, -0.0...
# 21  10500  [-0.0008339881896972656, -0.00543212890625, -0...
# 22  11000  [-0.0202484130859375, -0.0183868408203125, -0....
# 23  11500  [0.0041351318359375, 0.00785064697265625, 0.00...
# 24  12000  [0.003444671630859375, -0.0190887451171875, -0...
#
#                                              question  \
# 0   The symmetric group $S_n$ has $\n\factorial{n}...
# 1   ________________reflect a purchaser's high lev...
# 2   A developer is the owner of a parcel of land i...
# 3   A defendant, a nurse at a nursing home, is cha...
# 4   In time-out, a disruptive child who wants to s...
# 5   Research has shown a possible connection betwe...
# 6   The nucleotide sequence of a DNA molecule is 5...
# 7   The $J=2$ to 3 rotational transition in a cert...
# 8   For a certain liquid which obeysTrouton'srule,...
# 9   A gas in two dimensions is enclosed in a recta...
# 10  In what ways does gender shape the conceptuali...
# 11  Ralph purchases garden fertilizer at the nearb...
# 12  The houses of the future may allow you to oper...
# 13  One of the most common reasons for stoma forma...
# 14  The population of country X is exactly the sam...
# 15  What are the three major controls which the Fe...
# 16  An experiment is to be conducted to determine ...
# 17  Determine the number of positive real zero of ...
# 18  When food is exposed to gamma radiation, the f...
# 19  In the reaction _5B^11 + _2He^4 \ding{217} _7N...
# 20  The dew point (the temperature at which the wa...
# 21  Based on the paper “SoK: SSL and HTTPS: Revisi...
# 22  Hume claims that a person who is unaffected by...
# 23  The received signal at the end of a communicat...
# 24  Medium 1 has k_1 = 1.5 and extends to the left...
#
#                                               prompts answers  \
# 0   The symmetric group $S_n$ has $\n\factorial{n}...     (A)
# 1   ________________reflect a purchaser's high lev...     (G)
# 2   A developer is the owner of a parcel of land i...     (B)
# 3   A defendant, a nurse at a nursing home, is cha...     (I)
# 4   In time-out, a disruptive child who wants to s...     (G)
# 5   Research has shown a possible connection betwe...     (E)
# 6   The nucleotide sequence of a DNA molecule is 5...     (F)
# 7   The $J=2$ to 3 rotational transition in a cert...     (B)
# 8   For a certain liquid which obeysTrouton'srule,...     (D)
# 9   A gas in two dimensions is enclosed in a recta...     (D)
# 10  In what ways does gender shape the conceptuali...     (F)
# 11  Ralph purchases garden fertilizer at the nearb...     (D)
# 12  The houses of the future may allow you to oper...     (F)
# 13  One of the most common reasons for stoma forma...     (A)
# 14  The population of country X is exactly the sam...     (D)
# 15  What are the three major controls which the Fe...     (G)
# 16  An experiment is to be conducted to determine ...     (H)
# 17  Determine the number of positive real zero of ...     (I)
# 18  When food is exposed to gamma radiation, the f...     (G)
# 19  In the reaction _5B^11 + _2He^4 \ding{217} _7N...     (E)
# 20  The dew point (the temperature at which the wa...     (D)
# 21  Based on the paper “SoK: SSL and HTTPS: Revisi...     (A)
# 22  Hume claims that a person who is unaffected by...     (C)
# 23  The received signal at the end of a communicat...     (F)
# 24  Medium 1 has k_1 = 1.5 and extends to the left...     (I)
#
#                                               topic_b           topic_s  \
# 0                                             Algebra       Mathematics
# 1                                     Decision Making   Decision Making
# 2                                     Real Estate Law        RealEstate
# 3                                            Evidence             Legal
# 4                                          Discipline        Discipline
# 5                                    Mental Disorders  Mental Disorders
# 6                                             Biology           Biology
# 7                                        Spectroscopy      Spectroscopy
# 8                                           Chemistry    thermodynamics
# 9                                             Physics           Physics
# 10                                             Gender            Gender
# 11                                    Decision-making        Locational
# 12  Future\n\nThe houses of the future may allow y...      \nSmart Home
# 13                                           Disease.           Disease
# 14                                          Economics         Economics
# 15                                          Economics           Economy
# 16                                             Health            health
# 17                                           Calculus          Calculus
# 18                                               Food         radiation
# 19                                    Nuclear Physics          Nuclear.
# 20                                         Atmosphere           Physics
# 21                                       Cryptography          Security
# 22                                            Empathy           Empathy
# 23                                      Communication     Communication
# 24                                            Physics           Physics
#
#    b_wiki s_wiki
# 0    None   None
# 1    None   None
# 2    None   None
# 3    None   None
# 4    None   None
# 5    None   None
# 6    None   None
# 7    None   None
# 8    None   None
# 9    None   None
# 10   None   None
# 11   None   None
# 12   None   None
# 13   None   None
# 14   None   None
# 15   None   None
# 16   None   None
# 17   None   None
# 18   None   None
# 19   None   None
# 20   None   None
# 21   None   None
# 22   None   None
# 23   None   None
# 24   None   None

# %% [markdown]
# ### 뽑아둔 topic으로 wikipedia 검색해서, split 하기

# %%
import re
from langchain_text_splitters import (Language, RecursiveCharacterTextSplitter,)
from langchain.schema import Document
import numpy as np


# Split **** (hyper param) **********************
text_splitter = RecursiveCharacterTextSplitter.from_language(
    chunk_size=5000, chunk_overlap=1000, language=Language.HTML)



for idx, row in nowtest.iterrows() :

    broad = row['topic_b']
    broad = re.sub(r'\s{2,}|\n', '', broad) # 띄어쓰기가 2개 이상 또는 엔터 없애기
    broad = re.sub(r'[^a-zA-Z\s_]', '', broad) # 얘네들 남기기
    embed_ques = row['embed_ques']

    ########### broad ###########
    # 해당 topic에 해당하는 Wikipedia가 있는지 확인 + title, 본문 길이 출력
    wiki_broad = wiki_wiki.page(f'{broad}')
    print(f"Broad | query:{idx} {wiki_broad.exists()} | Title: {wiki_broad.title} | {len(wiki_broad.text)}")

    if wiki_broad.exists() is False : continue

    broad_docs = wiki_broad.text
    broad_docs = Document(page_content=broad_docs)

    # Split **** (hyper param)
    broad_chunk = text_splitter.split_documents([broad_docs]) ## 여기에 chunking된 애들이 저장됨
    print("Broad Splits:", len(broad_chunk)) 
    print(type(broad_chunk[0])) #????????????????????????????

    chunk = []
    for index in range(0,len(broad_chunk)) : # context 받아오기
        chunk.append(broad_chunk[index]['page_content']) #????????????????
    print() 

    chunks = passage_embeddings.embed_documents(chunk)
    #유사도 기준 내림차순 정렬
    sorted_idx = (np.array(embed_ques) @ np.array(chunks).T).argsort()[::-1]
    nowtest.at[idx, 'b_wiki'] = chunk[sorted_idx[0]].page_content # 임베딩 말고 원문 저장 // 일단 지금은 유사도 1등만 넣어둠





for idx, row in nowtest.iterrows() :
    broad, specific = row['topic_b'], row['topic_s']

    broad = re.sub(r'\s{2,}|\n', '', broad) # 띄어쓰기가 2개 이상 또는 엔터 없애기
    broad = re.sub(r'[^a-zA-Z\s_]', '', broad) # 얘네들 남기기
    specific = re.sub(r'\s{2,}|\n', '', specific) # 띄어쓰기가 2개 이상이면 없애기    
    specific = re.sub(r'[^a-zA-Z\s_]', '', specific)
    embed_ques = row['embed_ques']

    ######### specific ############# 
    if broad.lower() == specific.lower() :
        print('--same as broad--')
        continue

    specific = re.sub(r'\s{2,}|\n', '', specific) # 띄어쓰기가 2개 이상이면 없애기    
    specific = re.sub(r'[^a-zA-Z\s_]', '', specific)
    wiki_speci = wiki_wiki.page(f'{specific}')
    print(f"Speci | query:{idx} {wiki_speci.exists()} | Title: {wiki_speci.title} | {len(wiki_speci.text)}")

    if wiki_speci.exists() is False : continue

    # 받아온 Wikipedia를 split함수에 적용할 수 있도록 변환
    speci_docs = wiki_speci.text
    speci_docs = Document(page_content=speci_docs)

    # Split **** (hyper param)
    speci_chunk = text_splitter.split_documents([speci_docs]) ## 여기에도 저장됨
    print("Speci Splits:", len(speci_chunk))

    chunk = []
    for index in range(0,len(speci_chunk)) : # context 받아오기
        chunk.append(speci_chunk[index].page_content)


    chunks = passage_embeddings.embed_documents(chunk)
    #유사도 기준 내림차순 정렬
    sorted_idx = (np.array(embed_ques) @ np.array(chunks).T).argsort()[::-1]
    nowtest.at[idx, 's_wiki'] = chunk[sorted_idx[0]].page_content
    
    #########################
# Out:
# Broad | query:0 True | Title: Algebra | 54943
# Broad Splits: 14
# <class 'langchain_core.documents.base.Document'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 37
#      35 chunk = []
#      36 for index in range(0,len(broad_chunk)) : # context 받아오기
# ---> 37     chunk.append(broad_chunk[index]['page_content'])
#      38 print()
#      40 chunks = passage_embeddings.embed_documents(chunk)
#
# TypeError: 'Document' object is not subscriptable

# %%
nowtest
# Out:
#        index                                         embed_ques  \
# 0          0  [-0.0130157470703125, -0.004535675048828125, -...
# 1          1  [-0.00699615478515625, -0.038055419921875, -0....
# 2          2  [0.0017080307006835938, 0.0035076141357421875,...
# 3          3  [-0.0105438232421875, 0.0045623779296875, -0.0...
# 4          4  [-0.00896453857421875, -0.0262908935546875, -0...
# ...      ...                                                ...
# 12096  12097  [-0.00893402099609375, -0.002071380615234375, ...
# 12097  12098  [0.01129913330078125, -0.01090240478515625, -0...
# 12098  12099  [-0.02032470703125, -0.0207061767578125, -0.01...
# 12099  12100  [-0.01406097412109375, -0.01276397705078125, -...
# 12100  12101  [0.0097198486328125, 0.0142059326171875, -0.02...
#
#                                                 question  \
# 0      The symmetric group $S_n$ has $\n\factorial{n}...
# 1      Let V be the set of all real polynomials p(x)....
# 2      Let A be the set of all ordered pairs of integ...
# 3      A tank initially contains a salt solution of 3...
# 4      A total of 30 players will play basketball at ...
# ...                                                  ...
# 12096  A hot mild steel rod is placed in a carbonaceo...
# 12097  The cost of making the correct decisions for t...
# 12098  Consider the evaporation of liquid ammonia int...
# 12099  Air (100°F, 1atm) is flowing at a velocity of ...
# 12100  The frequency range of a commercially broadcas...
#
#                                                  prompts answers  \
# 0      The symmetric group $S_n$ has $\n\factorial{n}...     (A)
# 1      Let V be the set of all real polynomials p(x)....     (H)
# 2      Let A be the set of all ordered pairs of integ...     (E)
# 3      A tank initially contains a salt solution of 3...     (I)
# 4      A total of 30 players will play basketball at ...     (B)
# ...                                                  ...     ...
# 12096  A hot mild steel rod is placed in a carbonaceo...     (J)
# 12097  The cost of making the correct decisions for t...     (H)
# 12098  Consider the evaporation of liquid ammonia int...     (F)
# 12099  Air (100°F, 1atm) is flowing at a velocity of ...     (I)
# 12100  The frequency range of a commercially broadcas...     (F)
#
#                     topic_b               topic_s  \
# 0                   Algebra               Algebra
# 1               Mathematics           Mathematics
# 2               Mathematics           Mathematics
# 3      Chemical_Engineering  Chemical_Engineering
# 4                      Math                  Math
# ...                     ...                   ...
# 12096             Diffusion             Diffusion
# 12097              Decision              Decision
# 12098                  Heat         HeatTransfer.
# 12099                  Heat          HeatTransfer
# 12100           Electronics           Electronics
#
#                                                   b_wiki  \
# 0      ther with the operation of addition. The neutr...
# 1      d analytic geometry, which uses coordinates sy...
# 2      haustion to calculate the area under the arc o...
# 3                                                   None
# 4      d Germany. The oldest journal addressing instr...
# ...                                                  ...
# 12096  )\n        ]\n        .\n      \n    \n    {\d...
# 12097  Decision may refer to:\n\nLaw and politics\nJu...
# 12098  adiabatic work in terms of the statistical dis...
# 12099  rsibility, then there is entropy production, w...
# 12100  the levels as "0" or "1" is arbitrary.\nTernar...
#
#                                                   s_wiki
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      be part of every degree course that it accredi...
# 4                                                   None
# ...                                                  ...
# 12096                                               None
# 12097                                               None
# 12098                                               None
# 12099                                               None
# 12100                                               None
#
# [12101 rows x 9 columns]

# %%
nowtest.to_csv(data_path+'full_broad_test.csv', index=False)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_upstage import ChatUpstage


llm = ChatUpstage(api_key = api_key)

prompt_template = PromptTemplate.from_template(
    '''
    
    Please provide most correct answer from the following context.
    If the answer is not present in the context, please Answer "The information is NOT present in the context." with your own answer.
    
    The Answer format is as follow (do not explain) : 
    Answer: (D) keyword.
    ---
    
    Question: {question}
    Context: {context}
    Answer :
    ---
        
    '''

)
chain = prompt_template | llm

# %%
# QA
responses = []
for idx, row in nowtest.iterrows() :
    prompts, b_wiki, s_wiki = row['prompts'], row['b_wiki'], row['s_wiki']


    response = chain.invoke({"question": prompts, "context": b_wiki})
    responses.append(response.content)

# %%
responses
# Out:
# ['The characteristic of the ring 2Z is 2.\n\nAnswer: (G) 2.',
#  'Answer: (D) $95.46.',
#  'Answer: (G) A theoretical model.',
#  'The information is NOT present in the context.\n\nAnswer: (D) 6.',
#  'Answer: (D) 0.6t^3 + 60t^2 + 300t + 100.',
#  'Answer: (G) Durable goods.',
#  'To cover the floor with linoleum, you need to calculate the total length of linoleum required. The floor dimensions are 7\'6" × 11\'8", which is 87.5 inches × 140 inches. You need to add the width of the linoleum (6 feet or 72 inches) to the length of the floor to determine the total length of linoleum needed.\n\nTotal length = 87.5 inches + 140 inches + 72 inches = 299.5 inches\n\nNow, you need to convert the total length to feet and then calculate the cost.\n\nTotal length in feet = 299.5 inches / 12 = 24.96 feet\n\nCost = Total length in feet × Price per running foot\n\nCost = 24.96 feet × $1.79 per running foot = $45.02\n\nThe best way to cover the floor is to purchase 24.96 feet of linoleum, and the cost will be approximately $45.02.\n\nAnswer: (J) $35.70',
#  'The information is NOT present in the context.\n\nAnswer: (D) $810.90',
#  'Answer: (D) The confidence interval does not include zero, indicating a significant difference in proportions.\n\nThe context provided does not contain any information about the marketing research firm of Burrows, Heller and Larimer or the proportions of men and women familiar with a shoe polish. Therefore, a 95% confidence interval for the difference in proportions between men and women familiar with the product cannot be computed based on the given context.',
#  'The information is NOT present in the context.\n\nAnswer: (F) not prevail, because the son was not a party to the original contract.',
#  'The information is NOT present in the context.\nAnswer: (D) the dentist.',
#  'Answer: (F) The objection will be sustained because the question is irrelevant.',
#  "The information is NOT present in the context.\n\nAnswer: (E) prevail, because the guard used unreasonable force to protect the homeowner's property.",
#  'Answer: (D) not succeed, because the farmer was not a party to the original mortgage contract.',
#  "Answer: (D) Yes, because the student's dishonesty directly affects the credibility of his initial criminal complaint.",
#  'Answer: (F) No, because the treatise excerpts are considered hearsay and do not qualify for an exception.',
#  'Answer: (H) No, because the chemist lacks firsthand knowledge that the powder came from the defendant.',
#  'Answer: (D) Although the contract violates the law, the court will find that public policy does not bar enforcement of the contract, because the purpose of the fee is merely to raise revenue.',
#  'The Answer: (G) inadmissible, because it is prejudicial.',
#  'D.',
#  'The correct answer is (A) negative reinforcement. In time-out, a disruptive child who wants to stay with his or her class is removed from the classroom, which is an example of negative reinforcement. Negative reinforcement involves removing or eliminating an unpleasant stimulus or consequence to increase the likelihood of a specific behavior. In this case, the child is removed from the classroom as a consequence for misbehaving, which serves as a negative reinforcement to discourage future misbehavior.\n\nAnswer: (A) negative reinforcement.',
#  'Answer: (E) Drug therapy, psychiatric interviews, milieu therapy, social-learning or behavioral approaches.',
#  'The information is NOT present in the context.\nAnswer: (H) extraversion.',
#  'Answer: (H) Logarithmic.\n\nExplanation: Converting total number of errors to percent correct or vice versa involves a logarithmic transformation because the relationship between the total number of errors and the percent correct is not linear. It follows a logarithmic scale.',
#  'The information is NOT present in the context.',
#  "The information is NOT present in the context.\nAnswer: (E) Alzheimer's disease.",
#  'Answer: (B) response control.',
#  "Answer: (D) According to Weber's law, the threshold of detection is a fixed amount of intensity change regardless of the baseline intensity.",
#  'Answer: (F).',
#  'Answer: (I) Differential reproduction occurs when the percentage of viable offspring carrying a certain genotype cannot be accounted for by purely random mating. It results from nonrandom mating, differential fecundity, or differences in zygote viability or offspring fertility.',
#  'Answer: (F) 5′-C-A-U-3′.',
#  'Answer: (C) They maintain a constant internal body temperature and have a tremendous amount of subcutaneous fat serving an insulating function.',
#  "Answer: (I) The renal threshold is the concentration in the plasma of a substance such as glucose at the point where it just begins to appear in the urine. The renal clearance expresses quantitatively the kidneys' ability to eliminate a given substance from the blood.",
#  'Answer: (E) cdc mutants led to the establishment of a model of the cell cycle as a complex biochemical pathway.',
#  'Answer: (D) Evidence from taxonomy, morphology, comparative biochemistry, embryological structures and development, and genetics.',
#  'Answer: (D) 347.2 $\\mathrm{GHz}$.',
#  'The information is NOT present in the context.\nAnswer: (D) -220.14 kJ mol^{-1}.',
#  'Answer: (H) 1 × 10-^28 M.',
#  '(H) I_2 is covalent, LiCl is ionic, MgTe is covalent-ionic, Cl_2O is covalent-ionic, H_2S is covalent-ionic',
#  'The information is NOT present in the context.\nAnswer: (D) 4.74',
#  'The information is NOT present in the context.\n\nAnswer: (D) Heat of vaporization is 11.2 kcal and the normal boiling point is 264 °C',
#  'The information is NOT present in the context.\n\nAnswer: (D) 7.4 atm.',
#  'Answer: (D) 5.38 $10^6 \\mathrm{~m} \\mathrm{~s}^{-1}$.',
#  'The information is NOT present in the context.\n\nAnswer: (D) 30$\\mathrm{lb} \\mathrm{in}^{-2}$.',
#  'The information is NOT present in the context.\n\nAnswer: (A) -1.4389',
#  'The Answer is: (D) Z = [(Nc) / (π)].',
#  'The information is NOT present in the context.\n\nAnswer: (B) -10 kcal',
#  'Answer: (I) bipedalism.',
#  '질문: The Lake Forest Archaic tradition relied on ____________ resources; the Maritime Archaic hunted ___________ creatures.\n(A) pelagic; lacustrine\n(B) pelagic; littoral\n(C) pelagic; midden\n(D) littoral; lacustrine\n(E) midden; littoral\n(F) littoral; midden\n(G) lacustrine; midden\n(H) midden; pelagic\n(I) littoral; pelagic\n(J) lacustrine; pelagic\n\n답변: (D) littoral; lacustrine.',
#  'Answer: (A) The soil was waterlogged and provided conditions that allowed for the preservation of organic material.',
#  'Answer: (F).',
#  'Answer: (A) Saturn.',
#  'Answer: (D) Prepare an amended return within 30 days of the discovery of the error.',
#  'Answer: (C) an imaginary audience that is always judging our actions.',
#  'The information is NOT present in the context.\n\nAnswer: (B) 4.00%.',
#  'Answer: (D) Intervening opportunity.',
#  'The information is NOT present in the context.\n\nAnswer: (A) 60%.',
#  'Answer: (D) 17.0 percent.',
#  'Answer: (B) I wish I were your man.',
#  'The information is NOT present in the context.\n\nAnswer: (C) $4,000',
#  'The Answer: (F) Smarthouse.\n\nThe context provided does not contain information about the houses of the future or the specific terms used to describe them. However, based on common knowledge, a "Smarthouse" is a term often used to describe a house that is equipped with various smart technologies that can be controlled and operated virtually from a central terminal. Therefore, the most correct answer from the given options is (F) Smarthouse.',
#  'Answer: (I) Biotin.',
#  'Answer: (I) The process of memory retrieval slows down significantly with age.',
#  'Answer: (J) A dissolution of hierarchical modes of authority into collaborative teambased decision protocols.',
#  'Answer: (D) Increased capillary permeability due to inflammation.',
#  'Answer: (D) appendicitis.\n\nThe context does not provide information about the most common reasons for stoma formation. Therefore, the answer is based on general medical knowledge.',
#  'Answer: (B) The rate of increase in the median age of populations is slower in developing countries than wealthy countries.',
#  'Answer: (G) β2-Adrenergic agonist.',
#  'The Answer: (A) The short-run Phillips curve is downward sloping and the long-run Phillips curve is horizontal.',
#  'Answer: (A) $30,000.',
#  'Answer: (D) the people of country X enjoy a standard of living twice as much as country Y.',
#  'Answer: (G) Ensuring economic stability.\n\nJustification: The context mentions that the main objective of central banks is to ensure economic stability. It also states that monetary policy is conducted by central banks to accomplish their broader objectives, which implies that the main objective of modem central banking is to ensure economic stability. Therefore, the correct answer is (G).',
#  'Answer: (B) upward sloping demand curve.',
#  'Answer: (C) An inverse relationship between price and quantity supplied.',
#  'Answer: (A) Establishing minimum standards, providing public services, setting forth laws.',
#  'The information is NOT present in the context.\n\nAnswer: (G) raise or lower the required reserve ratio, buy or sell bonds in the open market, raise or lower the discount rate.',
#  'Answer: (H) 7^7.',
#  'Answer: (C) 11.1.',
#  'The information is NOT present in the context.\n\nAnswer: (D) $190.',
#  'Answer: (D) 97.2%.',
#  'Answer: (H) by blocking on exercise intensity.\n\nThe context provided discusses the importance of exercise and sleep for maintaining health and well-being. It mentions that daily exercise intensity is associated with cholesterol levels, while average sleep length is not. Therefore, the experiment should be conducted by blocking on exercise intensity to control for this potential confounding variable.',
#  "The information is NOT present in the context.\n\nThe answer is: [1, 1]\n\nHere's the reasoning:\n\n1. The context provided does not contain any information about the variables X_1, X_2, ... or the convergence in distribution to a normal distribution.\n2. To find the values of a and b, we need to apply the Central Limit Theorem (CLT), which states that the sum of a large number of independent and identically distributed random variables will approximate a normal distribution.\n3. For the given variables X_k, each taking values +1 or -1 with equal probabilities, the expected value (a) is E[X_k] = (1 + (-1))/2 = 0.\n4. The variance (b) can be calculated as Var[X_k] = E[(X_k - E[X_k])^2] = E[X_k^2] - (E[X_k])^2 = 1 - 0 = 1.\n5. Therefore, the values of a and b are 0 and 1, respectively.\n\nSo, the answer is [0, 1].",
#  'The information is NOT present in the context.\nAnswer: (E) -1.732',
#  'The information is NOT present in the context.\n\nAnswer: (J) 1.1111111',
#  'The information is NOT present in the context.\n\nAnswer: (B) [-1, 2, 0, 3].',
#  'Answer: (C) [1, 0].',
#  'The information is NOT present in the context.\n\nAnswer: (D) keyword.',
#  'The information is NOT present in the context.\nAnswer: (C) 9.',
#  'Answer: (D) \\frac{7\\pi}{12}.',
#  'The information is NOT present in the context.\n\nAnswer: (D) 2.25',
#  'Answer: (G) doesn’t become radioactive.',
#  'The information is NOT present in the context.\n\nAnswer: (D) 4q.',
#  'Answer: (I) younger.\n\nExplanation: According to the context, if you travel at high speed compared with your friends who "stay at home," you are (I) younger. This is because the relative motion of time dilation predicts that a faster moving observer will age more slowly than an observer at rest. This effect is known as the "twin paradox" in special relativity.',
#  'The information is NOT present in the context.\nAnswer: (B) +3e and -4e.',
#  'Answer: (F) 2.18 × 10^-18 joule.',
#  'The information is NOT present in the context.\n\nAnswer: (I) 1.01098 amu.',
#  'Answer: (I) Multiple high voltage batteries with resistors arranged in parallel.',
#  'The information is NOT present in the context.\n\nAnswer: (F) 1 × 10^5 Pa',
#  'The information is NOT present in the context.\n\nAnswer: (D) 7.91 × 10^3 m/sec.',
#  'Answer: (D) 4.50 MeV.',
#  'Answer: (D) Relative Humidity: 71.9%, Mass of 1 liter moist air: 1.2346 g.',
#  'Answer: (C) No change in velocity.',
#  'Answer: (D) Instantly, as gravitational waves travel at infinite speed.',
#  'Answer: (F) 78.4.',
#  'The information is NOT present in the context.\n\nAnswer: (B) [0, 2, 3, 5].',
#  'The information is NOT present in the context.\nAnswer: (A)',
#  'Answer: (D) 34.0.',
#  'The information is NOT present in the context.\n\nAnswer: (E) Life was a series of random events with no ultimate purpose.',
#  'Answer: (F) repugnant to Nature; indifferent to Nature.',
#  'Answer: (A) the artificial assumptions are, in fact, empirical claims that are central to the debate.',
#  'Answer: (J) the welfare of others.',
#  'The information is NOT present in the context.\n\nAnswer: (G) He claims that the objection is based on a misunderstanding.',
#  'The information is NOT present in the context.\n\nAnswer: (D) -100j ohms.',
#  'The information is NOT present in the context.\n\nAnswer: The information is NOT present in the context.',
#  'Answer: (D) 1600lbf/ft^2 for 1/2 in. diameter, 550lbf/ft^2 for 1 in. diameter.',
#  'Answer: (D) Bandwidth is approximately 64 kHz, modulating signal for FM is cos 500t, and for PM is sin 500t',
#  'The information is NOT present in the context.\nAnswer: (D) 480 fps, 32.2 fps',
#  'The information is NOT present in the context.\n\nAnswer: (D) q = 163.7 e(t / 50)C, i = 0.149 e(t / 50)A',
#  'The information is NOT present in the context.\n\nAnswer: (D) πσ^2.',
#  'The information is NOT present in the context.\n\nAnswer: (D) 144,580 cal/g mol CH_4.',
#  'The information is NOT present in the context.\n\nAnswer: (D) E_1 = x̂_2 - \\^{y}_3.5 + ẑ, E_2 = x̂1.4 - \\^{y}3.5 + ẑ, D_1 =\\epsilon_0(x̂3 - \\^{y}5.25 + ẑ1.75), D_2 = \\epsilon_0(x̂4.2 - \\^{y}8.75 + ẑ3.5)',
#  'Answer: (I) 1.09 Btu/hr ft²°F, 51,569 Btu/hr, 0.0015, 6.18 × 10^-4lb_f/ft², 0.023 ft.']

# %% [markdown]
# ### Groundedness check

# %%
import os
from langchain_upstage import UpstageGroundednessCheck
 
os.environ["UPSTAGE_API_KEY"] = api_key
 
groundedness_check = UpstageGroundednessCheck()
 
request_input = {
    "context": f"{}",
    "answer": f"{}}",
}
response = groundedness_check.invoke(request_input)
print(response)
# Out:
#   Cell In[29], line 9
#     "context": f"{}",
#                     ^
# SyntaxError: f-string: empty expression not allowed

# %%
answers = nowtest.answers
answers
# Out:
# 0      (A)
# 1      (E)
# 2      (J)
# 3      (H)
# 4      (J)
#       ...
# 117    (D)
# 118    (I)
# 119    (D)
# 120    (I)
# 121    (I)
# Name: answers, Length: 122, dtype: object

# %% [markdown]
# ## Check Accuracy

# %%
# funcion to extract an answer from response

import re

def extract_answer(response):
    """
    extracts the answer from the response using a regular expression.
    expected format: "[ANSWER]: (A) convolutional networks"

    if there are any answers formatted like the format, it returns None.
    """
    pattern = r"\[ANSWER\]:\s*\((A|B|C|D|E)\)"  # Regular expression to capture the answer letter and text
    match = re.search(pattern, response)

    if match:
        return match.group(1) # Extract the letter inside parentheses (e.g., A)
    else:
        return extract_again(response)

def extract_again(response):
    pattern = r"\b[A-J]\b(?!.*\b[A-J]\b)"
    match = re.search(pattern, response)
    if match:
        return match.group(0)
    else:
        return None

# %%
# print accuracy

cnt = 0

for answer, response in zip(answers, responses):
    print("-"*10)
    generated_answer = extract_answer(response)
    print(response)
    # check
    if generated_answer:
        print(f"generated answer: {generated_answer}, answer: {answer}")
    else:
        print("extraction fail")


    if generated_answer == None:
        continue
    if generated_answer in answer:
        cnt += 1

print()
print(f"acc: {(cnt/len(answers))*100}%")
# Out:
# ----------
# The characteristic of the ring 2Z is 2.
#
# Answer: (G) 2.
# generated answer: G, answer: (A)
# ----------
# Answer: (D) $95.46.
# generated answer: D, answer: (E)
# ----------
# Answer: (G) A theoretical model.
# generated answer: A, answer: (J)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) 6.
# generated answer: D, answer: (H)
# ----------
# Answer: (D) 0.6t^3 + 60t^2 + 300t + 100.
# generated answer: D, answer: (J)
# ----------
# Answer: (G) Durable goods.
# generated answer: G, answer: (G)
# ----------
# To cover the floor with linoleum, you need to calculate the total length of linoleum required. The floor dimensions are 7'6" × 11'8", which is 87.5 inches × 140 inches. You need to add the width of the linoleum (6 feet or 72 inches) to the length of the floor to determine the total length of linoleum needed.
#
# Total length = 87.5 inches + 140 inches + 72 inches = 299.5 inches
#
# Now, you need to convert the total length to feet and then calculate the cost.
#
# Total length in feet = 299.5 inches / 12 = 24.96 feet
#
# Cost = Total length in feet × Price per running foot
#
# Cost = 24.96 feet × $1.79 per running foot = $45.02
#
# The best way to cover the floor is to purchase 24.96 feet of linoleum, and the cost will be approximately $45.02.
#
# Answer: (J) $35.70
# generated answer: J, answer: (B)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) $810.90
# generated answer: D, answer: (E)
# ----------
# Answer: (D) The confidence interval does not include zero, indicating a significant difference in proportions.
#
# The context provided does not contain any information about the marketing research firm of Burrows, Heller and Larimer or the proportions of men and women familiar with a shoe polish. Therefore, a 95% confidence interval for the difference in proportions between men and women familiar with the product cannot be computed based on the given context.
# generated answer: D, answer: (B)
# ----------
# The information is NOT present in the context.
#
# Answer: (F) not prevail, because the son was not a party to the original contract.
# generated answer: F, answer: (J)
# ----------
# The information is NOT present in the context.
# Answer: (D) the dentist.
# generated answer: D, answer: (B)
# ----------
# Answer: (F) The objection will be sustained because the question is irrelevant.
# generated answer: F, answer: (A)
# ----------
# The information is NOT present in the context.
#
# Answer: (E) prevail, because the guard used unreasonable force to protect the homeowner's property.
# generated answer: E, answer: (E)
# ----------
# Answer: (D) not succeed, because the farmer was not a party to the original mortgage contract.
# generated answer: D, answer: (I)
# ----------
# Answer: (D) Yes, because the student's dishonesty directly affects the credibility of his initial criminal complaint.
# generated answer: D, answer: (F)
# ----------
# Answer: (F) No, because the treatise excerpts are considered hearsay and do not qualify for an exception.
# generated answer: F, answer: (I)
# ----------
# Answer: (H) No, because the chemist lacks firsthand knowledge that the powder came from the defendant.
# generated answer: H, answer: (E)
# ----------
# Answer: (D) Although the contract violates the law, the court will find that public policy does not bar enforcement of the contract, because the purpose of the fee is merely to raise revenue.
# generated answer: D, answer: (D)
# ----------
# The Answer: (G) inadmissible, because it is prejudicial.
# generated answer: G, answer: (B)
# ----------
# D.
# generated answer: D, answer: (E)
# ----------
# The correct answer is (A) negative reinforcement. In time-out, a disruptive child who wants to stay with his or her class is removed from the classroom, which is an example of negative reinforcement. Negative reinforcement involves removing or eliminating an unpleasant stimulus or consequence to increase the likelihood of a specific behavior. In this case, the child is removed from the classroom as a consequence for misbehaving, which serves as a negative reinforcement to discourage future misbehavior.
#
# Answer: (A) negative reinforcement.
# generated answer: A, answer: (G)
# ----------
# Answer: (E) Drug therapy, psychiatric interviews, milieu therapy, social-learning or behavioral approaches.
# generated answer: E, answer: (E)
# ----------
# The information is NOT present in the context.
# Answer: (H) extraversion.
# generated answer: H, answer: (E)
# ----------
# Answer: (H) Logarithmic.
#
# Explanation: Converting total number of errors to percent correct or vice versa involves a logarithmic transformation because the relationship between the total number of errors and the percent correct is not linear. It follows a logarithmic scale.
# generated answer: H, answer: (I)
# ----------
# The information is NOT present in the context.
# extraction fail
# ----------
# The information is NOT present in the context.
# Answer: (E) Alzheimer's disease.
# generated answer: E, answer: (E)
# ----------
# Answer: (B) response control.
# generated answer: B, answer: (G)
# ----------
# Answer: (D) According to Weber's law, the threshold of detection is a fixed amount of intensity change regardless of the baseline intensity.
# generated answer: D, answer: (H)
# ----------
# Answer: (F).
# generated answer: F, answer: (F)
# ----------
# Answer: (I) Differential reproduction occurs when the percentage of viable offspring carrying a certain genotype cannot be accounted for by purely random mating. It results from nonrandom mating, differential fecundity, or differences in zygote viability or offspring fertility.
# generated answer: I, answer: (I)
# ----------
# Answer: (F) 5′-C-A-U-3′.
# generated answer: A, answer: (F)
# ----------
# Answer: (C) They maintain a constant internal body temperature and have a tremendous amount of subcutaneous fat serving an insulating function.
# generated answer: C, answer: (C)
# ----------
# Answer: (I) The renal threshold is the concentration in the plasma of a substance such as glucose at the point where it just begins to appear in the urine. The renal clearance expresses quantitatively the kidneys' ability to eliminate a given substance from the blood.
# generated answer: I, answer: (I)
# ----------
# Answer: (E) cdc mutants led to the establishment of a model of the cell cycle as a complex biochemical pathway.
# generated answer: E, answer: (E)
# ----------
# Answer: (D) Evidence from taxonomy, morphology, comparative biochemistry, embryological structures and development, and genetics.
# generated answer: D, answer: (D)
# ----------
# Answer: (D) 347.2 $\mathrm{GHz}$.
# generated answer: D, answer: (B)
# ----------
# The information is NOT present in the context.
# Answer: (D) -220.14 kJ mol^{-1}.
# generated answer: D, answer: (H)
# ----------
# Answer: (H) 1 × 10-^28 M.
# generated answer: H, answer: (C)
# ----------
# (H) I_2 is covalent, LiCl is ionic, MgTe is covalent-ionic, Cl_2O is covalent-ionic, H_2S is covalent-ionic
# generated answer: H, answer: (H)
# ----------
# The information is NOT present in the context.
# Answer: (D) 4.74
# generated answer: D, answer: (E)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) Heat of vaporization is 11.2 kcal and the normal boiling point is 264 °C
# generated answer: C, answer: (D)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) 7.4 atm.
# generated answer: D, answer: (A)
# ----------
# Answer: (D) 5.38 $10^6 \mathrm{~m} \mathrm{~s}^{-1}$.
# generated answer: D, answer: (F)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) 30$\mathrm{lb} \mathrm{in}^{-2}$.
# generated answer: D, answer: (D)
# ----------
# The information is NOT present in the context.
#
# Answer: (A) -1.4389
# generated answer: A, answer: (A)
# ----------
# The Answer is: (D) Z = [(Nc) / (π)].
# generated answer: D, answer: (D)
# ----------
# The information is NOT present in the context.
#
# Answer: (B) -10 kcal
# generated answer: B, answer: (I)
# ----------
# Answer: (I) bipedalism.
# generated answer: I, answer: (J)
# ----------
# 질문: The Lake Forest Archaic tradition relied on ____________ resources; the Maritime Archaic hunted ___________ creatures.
# (A) pelagic; lacustrine
# (B) pelagic; littoral
# (C) pelagic; midden
# (D) littoral; lacustrine
# (E) midden; littoral
# (F) littoral; midden
# (G) lacustrine; midden
# (H) midden; pelagic
# (I) littoral; pelagic
# (J) lacustrine; pelagic
#
# 답변: (D) littoral; lacustrine.
# generated answer: A, answer: (J)
# ----------
# Answer: (A) The soil was waterlogged and provided conditions that allowed for the preservation of organic material.
# generated answer: A, answer: (A)
# ----------
# Answer: (F).
# generated answer: F, answer: (F)
# ----------
# Answer: (A) Saturn.
# generated answer: A, answer: (A)
# ----------
# Answer: (D) Prepare an amended return within 30 days of the discovery of the error.
# generated answer: D, answer: (E)
# ----------
# Answer: (C) an imaginary audience that is always judging our actions.
# generated answer: C, answer: (E)
# ----------
# The information is NOT present in the context.
#
# Answer: (B) 4.00%.
# generated answer: B, answer: (C)
# ----------
# Answer: (D) Intervening opportunity.
# generated answer: D, answer: (D)
# ----------
# The information is NOT present in the context.
#
# Answer: (A) 60%.
# generated answer: A, answer: (B)
# ----------
# Answer: (D) 17.0 percent.
# generated answer: D, answer: (G)
# ----------
# Answer: (B) I wish I were your man.
# generated answer: I, answer: (D)
# ----------
# The information is NOT present in the context.
#
# Answer: (C) $4,000
# generated answer: C, answer: (J)
# ----------
# The Answer: (F) Smarthouse.
#
# The context provided does not contain information about the houses of the future or the specific terms used to describe them. However, based on common knowledge, a "Smarthouse" is a term often used to describe a house that is equipped with various smart technologies that can be controlled and operated virtually from a central terminal. Therefore, the most correct answer from the given options is (F) Smarthouse.
# generated answer: F, answer: (F)
# ----------
# Answer: (I) Biotin.
# generated answer: I, answer: (E)
# ----------
# Answer: (I) The process of memory retrieval slows down significantly with age.
# generated answer: I, answer: (A)
# ----------
# Answer: (J) A dissolution of hierarchical modes of authority into collaborative teambased decision protocols.
# generated answer: A, answer: (J)
# ----------
# Answer: (D) Increased capillary permeability due to inflammation.
# generated answer: D, answer: (I)
# ----------
# Answer: (D) appendicitis.
#
# The context does not provide information about the most common reasons for stoma formation. Therefore, the answer is based on general medical knowledge.
# generated answer: D, answer: (A)
# ----------
# Answer: (B) The rate of increase in the median age of populations is slower in developing countries than wealthy countries.
# generated answer: B, answer: (F)
# ----------
# Answer: (G) β2-Adrenergic agonist.
# generated answer: G, answer: (G)
# ----------
# The Answer: (A) The short-run Phillips curve is downward sloping and the long-run Phillips curve is horizontal.
# generated answer: A, answer: (B)
# ----------
# Answer: (A) $30,000.
# generated answer: A, answer: (H)
# ----------
# Answer: (D) the people of country X enjoy a standard of living twice as much as country Y.
# generated answer: D, answer: (D)
# ----------
# Answer: (G) Ensuring economic stability.
#
# Justification: The context mentions that the main objective of central banks is to ensure economic stability. It also states that monetary policy is conducted by central banks to accomplish their broader objectives, which implies that the main objective of modem central banking is to ensure economic stability. Therefore, the correct answer is (G).
# generated answer: G, answer: (A)
# ----------
# Answer: (B) upward sloping demand curve.
# generated answer: B, answer: (C)
# ----------
# Answer: (C) An inverse relationship between price and quantity supplied.
# generated answer: C, answer: (D)
# ----------
# Answer: (A) Establishing minimum standards, providing public services, setting forth laws.
# generated answer: A, answer: (A)
# ----------
# The information is NOT present in the context.
#
# Answer: (G) raise or lower the required reserve ratio, buy or sell bonds in the open market, raise or lower the discount rate.
# generated answer: G, answer: (G)
# ----------
# Answer: (H) 7^7.
# generated answer: H, answer: (B)
# ----------
# Answer: (C) 11.1.
# generated answer: C, answer: (G)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) $190.
# generated answer: D, answer: (C)
# ----------
# Answer: (D) 97.2%.
# generated answer: D, answer: (E)
# ----------
# Answer: (H) by blocking on exercise intensity.
#
# The context provided discusses the importance of exercise and sleep for maintaining health and well-being. It mentions that daily exercise intensity is associated with cholesterol levels, while average sleep length is not. Therefore, the experiment should be conducted by blocking on exercise intensity to control for this potential confounding variable.
# generated answer: H, answer: (H)
# ----------
# The information is NOT present in the context.
#
# The answer is: [1, 1]
#
# Here's the reasoning:
#
# 1. The context provided does not contain any information about the variables X_1, X_2, ... or the convergence in distribution to a normal distribution.
# 2. To find the values of a and b, we need to apply the Central Limit Theorem (CLT), which states that the sum of a large number of independent and identically distributed random variables will approximate a normal distribution.
# 3. For the given variables X_k, each taking values +1 or -1 with equal probabilities, the expected value (a) is E[X_k] = (1 + (-1))/2 = 0.
# 4. The variance (b) can be calculated as Var[X_k] = E[(X_k - E[X_k])^2] = E[X_k^2] - (E[X_k])^2 = 1 - 0 = 1.
# 5. Therefore, the values of a and b are 0 and 1, respectively.
#
# So, the answer is [0, 1].
# generated answer: E, answer: (B)
# ----------
# The information is NOT present in the context.
# Answer: (E) -1.732
# generated answer: E, answer: (I)
# ----------
# The information is NOT present in the context.
#
# Answer: (J) 1.1111111
# generated answer: J, answer: (E)
# ----------
# The information is NOT present in the context.
#
# Answer: (B) [-1, 2, 0, 3].
# generated answer: B, answer: (J)
# ----------
# Answer: (C) [1, 0].
# generated answer: C, answer: (I)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) keyword.
# generated answer: D, answer: (F)
# ----------
# The information is NOT present in the context.
# Answer: (C) 9.
# generated answer: C, answer: (G)
# ----------
# Answer: (D) \frac{7\pi}{12}.
# generated answer: D, answer: (I)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) 2.25
# generated answer: D, answer: (B)
# ----------
# Answer: (G) doesn’t become radioactive.
# generated answer: G, answer: (G)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) 4q.
# generated answer: D, answer: (I)
# ----------
# Answer: (I) younger.
#
# Explanation: According to the context, if you travel at high speed compared with your friends who "stay at home," you are (I) younger. This is because the relative motion of time dilation predicts that a faster moving observer will age more slowly than an observer at rest. This effect is known as the "twin paradox" in special relativity.
# generated answer: I, answer: (I)
# ----------
# The information is NOT present in the context.
# Answer: (B) +3e and -4e.
# generated answer: B, answer: (B)
# ----------
# Answer: (F) 2.18 × 10^-18 joule.
# generated answer: F, answer: (E)
# ----------
# The information is NOT present in the context.
#
# Answer: (I) 1.01098 amu.
# generated answer: I, answer: (E)
# ----------
# Answer: (I) Multiple high voltage batteries with resistors arranged in parallel.
# generated answer: I, answer: (B)
# ----------
# The information is NOT present in the context.
#
# Answer: (F) 1 × 10^5 Pa
# generated answer: F, answer: (H)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) 7.91 × 10^3 m/sec.
# generated answer: D, answer: (D)
# ----------
# Answer: (D) 4.50 MeV.
# generated answer: D, answer: (I)
# ----------
# Answer: (D) Relative Humidity: 71.9%, Mass of 1 liter moist air: 1.2346 g.
# generated answer: D, answer: (D)
# ----------
# Answer: (C) No change in velocity.
# generated answer: C, answer: (E)
# ----------
# Answer: (D) Instantly, as gravitational waves travel at infinite speed.
# generated answer: D, answer: (E)
# ----------
# Answer: (F) 78.4.
# generated answer: F, answer: (A)
# ----------
# The information is NOT present in the context.
#
# Answer: (B) [0, 2, 3, 5].
# generated answer: B, answer: (H)
# ----------
# The information is NOT present in the context.
# Answer: (A)
# generated answer: A, answer: (A)
# ----------
# Answer: (D) 34.0.
# generated answer: D, answer: (E)
# ----------
# The information is NOT present in the context.
#
# Answer: (E) Life was a series of random events with no ultimate purpose.
# generated answer: E, answer: (I)
# ----------
# Answer: (F) repugnant to Nature; indifferent to Nature.
# generated answer: F, answer: (D)
# ----------
# Answer: (A) the artificial assumptions are, in fact, empirical claims that are central to the debate.
# generated answer: A, answer: (A)
# ----------
# Answer: (J) the welfare of others.
# generated answer: J, answer: (C)
# ----------
# The information is NOT present in the context.
#
# Answer: (G) He claims that the objection is based on a misunderstanding.
# generated answer: G, answer: (A)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) -100j ohms.
# generated answer: D, answer: (H)
# ----------
# The information is NOT present in the context.
#
# Answer: The information is NOT present in the context.
# extraction fail
# ----------
# Answer: (D) 1600lbf/ft^2 for 1/2 in. diameter, 550lbf/ft^2 for 1 in. diameter.
# generated answer: D, answer: (A)
# ----------
# Answer: (D) Bandwidth is approximately 64 kHz, modulating signal for FM is cos 500t, and for PM is sin 500t
# generated answer: D, answer: (F)
# ----------
# The information is NOT present in the context.
# Answer: (D) 480 fps, 32.2 fps
# generated answer: D, answer: (I)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) q = 163.7 e(t / 50)C, i = 0.149 e(t / 50)A
# generated answer: A, answer: (D)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) πσ^2.
# generated answer: D, answer: (I)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) 144,580 cal/g mol CH_4.
# generated answer: D, answer: (D)
# ----------
# The information is NOT present in the context.
#
# Answer: (D) E_1 = x̂_2 - \^{y}_3.5 + ẑ, E_2 = x̂1.4 - \^{y}3.5 + ẑ, D_1 =\epsilon_0(x̂3 - \^{y}5.25 + ẑ1.75), D_2 = \epsilon_0(x̂4.2 - \^{y}8.75 + ẑ3.5)
# generated answer: D, answer: (I)
# ----------
# Answer: (I) 1.09 Btu/hr ft²°F, 51,569 Btu/hr, 0.0015, 6.18 × 10^-4lb_f/ft², 0.023 ft.
# generated answer: F, answer: (I)
#
# acc: 27.049180327868854%
