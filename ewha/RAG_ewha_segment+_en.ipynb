# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/UpstageAI/cookbook/blob/main/cookbooks/upstage/Solar-Full-Stack LLM-101/05_3_OracleDB.ipynb">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Retrieval Augmented Generation (RAG) Baseline

# %% [markdown]
# # Baseline

# %%
# set parameters

file = open("info/api.txt", "r")
api_key = file.read()
file.close()

file = open("info/datapath.txt", "r")
data_path = file.read()
file.close()

file = open("info/resultspath.txt", "r")
results_path = file.read()
file.close()

# %%
from langchain_upstage import UpstageEmbeddings

# 쿼리 전용 임베딩 모델
query_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-query")

# 문장 전용 임베딩 모델
passage_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-passage")

# %%
# funcion to extract an answer from response

import re

def extract_answer(response):
    """
    extracts the answer from the response using a regular expression.
    expected format: "[ANSWER]: (A) convolutional networks"

    if there are any answers formatted like the format, it returns None.
    """
    pattern = r"\[ANSWER\]:\s*\((A|B|C|D|E)\)"  # Regular expression to capture the answer letter and text
    match = re.search(pattern, response)

    if match:
        return match.group(1) # Extract the letter inside parentheses (e.g., A)
    else:
        return extract_again(response)

def extract_again(response):
    pattern = r"\b[A-J]\b(?!.*\b[A-J]\b)"
    match = re.search(pattern, response)
    if match:
        return match.group(0)
    else:
        return None

# %% [markdown]
# ## Load DB

# %%
from langchain_upstage import UpstageLayoutAnalysisLoader
import os
import numpy as np


UPSTAGE_API_KEY = api_key

# .npy 파일 로드 (타입==넘파이)
ewhaDB = np.load(data_path+f'embedding/full_ewha500.npy')

ewhaDB_embed = np.load(data_path+f'embedding/full_ewha500_embed.npy')
ewhaDB_embed = ewhaDB_embed.tolist()

# %% [markdown]
# ## DB Split (chunking)

# %% [markdown]
# ## test set 가져와서 dataframe 만들기

# %%
# read samples.csv file
import pandas as pd

def read_data(data_path):
    data = pd.read_csv(data_path)
    prompts = data['prompts']
    answers = data['answers']
    # returns two lists: prompts and answers
    return prompts, answers

# %%
prompts, answers = read_data(os.path.join(data_path, 'test_own_ewha.csv'))

# %%
testdata = pd.read_csv(data_path+'test_own_ewha.csv')

# %%
nowtest = pd.DataFrame(columns=['index', 'embed_ques', 'question', 'prompts', 'answers','predict', 'top1', 'top2', 'top3', 'top1plus', 'top2plus', 'top3plus', 'ground' ])

for index, row in testdata.iterrows():
    #if index % 100 != 0 : continue # 일단 실험할 땐 100개 단위로 끊어서 가져옴
    q = row.prompts
    a = row.answers
    question = q.partition('(A)')[0]
    question = question.partition(') ')[2]
    q = q.partition(') ')[2]
    try : 
        embedded_query = query_embeddings.embed_query(question) # >>질문<<만 받아와서 embedding 하기 // >>선지까지<< 받아와서 embedding하기
        nowtest.loc[len(nowtest)] = {'index':index, 'embed_ques' : embedded_query, 'question' : question, 'prompts' : q, 'answers' : a }

    except :
        print(f'pass: {index}')
        continue

# %%
nowtest
# Out:
#     index                                         embed_ques  \
# 0       0  [-0.005329132080078125, 0.0017337799072265625,...
# 1       1  [-0.00460052490234375, -0.0174713134765625, -0...
# 2       2  [0.007404327392578125, -0.0216522216796875, 0....
# 3       3  [-0.002162933349609375, -0.039215087890625, -0...
# 4       4  [0.0089111328125, -0.0259552001953125, -0.0064...
# 5       5  [0.0015554428100585938, -0.019683837890625, -0...
# 6       6  [-0.018157958984375, -0.0157318115234375, -0.0...
# 7       7  [0.0029163360595703125, -0.018707275390625, -0...
# 8       8  [-5.4895877838134766e-05, -0.01477813720703125...
# 9       9  [-0.002269744873046875, 0.0017795562744140625,...
# 10     10  [-0.0174560546875, -0.022064208984375, -0.0094...
# 11     11  [-0.0036525726318359375, 0.005313873291015625,...
# 12     12  [0.00012981891632080078, -0.01374053955078125,...
# 13     13  [-0.0191650390625, -0.0198516845703125, -0.027...
# 14     14  [-0.006168365478515625, -0.009368896484375, -0...
# 15     15  [-0.00464630126953125, -0.00894927978515625, -...
# 16     16  [0.00395965576171875, -0.0242156982421875, -0....
# 17     17  [-0.023773193359375, -0.012847900390625, -0.01...
# 18     18  [0.0045623779296875, -0.026580810546875, -0.01...
# 19     19  [0.0032901763916015625, -0.0141448974609375, 0...
# 20     20  [-0.0005626678466796875, -0.0136566162109375, ...
# 21     21  [-0.01462554931640625, -0.0188140869140625, -0...
# 22     22  [-0.00027251243591308594, -0.01363372802734375...
# 23     23  [0.00484466552734375, -0.00014400482177734375,...
# 24     24  [-0.0201263427734375, -0.01532745361328125, -0...
# 25     25  [0.01309967041015625, -0.0241546630859375, -0....
# 26     26  [0.01483154296875, -0.03533935546875, -0.00331...
# 27     27  [0.035247802734375, -0.0292510986328125, -0.02...
# 28     28  [0.00457763671875, -0.0146636962890625, -0.000...
# 29     29  [0.00870513916015625, -0.005367279052734375, -...
# 30     30  [-0.017486572265625, -0.029327392578125, -0.01...
# 31     31  [0.00934600830078125, -0.00826263427734375, -0...
# 32     32  [0.004810333251953125, -0.01242828369140625, -...
# 33     33  [-0.00408172607421875, -0.0066680908203125, -0...
# 34     34  [0.01059722900390625, 0.003986358642578125, -0...
# 35     35  [0.01451873779296875, -0.0285491943359375, -0....
# 36     36  [0.005802154541015625, -0.0128326416015625, -0...
# 37     37  [-0.0031147003173828125, -0.000395059585571289...
# 38     38  [-0.01178741455078125, -0.035858154296875, -0....
# 39     39  [-0.0184173583984375, -0.0208740234375, -0.007...
# 40     40  [-0.00659942626953125, 0.005962371826171875, -...
# 41     41  [0.0025501251220703125, -0.00481414794921875, ...
#
#                                              question  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...
# 1                 각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n
# 2           부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n
# 3               학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...
# 5           학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n
# 6    학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?\n
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...
# 9        학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까?\n
# 11     학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n
# 12   학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?\n
# 13      학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n
# 14          학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n
# 15    학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\n
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...
# 20    학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\n
# 21     학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...
# 25                             전공과 관련된 조항으로 올바른 것은?\n
# 26                         등록금에 관한 조항으로 올바르지 않은 것은?\n
# 27                                 전공과목은 어떻게 구분되는가?\n
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...
# 29                          학칙개정에 관한 설명으로 옳지 않은 것은?\n
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...
# 31                  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...
# 33       제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...
# 36               제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n
# 37          제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...
#
#                                               prompts answers predict  top1  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...     (D)    None  None
# 1   각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n(A) 이학사\n(B...     (E)    None  None
# 2   부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n(A) 현...     (B)    None  None
# 3   학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n(A) 시험 직후...     (B)    None  None
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...     (C)    None  None
# 5   학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n(A) 서...     (D)    None  None
# 6   학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?...     (C)    None  None
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...     (D)    None  None
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...     (C)    None  None
# 9   학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n(A...     (B)    None  None
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까...     (B)    None  None
# 11  학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n...     (C)    None  None
# 12  학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?...     (B)    None  None
# 13  학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n(...     (E)    None  None
# 14  학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n(A) 신...     (A)    None  None
# 15  학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\...     (C)    None  None
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...     (E)    None  None
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...     (B)    None  None
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...     (C)    None  None
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...     (C)    None  None
# 20  학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\...     (C)    None  None
# 21  학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n...     (D)    None  None
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...     (B)    None  None
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...     (C)    None  None
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...     (B)    None  None
# 25  전공과 관련된 조항으로 올바른 것은?\n(A) 2 이상의 학부가 연계하여 제공하는 ...     (B)    None  None
# 26  등록금에 관한 조항으로 올바르지 않은 것은?\n(A) 총장은 등록금심의위원회의 구성...     (E)    None  None
# 27  전공과목은 어떻게 구분되는가?\n(A) 전공기초과목과 전공과목\n(B) 총장이 따로...     (C)    None  None
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...     (D)    None  None
# 29  학칙개정에 관한 설명으로 옳지 않은 것은?\n(A) 학칙 개정과 대학평의원회는 무관...     (A)    None  None
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...     (B)    None  None
# 31  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n(A) 학칙 개정은 사전...     (C)    None  None
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...     (A)    None  None
# 33  제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n(A...     (C)    None  None
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...     (D)    None  None
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...     (D)    None  None
# 36  제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n(A) 입학 전형은...     (B)    None  None
# 37  제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n(A) 입...     (B)    None  None
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...     (A)    None  None
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...     (A)    None  None
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...     (B)    None  None
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...     (A)    None  None
#
#     top2  top3  top1plus  top2plus  top3plus  ground
# 0   None  None       NaN       NaN       NaN     NaN
# 1   None  None       NaN       NaN       NaN     NaN
# 2   None  None       NaN       NaN       NaN     NaN
# 3   None  None       NaN       NaN       NaN     NaN
# 4   None  None       NaN       NaN       NaN     NaN
# 5   None  None       NaN       NaN       NaN     NaN
# 6   None  None       NaN       NaN       NaN     NaN
# 7   None  None       NaN       NaN       NaN     NaN
# 8   None  None       NaN       NaN       NaN     NaN
# 9   None  None       NaN       NaN       NaN     NaN
# 10  None  None       NaN       NaN       NaN     NaN
# 11  None  None       NaN       NaN       NaN     NaN
# 12  None  None       NaN       NaN       NaN     NaN
# 13  None  None       NaN       NaN       NaN     NaN
# 14  None  None       NaN       NaN       NaN     NaN
# 15  None  None       NaN       NaN       NaN     NaN
# 16  None  None       NaN       NaN       NaN     NaN
# 17  None  None       NaN       NaN       NaN     NaN
# 18  None  None       NaN       NaN       NaN     NaN
# 19  None  None       NaN       NaN       NaN     NaN
# 20  None  None       NaN       NaN       NaN     NaN
# 21  None  None       NaN       NaN       NaN     NaN
# 22  None  None       NaN       NaN       NaN     NaN
# 23  None  None       NaN       NaN       NaN     NaN
# 24  None  None       NaN       NaN       NaN     NaN
# 25  None  None       NaN       NaN       NaN     NaN
# 26  None  None       NaN       NaN       NaN     NaN
# 27  None  None       NaN       NaN       NaN     NaN
# 28  None  None       NaN       NaN       NaN     NaN
# 29  None  None       NaN       NaN       NaN     NaN
# 30  None  None       NaN       NaN       NaN     NaN
# 31  None  None       NaN       NaN       NaN     NaN
# 32  None  None       NaN       NaN       NaN     NaN
# 33  None  None       NaN       NaN       NaN     NaN
# 34  None  None       NaN       NaN       NaN     NaN
# 35  None  None       NaN       NaN       NaN     NaN
# 36  None  None       NaN       NaN       NaN     NaN
# 37  None  None       NaN       NaN       NaN     NaN
# 38  None  None       NaN       NaN       NaN     NaN
# 39  None  None       NaN       NaN       NaN     NaN
# 40  None  None       NaN       NaN       NaN     NaN
# 41  None  None       NaN       NaN       NaN     NaN

# %% [markdown]
# ## chunk마다 Evidence와 Reasoning 생성
#
# 계산 효율을 위해 그냥 모든 chunk를 미리 segment+(note) 해두기 (나중에 유사도 계산 후에 관련있는 애들 다시 중복으로 계산 할 바에 미리 해둔다는 뜻)

# %%
############# Segment+ first prompt ( Evidence and Reasoning ) ##########

### 논문에서 제공하는 영어 버전으로 하면, 답변에 영어가 섞이는 현상 -> 프롬프트를 한글로 바꿈
### 논문 그대로 프롬프트를 제공하면 전부 이해하지 못하는 것 같아서 좀 간소화시킴

from langchain_core.prompts import PromptTemplate
from langchain_upstage import ChatUpstage

 
llm = ChatUpstage(api_key = api_key)

prompt_template = PromptTemplate.from_template(
    '''

    You are provided with a segment from a long document along with a question related to this document.
    Segment Content: {context1}
    —
    Question: {question}
    —

    Your task: Evaluate the provided segment against the question to identify and categorize information into two distinct types: 'Evidence' and 'Reasoning'. Your assessment and categorization should adhere to the following guidelines:
    Guidelines for Note-Writing:
    Your note should be meticulously structured into two main parts: Evidence and Reasoning,
    following these guidelines:
    - Evidence:
        1. Extract key sentences or descriptions from the segment that are pertinent to the question, with a focus on specific details such as
        numbers, relevant words, and other significant
        elements.
          (1) Include content that directly relates to the question, providing a straightforward answer.
          (2) Also include content that may not directly answer the question but is valuable for answering it when combined with information from other segments. For instance, for questions about someone’s birthplace, include all mentioned birthplaces for potential matching in later analysis. Similarly, if the question involves several events but this segment only contains information about one event, you should include it.
        2. Accurately quote the directly related sentences to present clear and unambiguous evidence.
    - Reasoning:
        1. Analyze the question and any subquestions, offering answers, summaries, interpretations, or any relevant commentary to deepen the understanding of the question.
    
    The note should be formatted in JSON as follows:
    [ 'Evidence': 'Your evidence content here',
    'Reasoning': 'Your reasoning content here' ]
            
    '''

)
segplus1 = prompt_template | llm

# %%
nowtest.question[0]
# Out:
# '영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학점은 몇점인가?\n'

# %% [markdown]
# ## question - chunk 유사도 계산

# %%
# 유사도 높은 chunk top3를 df에 넣어두기

import numpy as np


for idx, row in nowtest.iterrows() : # 질문 받아오기 
    #if idx == 10 : break ## 테스트용
    embed_ques= row.embed_ques
    prompt = row.prompts
    ques = row.question

    sorted_idx = (np.array(embed_ques) @ np.array(ewhaDB_embed).T).argsort()[::-1]

    print( f" ==================={idx+1}==================== ")
    for topidx in range(3) :
        top = f"top{topidx+1}"
        topplus = f"top{topidx+1}plus"

        nowtest.loc[idx, top] = ewhaDB[sorted_idx[topidx]]

        response = segplus1.invoke({"context1": ewhaDB[sorted_idx[topidx]], "question": prompt})
        nowtest.loc[idx, topplus] = response.content
        print(response.content) # 확인용
        print("***")
# Out:
#  ===================1====================
# /tmp/ipykernel_448111/1955669393.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '{
#   "Evidence": "외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다.",
#   "Reasoning": "The given segment does not provide information about the number of credits awarded for acquiring a certain level of proficiency or certification in English and information. The segment discusses the maximum number of credits that can be earned through special examinations and the recognition of credits from other institutions or pre-admission courses. It does not mention anything specific to the question about the number of credits received for acquiring proficiency or certification in English and information. Therefore, the answer to the question cannot be determined from the given segment."
# }' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, topplus] = response.content
# {
#   "Evidence": "외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다.",
#   "Reasoning": "The given segment does not provide information about the number of credits awarded for acquiring a certain level of proficiency or certification in English and information. The segment discusses the maximum number of credits that can be earned through special examinations and the recognition of credits from other institutions or pre-admission courses. It does not mention anything specific to the question about the number of credits received for acquiring proficiency or certification in English and information. Therefore, the answer to the question cannot be determined from the given segment."
# }
# ***
# /tmp/ipykernel_448111/1955669393.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '{
#   "Evidence": [
#     "제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 1996.2)"
#   ],
#   "Reasoning": [
#     "The segment provides information about special examinations for acquiring credits for specific subjects in liberal arts and major foundation subjects. However, it does not specify the number of credits that can be recognized for obtaining a certain standard of ability or qualifications in English and information. Therefore, we cannot find a direct answer to the question in the segment."
#   ]
# }' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, topplus] = response.content
# {
#   "Evidence": [
#     "제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 1996.2)"
#   ],
#   "Reasoning": [
#     "The segment provides information about special examinations for acquiring credits for specific subjects in liberal arts and major foundation subjects. However, it does not specify the number of credits that can be recognized for obtaining a certain standard of ability or qualifications in English and information. Therefore, we cannot find a direct answer to the question in the segment."
#   ]
# }
# ***
# /tmp/ipykernel_448111/1955669393.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[
#   "Evidence": "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)",
#   "Reasoning": "The segment provided does not contain any information about the number of credits recognized for obtaining a certain level of ability or qualification in English and information. Therefore, none of the answer options (A), (B), (C), or (D) can be determined from this segment. The segment discusses re-admission after expulsion or dropping out, and there is no direct relation to the question regarding credits for English and information proficiency."
# ]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, topplus] = response.content
# [
#   "Evidence": "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)",
#   "Reasoning": "The segment provided does not contain any information about the number of credits recognized for obtaining a certain level of ability or qualification in English and information. Therefore, none of the answer options (A), (B), (C), or (D) can be determined from this segment. The segment discusses re-admission after expulsion or dropping out, and there is no direct relation to the question regarding credits for English and information proficiency."
# ]
# ***
#  ===================2====================
# {
#   "Evidence": "입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가한다. 다만, 제15조제1항의 단서의 경우나 특별전형, 기타 입학에 관하여 긴급한 필요가 있는 이화여자대학교 학칙 경우에는 대학장의 제청을 거치지 아니할 수 있다. (개정 2015. 2.6.)",
#   "Reasoning": "이 문장은 각 대학에 따른 학위의 종류에 대한 정보를 제공하지 않습니다. 대신, 입학 절차와 관련된 내용을 다루고 있으며, 학위의 종류와는 직접적인 연관이 없습니다. 이 문장은 학위 종류에 대한 질문에 대한 직접적인 답변을 제공하지 않으므로, 'Evidence'가 아닌 'Reasoning'으로 분류되어야 합니다."
# }
# ***
# {
#   "Evidence": "제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초과목 및 전공과목으로 구분한다.(개정 2011.4.15., 2016.2.16.) 제33조(교양과목) 교양과목의 종류와 학점은 총장이 따로 정한다. (개정 1996.2.15) 제34조(전공과목) 전공과목은 필수과목과 선택과목으로 구분하되, 각각 그 종류와 학점은 소속 대학장의 제청에 의하여 총장이 따로 정한다. (개정 1985.3.5)",
#   "Reasoning": "이 부분의 정보는 이화여자대학교의 교육과정에 대한 내용이며, 각 대학에 따른 학위의 종류에 대한 정보는 포함되어 있지 않습니다. 따라서, 주어진 질문과 직접적으로 관련된 내용은 없습니다."
# }
# ***
# {
#   "Evidence": [
#     "외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 1996.2.15., 2017.2.8.)",
#     "학점취득특별시험의 방법, 종류에 관한 세부 사항은 총장이 따로 정한다. (개정 2001.9.24)",
#     "다음 각 호의 경우에 취득한 학점은 총장의 승인을 얻어 졸업에 필요한 학점의 2분의 1의 범위 안에서 이를 본교에서 취득한 것으로 본다. (개정 2012.12.31.)",
#     "입학 전 본교 언어교육원에서 소정의 과정을 이수한 경우 입학 후 대학의 학점으로 인정할 수 있다. 학점인정대상자 및 범위"
#   ],
#   "Reasoning": [
#     "This segment provides information about various ways to earn credits towards a degree, including special exams, transfer credits from other schools, and credits for completing courses at the university's language education institute. However, it does not provide information about the types of degrees offered at different universities."
#   ]
# }
# ***
#  ===================3====================
# {
#   "Evidence": [
#     "제7장 교내전학제25조(전과) ① 학생이 소속 학부 또는 학과의 변경(이하 “전과”라 한다)을 원할 때에는 「고등교육법 시행령」 제29조제3항의 규정이 정하는 범위내에서 허가할 수 있다. (개정 1999.2.9., 2015.9.18.)",
#     "② 전과의 허가는 매 학년도말에 할 수 있다. (개정 1999.2.9., 2017.8.16.)",
#     "③ 전과의 기준․대상․절차 등 세부사항은 총장이 따로 정한다. (개정 1992.3.16)",
#     "제8장 휴학, 복학, 제적, 자퇴 및 재입학 (개정 2017.8.16.)",
#     "제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다.",
#     "② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28)",
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라"
#   ],
#   "Reasoning": [
#     "이 문서에서는 학부 또는 학과의 변경(전과)에 대한 규정이 언급되었지만, 학과명 변경 및 폐과된 학과가 어떤 규정에 의해 언제까지 존속하는지에 대한 구체적인 내용은 언급되지 않았습니다. 따라서, 주어진 옵션들 중 어떤 것이 정답인지 판단할 수 없습니다."
#   ]
# }
# ***
# [
#   'Evidence': '제6조(학과명칭 및 모집단위변경) ①학칙 제2조의 학과명칭 및 모집단위를 다음 각 호와 같이 변경한다.',
#   'Reasoning': '부칙에 학과명 변경 및 폐과된 학과는 학칙 제2조의 학과명칭 및 모집단위를 다음 각 호와 같이 변경한다는 내용이 있으므로, 현 학칙에 의하여 입학생이 졸업하는 연도까지 존속한다.'
# ]
# ***
# {
#   "Evidence": [
#     "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)"
#   ],
#   "Reasoning": "이 구절은 대학 재입학에 대한 조항을 언급하고 있지만, 학과명 변경 및 폐과된 학과가 어떻게 존속하는지에 대한 정보를 제공하지 않습니다. 이 구절은 학과 변경 및 폐과와 직접적으로 관련되지 않으므로, 질문과 관련된 직접적인 답변을 제공하지 않습니다."
# }
# ***
#  ===================4====================
# {
#   "Evidence": [
#     "학생은 매 학기초 소정 기일 내에 소정 절차에 의한 등록을 완료하여야 한다.",
#     "학생은 소정 기일 내에 그 학기에 수강할 교과목을 지도교수의 지도를받아 신청하여야 한다."
#   ],
#   "Reasoning": "제공된 세그먼트는 등록 기한과 수강 신청 기한에 대한 내용을 포함하고 있지만, 학생이 성적을 조회할 수 있는 시기에 대한 구체적인 언급은 없습니다. 따라서 주어진 정보를 바탕으로 학생이 학생 포털에서 본인의 성적을 조회할 수 있는 시기를 직접적으로 판단할 수는 없습니다."
# }
# ***
# [
#   "Evidence": "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 제출하여 총장의 허가를 얻어야 한다. (개정 2017.8.16.)",
#   "Reasoning": "The provided segment does not contain information about when students can check their grades on the student portal. The segment discusses regulations related to dropping out of school and readmission, but there is no mention of grade access or the student portal."
# ]
# ***
# [
#   "Evidence": "제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다. ② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28) ③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라",
#   "Reasoning": "The segment provided does not contain any information related to the question about when a student can check their grades on the student portal. The segment discusses regulations about leaving school for a period of time due to illness or other unavoidable circumstances, and the duration of such leave. It does not mention anything about checking grades or the time when students can access their grades on the student portal."
# ]
# ***
#  ===================5====================
# {
#   "Evidence": [
#     "이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다.",
#     "휴학기간이 만료된 자는 총장의 허가를 얻어 복학하여야 한다.",
#     "휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자"
#   ],
#   "Reasoning": [
#     "이 세그먼트는 이화여자대학교의 학칙에 관한 내용을 다루고 있으며, 특히 휴학, 복학, 제적 등과 관련된 규정을 설명하고 있습니다. 그러나 이 세그먼트에서는 이화여자대학교의 설립 목적에 대한 직접적인 언급은 없습니다. 따라서 이 세그먼트에서는 학칙 제1조(목적)에 따른 목적과 일치하지 않는 것을 판단할 수 없습니다."
#   ]
# }
# ***
# {
#   "Evidence": "학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입니까?",
#   "Reasoning": "이 질문은 이화여자대학교의 설립 목적과 관련된 것입니다. 설립 목적은 학칙 제1조에 명시되어 있으며, 기독교 정신을 바탕으로 교육, 지도여성 양성, 지역사회의 봉사, 학술의 응용방법 연구, 국제사회 협력, 국가와 인류사회의 발전에 공헌 등이 포함됩니다. 따라서, 이 질문은 이러한 목적 중 하나가 아닌 것을 찾는 것입니다."
# }
# ***
# {
#   "Evidence": "제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)",
#   "Reasoning": "이 섹션은 교육과정, 이수, 수료 및 졸업에 대한 내용을 다루고 있으며, 학점, 교과목, 이수 규정 등에 대한 정보가 포함되어 있습니다. 그러나 이 섹션은 이화여자대학교의 설립 목적에 대한 직접적인 정보를 제공하지 않습니다."
# }
# ***
#  ===================6====================
# {
#   "Evidence": [
#     "제29조 삭제 (1987.9.1)",
#     "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 제출하여 총장의 허가를 얻어야 한다. (개정 2017.8.16.)",
#     "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)",
#     "제31조의2(법령 등에 의한 재입학의 특례) 법령이나 법령에 근거한 처분 또는 권고 등에 의하여 재입학을 인정할 필요가 있는 경우에는 총장은 제31조의 규정에 불구하고 재입학을 허가할 수 있다. [본조신설 2005.6.17.]"
#   ],
#   "Reasoning": "The provided segment does not contain any information related to the address of the school mentioned in Article 3 of the regulations. The segment discusses the regulations for withdrawal and readmission, as well as a special provision for readmission based on laws or regulations. Therefore, none of the options (A) 서울특별시, (B) 서대문구, (C) 이화여대길 52, (D) 강남구 are relevant or can be categorized as evidence for the question."
# }
# ***
# {
#   "Evidence": [
#     "당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다. (개정 2012.12.31.)",
#     "학칙 제3조(주소) 이 대학의 주소는 서울특별시 서대문구 이화여대길 52로 한다. 다만, 교육 및 연구활동의 필요에 따라 다른 지역에 시설물을 설치하여 운영할 수 있다."
#   ],
#   "Reasoning": [
#     "The question asks for an element not included in the address of the main campus specified in Article 3 of the school regulations. Based on the provided segment, the address of the main campus is stated as 'Seoul Special City, Seodaemun-gu, Ewha-dae-gil 52'. Therefore, the element not included in the address is (D) Gangnam-gu."
#   ]
# }
# ***
# {
#   "Evidence": [
#     {
#       "text": "제8장 휴학, 복학, 제적, 자퇴 및 재입학 (개정 2017.8.16.)",
#       "type": "chapter_title"
#     },
#     {
#       "text": "① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가",
#       "type": "requirement"
#     },
#     {
#       "text": "③ 1회의 휴학기간은 1년 이내로 한다.",
#       "type": "duration"
#     }
#   ],
#   "Reasoning": [
#     "The segment provides information about the regulations for taking a leave of absence from the university. It specifies that a student can take a leave of absence for a maximum of one year at a time if they are unable to attend classes for three weeks or more due to illness or other unavoidable circumstances. This information is relevant to the question about the duration of a leave of absence."
#   ]
# }
# ***
#  ===================7====================
# {
#   "Evidence": [
#     "제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다.",
#     "② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28)",
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라"
#   ],
#   "Reasoning": "주어진 문단에서는 휴학에 대한 규정이 설명되어 있습니다. 질병이나 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 경우나 건강상의 이유로 정상적인 수업을 받을 수 없는 경우 휴학을 허가할 수 있습니다. 또한, 1회의 휴학기간은 1년 이내로 제한되어 있습니다. 그러나, 국가적 비상사태, 자연재해, 학생총회 요청, 대규모 학내 행사 등과 같은 이유로 임시휴업을 결정할 수 있는 근거에 대한 언급은 없습니다."
# }
# ***
# {
#   "Evidence": [
#     "④ 휴학기간은 통산하여 3년(건축학전공의 경우 4년, 의예과의 경우 3학기)을 초과할 수 없다. 다만, 임신, 출산 및 육아로 인한 휴학, 창업으로 인한 휴학은 2년 이내의 기간을, 군복무로 인한 휴학은 의무복무기간을 추가 휴학기간으로 허가할 수 있다. (개정 2013. 2.25., 2015.9.18., 2016.2.16.)",
#     "⑥ 재학 중인 자가 휴학을 하고자 하는 경우 학기개시일로부터 90일 이내에 휴학을 신청하여야 한다. (신설 2015.9.18.)"
#   ],
#   "Reasoning": "The provided segment is discussing the rules and regulations regarding student leave of absence in Ewha Womans University. It does not contain any information related to the question about the grounds for deciding on a temporary holiday in the school rules and regulations. Therefore, there is no evidence or reasoning in the segment that can be used to answer the question."
# }
# ***
# {
#   "Evidence": [
#     "제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다.",
#     "제27조(복학) ① 휴학기간이 만료된 자는 총장의 허가를 얻어 복학하여야 한다.",
#     "제28조(제적) 다음 각 호의 1에 해당하는 학생은 총장이 이를 제적한다.1. 휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자"
#   ],
#   "Reasoning": "이 세그먼트는 휴학, 복학, 제적에 관한 내용을 다루고 있으며, 휴학기간 만료 후 복학하지 않거나 정당한 이유 없이 휴학 연장을 신청하는 경우에 대한 규정을 언급하고 있습니다. 그러나 학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우에 대한 직접적인 언급은 없습니다."
# }
# ***
#  ===================8====================
# {
# "Evidence": "제23조(수업연한) ① 각 대학의 수업연한은 4년으로 한다. 다만, 엘텍공과대학의 건축학전공은 5년으로 하고, 의과대학은 6년으로 하되 의예과는 2년, 의학과는 4년으로 하며, 약학대학은 6년으로 하되 다른 학과 또는 학부 등에서 이수하는 기초․소양 교육은 2년으로 하고, 전공교육은 4년으로 한다.",
# "Reasoning": "건축학과는 건축학전공이 5년으로 되어 있고, 약학대학은 기초․소양 교육이 2년, 전공교육이 4년으로 되어 있어 총 6년이 소요됩니다. 따라서, '건축학과는 추가 설계 실습을 포함하므로 더 긴 연한이 필요하다'는 설명이 올바른 것입니다."
# }
# ***
# {
#   "Evidence": [
#     "의과대학 학생의 재학연한은 의예과는 4년, 의학과는 8년을 초과할 수 없고, 엘텍공과대학의 건축학전공 학생의 재학연한은 10년을 초과할 수 없다.",
#     "복수전공을 이수하는 학생, 「고등교육법 시행령」 제29조제2항의제6호 및 제7호에 해당하는 학생의 재학연한은 9년을 초과할 수 없다.",
#     "휴학기간은 재학연한에 산입하지 아니한다."
#   ],
#   "Reasoning": [
#     "학칙 제23조(수업연한)에 따르면, 의과대학 학생의 재학연한은 의예과는 4년, 의학과는 8년이며, 건축학전공 학생은 10년입니다. 복수전공을 이수하는 학생은 9년을 초과할 수 없습니다. 또한, 휴학기간은 재학연한에 포함되지 않습니다."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라 총장이 지정하는 학부, 학과 또는 전공에 있어서는 이를 1년으로 한다. (개정 1996.2.15)",
#     "④ 휴학기간은 통산하여 3년(건축학전공의 경우 4년, 의예과의 경우 3학기)을 초과할 수 없다. 다만, 임신, 출산 및 육아로 인한 휴학, 창업으로 인한 휴학은 2년 이내의 기간을, 군복무로 인한 휴학은 의무복무기간을 추가 휴학기간으로 허가할 수 있다. (개정 2013.2.25., 2015.9.18., 2016.2.16.)"
#   ],
#   "Reasoning": [
#     "The given segment provides information on the duration of a leave of absence for students at Ewha Womans University. The segment specifies that the duration of a leave of absence for students in the School of Architecture is 4 years, while for students in the College of Medicine, the duration is 3 semesters. This information is relevant to the question about the duration of the curriculum in the School of Architecture and College of Pharmacy."
#   ]
# }
# ***
#  ===================9====================
# {
#   "Evidence": [
#     "④ 휴학기간은 통산하여 3년(건축학전공의 경우 4년, 의예과의 경우 3학기)을 초과할 수 없다. 다만, 임신, 출산 및 육아로 인한 휴학, 창업으로 인한 휴학은 2년 이내의 기간을, 군복무로 인한 휴학은 의무복무기간을 추가 휴학기간으로 허가할 수 있다. (개정 2013. 2.25., 2015.9.18., 2016.2.16.)"
#   ],
#   "Reasoning": [
#     "The question asks for a case that does not exceed the maximum extension period for a leave of absence, as defined in Article 26 of the School Regulations. The evidence provided specifies that the maximum extension period for a leave of absence is 3 years (4 years for architecture majors and 3 semesters for medical students), but it also lists exceptions: pregnancy, childbirth, and childcare leave for up to 2 years, entrepreneurship leave for up to 2 years, and military service leave for the duration of the mandatory military service period. Therefore, the options (A), (B), and (C) are not cases that exceed the maximum extension period for a leave of absence, as they are covered by the exceptions. On the other hand, the option (D) (overseas volunteer service leave for 3 years) and the option (E) (extended leave due to a serious illness, at the discretion of the president) could potentially exceed the maximum extension period, as they are not specified as exceptions in the provided evidence. However, without additional information or context, it is not possible to definitively determine which option is not a case that exceeds the maximum extension period for a leave of absence."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)제7장 교내전학제25조(전과) ① 학생이 소속 학부 또는 학과의 변경(이하 “전과”라 한다)을 원할 때에는 「고등교육법 시행령」 제29조제3항의 규정이 정하는 범위내에서 허가할 수 있다. (개정 1999.2.9., 2015.9.18.)",
#     "② 전과의 허가는 매 학년도말에 할 수 있다. (개정 1999.2.9., 2017.8.16.)",
#     "③ 전과의 기준․대상․절차 등 세부사항은 총장이 따로 정한다. (개정 1992.3.16)제8장 휴학, 복학, 제적, 자퇴 및 재입학 (개정 2017.8.16.)제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가",
#     "를 얻어 휴학할 수 있다. ② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28)",
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라"
#   ],
#   "Reasoning": [
#     "이 내용에서는 휴학의 최대 연장 가능 기간에 대한 구체적인 규정이 언급되지 않았으므로, 주어진 선택지 중 어느 것도 해당되지 않습니다. 이 내용에서는 휴학의 최대 연장 가능 기간에 대한 규정이 언급되지 않았으므로, 주어진 선택지 중 어느 것도 해당되지 않습니다. 이 내용에서는 휴학의 최대 연장 가능 기간에 대한 규정이 언급되지 않았으므로, 주어진 선택지 중 어느 것도 해당되지 않습니다. 이 내용에서는 휴학의 최대 연장 가능 기간에 대한 규정이 언급되지 않았으므로, 주어진 선택지 중 어느 것도 해당되지 않습니다. 이 내용에서는 휴학의 최대 연장 가능 기간에 대한 규정이 언급되지 않았으므로, 주어진 선택지 중 어느 것도 해당되지 않습니다."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다.",
#     "제26조(휴학) ① 일반휴학 \u2026 \n\n(2) 휴학기간은 통산 2년 이내로 한다. 다만, 여성의 경우 임신 및 육아로 인한 휴학은 2년 이내로 한다.",
#     "제26조(휴학) ④ 휴학의 최대 연장 가능 기간은 통산 2년 이내로 한다. 다만, 여성의 경우 임신 및 육아로 인한 휴학은 2년 이내로 한다.",
#     "제26조(휴학) ⑤ 군복무로 인한 휴학기간은 통산 휴학기간에 산입하지 않는다."
#   ],
#   "Reasoning": "주어진 문맥에서, 학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우는 '군복무로 인한 휴학'입니다. 군복무로 인한 휴학기간은 통산 휴학기간에 산입하지 않으므로, 휴학의 최대 연장 가능 기간인 2년을 초과할 수 있습니다. 임신 및 육아로 인한 휴학, 창업으로 인한 휴학, 해외 봉사로 인한 휴학은 모두 최대 연장 가능 기간이 2년 이내로 제한되어 있으며, 중대한 질병으로 인한 휴학은 총장의 판단에 따라 연장 가능하므로 최대 연장 가능 기간이 초과되지 않을 수 있습니다."
# ***
#  ===================10====================
# "Evidence": ["제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초과목 및 전공과목으로 구분한다.", "제33조(교양과목) 교양과목의 종류와 학점은 총장이 따로 정한다.", "제34조(전공과목) 전공과목은 필수과목과 선택과목으로 구분하되, 각각 그 종류와 학점은 소속 대학장의 제청에 의하여 총장이 따로 정한다.", "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으", "제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다."]
# "Reasoning": ["이 세그먼트는 이화여자대학교의 교육과정에 대한 내용을 다루고 있으며, 교양의 종류와 학점, 전공과목의 종류와 학점 등에 대한 언급이 있습니다. 그러나, 질문에서 요구하는 복수전공 이수자가 요구되는 추가 조건에 대한 내용은 포함되어 있지 않습니다."]
# ***
# {
#   "Evidence": [
#     "복수전공을 이수하는 학생, \"고등교육법 시행령\" 제29조제2항의제6호 및 제7호에 해당하는 학생의 재학연한은 9년을 초과할 수 없다. (개정 2014.11.21)",
#     "제5조의 규정에 의하여 편입학한 학생의 재학연한은 잔여수업연한의 2배를 초과할 수 없다. 다만, 이 경우 복수전공을 이수하는 학생은 잔여수업연한의 2배에 1년을 더한 연한을 초과할 수 없다. (개정 2014.11.21)"
#   ],
#   "Reasoning": [
#     "복수전공 이수자의 추가 조건에 대한 직접적인 언급은 없지만, 학칙 제50조(졸업)에서는 복수전공을 이수하는 학생의 재학연한을 9년으로 제한하고 있습니다. 이는 복수전공을 이수하기 위해서는 일정 기간 내에 졸업을 해야 함을 의미합니다. 또한, 편입학한 학생의 경우에도 복수전공을 이수하는 경우 재학연한을 1년 더 연장할 수 있다는 내용이 있습니다. 이는 복수전공 이수자가 편입학한 경우, 일반적인 경우보다 더 긴 기간이 필요할 수 있음을 시사합니다. 따라서, 추가 조건으로는 졸업요건 학점 충족, 전공별 종합시험 합격, 총 평균성적 3.0 이상 등의 조건이 필요할 수 있을 것으로 예상됩니다."
#   ]
# }
# ***
# {
#   "Evidence": "제32조(교과목) ① 대학원에서는 석사학위과정과 박사학위과정 및 석박사통합과정에 필요한 교과목을 다음 각 호와 같이 설치한다. 1. 공통교과목: 대학원 교과과정 운영에 필요한 교과목으로 한다. 2. 전공교과목: 전공분야의 전문지식을 습득하고 연구능력을 배양하기 위한 교과목으로 한다. 3. 선택교과목: 전공분야 외의 지식과 소양을 함양하기 위한 교과목으로 한다. ② 공통교과목에는 다음 각 호와 같은 과목을 포함하여야 한다. 1. 연구윤리 2. 연구방법론 3. 외국어 4. 기타 대학원장이 필요하다고 인정하는 과목 ③ 전공교과목 및 선택교과목의 구체적인 명칭과 내용은 각 대학원별 학칙으로 정한다. ④ 교과목의 수업은 세미나, 토론, 발표, 실험·실습, 그 밖의 방법으로 운영할 수 있다. ⑤ 교과목의 학점은 150시간 이상의 수업량을 기준으로 3학점으로 한다. 다만, 실험·실습, 현장실습, 그 밖의 방법에 의한 교과목의 학점은 대학원별로 따로 정할 수 있다. ⑥ 교과목의 이수학점은 4.0 만점 기준으로 3.0 이상으로 한다. 다만, 연구윤리 교과목은 P/NP(Pass/Non-Pass)로 평가한다. ⑦ 기타 교과목 운영에 필요한 사항은 대학원별로 따로 정한다.",
#   "Reasoning": "이 세그먼트는 대학원 교과목과 관련된 내용을 다루고 있으며, 공통교과목, 전공교과목, 선택교과목에 대한 설명과 수업 방식, 학점 기준 등이 포함되어 있습니다. 그러나 이 세그먼트에서는 복수전공 이수자가 요구되는 추가 조건에 대한 구체적인 언급은 없습니다. 따라서 이 세그먼트는 질문에 직접적인 답변을 제공하지는 않지만, 추가 조건을 이해하는 데 도움이 될 수 있는 관련 정보를 포함하고 있습니다."
# }
# ***
#  ===================11====================
# {
#   "Evidence": [
#     "학칙 제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다.",
#     "휴학기간이 만료된 자는 총장의 허가를 얻어 복학하여야 한다.",
#     "휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자",
#     "성적이 불량한 자"
#   ],
#   "Reasoning": [
#     "The question is asking for the cases where a student's grade will not be processed as F based on the school regulations. The evidence contains information about the regulations for extending leave, re-enrolling, dropping out, and poor academic performance. These details may be relevant to understanding the conditions under which a grade of F would or would not be assigned."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 제출하여 총장의 허가를 얻어야 한다.",
#     "재입학은 1회에 한하여 할 수 있다. 다만, 제28조제4호에 의하여 제적된 자는 제적된 날부터 1년이 경과한 후 재입학할 수 있다."
#   ],
#   "Reasoning": "The provided segment contains information about leaving the school (자퇴) and re-entering the school (재입학), but it does not directly address the question about what circumstances do not result in an F grade according to the school regulations. The segment does not provide any specific details about the criteria for receiving an F grade."
# }
# ***
# {
#   "Evidence": [
#     "⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)",
#     "제7장 교내전학제25조(전과) ① 학생이 소속 학부 또는 학과의 변경(이하 “전과”라 한다)을 원할 때에는 「고등교육법 시행령」 제29조제3항의 규정이 정하는 범위내에서 허가할 수 있다. (개정 1999.2.9., 2015.9.18.)② 전과의 허가는 매 학년도말에 할 수 있다. (개정 1999.2.9., 2017.8.16.)③ 전과의 기준․대상․절차 등 세부사항은 총장이 따로 정한다. (개정 1992.3.16)",
#     "제8장 휴학, 복학, 제적, 자퇴 및 재입학 (개정 2017.8.16.)제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다. ② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28) ③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라",
#     "성적이 F로 처리되지 않는 경우"
#   ],
#   "Reasoning": [
#     "휴학기간, 전과, 휴학, 복학, 제적, 자퇴 및 재입학에 대한 규정이 언급됨.",
#     "성적과 관련된 구체적인 내용은 언급되지 않음.",
#     "휴학에 대한 규정이 언급되었지만, 성적과 직접적인 연관성은 없음.",
#     "성적과 관련된 구체적인 내용이 언급되지 않아 질문에 대한 답변을 직접적으로 제공하지 않음."
#   ]
# }
# ***
#  ===================12====================
# "Evidence": ["제6장 수업연한 및 재학연한 (개정 2014.11.21)제23조(수업연한) ① 각 대학의 수업연한은 4년으로 한다. 다만, 엘텍공과대학의 건축학전공은 5년으로 하고, 의과대학은 6년으로 하되 의예과는 2년, 의학과는 4년으로 하며, 약학대학은 6년으로 하되 다른 학과 또는 학부 등에서 이수하는 기초․소양 교육은 2년으로 하고, 전공교육은 4년으로 한다. (개정 2014.11.21., 2017.2.8.)"],
# "Reasoning": ["이 증거는 학칙 제47조(전공)에서 융합전공의 설계 기준에 대한 질문과 직접적인 연관이 없습니다. 이 증거는 각 대학의 수업연한과 의과대학, 약학대학 등의 예외사항에 대한 내용입니다. 융합전공의 설계 기준과는 직접적인 연관이 없으므로, 이 증거는 질문에 대한 답을 찾는 데 도움이 되지 않습니다."]
# ***
# {
#   "Evidence": [
#     "제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)",
#     "제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초과목 및 전공과목으로 구분한다.",
#     "제33조(교양과목) 교양과목의 종류와 학점은 총장이 따로 정한다.",
#     "제34조(전공과목) 전공과목은 필수과목과 선택과목으로 구분하되, 각",
#     "각 그 종류와 학점은 소속 대학장의 제청에 의하여 총장이 따로 정한다.",
#     "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으로 한다.",
#     "이화여자대학교 학칙",
#     "제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며, 그 학점수는 12학점을 초과할 수 없다."
#   ],
#   "Reasoning": "The provided segment contains information about the curriculum, courses, and credits at Ewha Womans University. It mentions that courses are divided into general education, major foundation, and major courses, and that the number and credits of general education courses are determined by the president. The segment also states that major courses are divided into required and elective courses, with their types and credits determined by the dean of the respective college. Additionally, it specifies that the unit of curriculum completion is a credit, with one credit equivalent to 15 hours of class per semester. The segment does not provide information about the design criteria for fusion majors in Article 47 of the school regulations."
# }
# ***
# {
#   "Evidence": [
#     "② 의과대학 학생의 재학연한은 의예과는 4년, 의학과는 8년을 초과할 수 없고, 엘텍공과대학의 건축학전공 학생의 재학연한은 10년을 초과할 수 없다. (개정 2014.11.21.,이화여자대학교 학칙2017.2.8.)",
#     "③ 복수전공을 이수하는 학생, 「고등교육법 시행령」 제29조제2항의제6호 및 제7호에 해당하는 학생의 재학연한은 9년을 초과할 수 없다. (개정 2014.11.21)",
#     "④ 재입학한 학생의 재학연한은 재입학전 재학기간을 산입하여 제1항부터 제3항까지의 해당 기간을 초과할 수 없다. (개정 2014.11.21., 2017.8.16.)",
#     "⑤ 제15조의 규정에 의하여 편입학한 학생의 재학연한은 잔여수업연한의 2배를 초과할 수 없다. 다만, 이 경우 복수전공을 이수하는 학생은 잔여수업연한의 2배에 1년을 더한 연한을 초과할 수 없다. (개정 2014.11.21)"
#   ],
#   "Reasoning": "The provided segment discusses the maximum duration of study for various types of students, including those in the medical school, those majoring in architecture, those pursuing double majors, re-admitted students, and those who have transferred. However, it does not provide any information about the design criteria for a convergence major, as the question asks. The answers provided in the question are not related to the segment."
# }
# ***
#  ===================13====================
# {
#   "Evidence": [
#     "제28조(제적) 다음 각 호의 1에 해당하는 학생은 총장이 이를 제적한다.1. 휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자 2. 삭제 (2017.8.16.) 3. 수업료 기타 납입금을 소정 기일 내에 납입하지 아니한 자 4. 성적이 불량한 자 (개정 2002.11.8) 5. 재학연한 내에 본교 소정 전과정을 이수하지 못한 자 (개정 2014.11.21.) 6. 타교에 입학한 자",
#     "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한"
#   ],
#   "Reasoning": [
#     "학칙 제28조(제적)에 따라 제적되는 사유로는 휴학기간 경과 후 복학하지 않은 경우, 등록금을 기한 내 납부하지 않은 경우, 성적이 불량한 경우, 재학 연한 내에 졸업 요건을 충족하지 못한 경우, 타교에 입학한 경우 등이 있습니다. 그러나 이 중 휴학 기간이 만료된 경우와 자퇴한 경우는 제적 사유로 포함되지 않습니다. 따라서 정답은 (A) 등록금을 기한 내 납부하지 않은 경우, (B) 연속 2회 학사경고를 받은 경우, (C) 재학 연한 내 졸업 요건을 충족하지 못한 경우, (D) 타교에 입학한 경우, (E) 휴학 기간이 만료된 경우 중 (E) 휴학 기간이 만료된 경우입니다."
#   ]
# }
# ***
# [
#   "Evidence": "제28조(제적) 다음 각 호의 1에 해당하는 자는 제적한다. <개정 2008.8.19, 2017.8.16.> 1. 등록금을 기한 내에 납부하지 아니한 자 2. 연속하여 2회 이상 수업 연한 내에 졸업에 필요한 과목의 학점을 취득하지 못한 자 3. 휴학 기간이 만료된 후에도 복학하지 아니한 자 4. 타교에 입학한 자",
#   "Reasoning": "해당 증거에 따르면, 학칙 제28조(제적)에 따라 제적 사유로 포함되지 않는 경우는 '등록금을 기한 내 납부하지 않은 경우' (A)와 '연속 2회 학사경고를 받은 경우' (B)입니다. 또한, '재학 연한 내 졸업 요건을 충족하지 못한 경우' (C)와 '타교에 입학한 경우' (D)도 제적 사유로 명시되어 있습니다. 하지만, '휴학 기간이 만료된 경우' (E)는 제적 사유로 명시되어 있지 않습니다."
# ]
# ***
# {
#   "Evidence": [
#     "제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다.",
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라"
#   ],
#   "Reasoning": "The provided segment does not directly mention the specific question about the reasons for dismissal according to Article 28 of the school regulations. However, it does provide information about the rules for taking a leave of absence. This information might be relevant if the question involves dismissal due to non-compliance with leave of absence regulations. The evidence does not provide a direct answer to the question, but it can be used in conjunction with information from other segments to answer the question."
# }
# ***
#  ===================14====================
# {
#   "Evidence": [
#     "학칙 제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다.",
#     "② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28)",
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라"
#   ],
#   "Reasoning": [
#     "The segment provided does not contain information about the regular holidays specified in Article 12 of the school regulations. The segment discusses the rules and procedures for taking a leave of absence from school. It mentions that a student can take a leave of absence for a maximum of one year due to illness or other unavoidable circumstances, and the total length of leave of absence shall not exceed one year. However, it does not specify what days are considered regular holidays or which of the given options (A) to (E) are included in this category."
#   ]
# }
# ***
# {
#   "Evidence": "이화여자대학교 학칙 제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다. (신설 2015.9.18.)",
#   "Reasoning": "이화여자대학교 학칙 제12조(휴업일)에서 명시된 정기휴업일에 대한 질문이므로, 해당 학칙의 내용을 참고하여 정기휴업일에 해당하는 정보를 파악해야 합니다. 그러나, 제공된 세그먼트에서는 학칙 제12조(휴업일)에 대한 내용이 나오지 않으므로, 주어진 질문과 직접적으로 관련된 내용은 없습니다."
# }
# ***
# {
#   "Evidence": [
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라 총장이 지정하는 학부, 학과 또는 전공에 있어서는 이를 1년으로 한다. (개정 1996.2.15)",
#     "④ 휴학기간은 통산하여 3년(건축학전공의 경우 4년, 의예과의 경우 3학기)을 초과할 수 없다. 다만, 임신, 출산 및 육아로 인한 휴학, 창업으로 인한 휴학은 2년 이내의 기간을, 군복무로 인한 휴학은 의무복무기간을 추가 휴학기간으로 허가할 수 있다. (개정 2013. 2.25., 2015.9.18., 2016.2.16.)"
#   ],
#   "Reasoning": "The provided segment discusses rules and regulations regarding academic leave of absence, including the duration of leave and specific exceptions. However, it does not provide information about regular holidays as specified in the question. The answer to the question cannot be found in this segment."
# }
# ***
#  ===================15====================
# Evidence: "① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가 를 얻어 휴학할 수 있다."
# Reasoning: 학칙 제26조에 따르면 질병이나 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 학생은 휴학을 신청할 수 있습니다. 그러나 질문에서 언급된 조건들(신입생 첫 학기, 중대한 질병으로 3주 이상 수업 불가능한 경우, 편입학 첫 학기, 군 복무로 인한 경우, 재입학 첫 학기)은 학칙 제26조에서 명시적으로 언급되지 않았으므로, 이 조건들에 해당하는 학생들은 휴학을 신청할 수 있는지 여부를 결정할 수 없습니다.
# ***
# {
#   "Evidence": [
#     "이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다.",
#     "제27조(복학) ① 휴학기간이 만료된 자는 총장의 허가를 얻어 복학하여야 한다."
#   ],
#   "Reasoning": "질문은 학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건에 대해 묻고 있습니다. 제공된 세그먼트에서는 제26조에 대한 구체적인 내용을 찾을 수 없지만, 제28조에서 휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자는 제적된다는 내용이 언급됩니다. 이는 휴학기간 만료 후 복학하지 않는 경우 제적될 수 있음을 시사합니다. 따라서, 휴학을 신청할 수 없는 학생의 조건은 휴학기간이 만료된 후에도 복학하지 않는 것일 수 있습니다."
# }
# ***
# {
#   "Evidence": [
#     "⑦ 신입생, 편입학한 학생, 재입학한 학생은 중대한 질병 및 그에 준하는 사유를 제외하고는 입학 후 첫 학기를 휴학할 수 없다. (신설 2015.9.18.)"
#   ],
#   "Reasoning": "The question asks for the condition under which a student cannot apply for a leave of absence according to Article 26 of the school regulations. The evidence provided indicates that a student who is a new student, a student who has transferred, or a student who has re-entered the school cannot take a leave of absence in the first semester after enrollment, except in cases of serious illness or similar reasons."
# }
# ***
#  ===================16====================
# {
#   "Evidence": "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으 로 한다. (개정 1999.2.9)",
#   "Reasoning": "This evidence directly answers the question. According to the regulation, one credit is given for classes that last 15 hours or more in one semester. Therefore, the minimum standard for classes that qualify for one credit is 15 hours or more. The correct answer is (C) 15시간 이상."
# }
# ***
# {
#   "Evidence": "학칙 제35조(학점)에 따르면, 한 학점으로 인정되는 수업 시간의 최소 기준은 15시간 이상입니다.",
#   "Reasoning": "학칙 제35조는 각 수업의 학점과 수업 시간의 최소 기준을 규정하는 조항입니다. 이 조항에 따르면, 한 학점으로 인정되는 수업 시간의 최소 기준은 15시간 이상입니다. 따라서, 주어진 선택지 중에서 (C) 15시간 이상이 학칙 제35조에 따라 한 학점으로 인정되는 수업 시간의 최소 기준입니다."
# }
# ***
# {
#   "Evidence": "학점취득특별시험의 방법, 종류에 관한 세부 사항은 총장이 따로 정한다. (개정 2001.9.24)제35조의3(학점의 인정) ① 다음 각 호의 경우에 취득한 학점은 총장의 승인을 얻어 졸업에 필요한 학점의 2분의 1의 범위 안에서 이를 본교에서 취득한 것으로 본다. (개정 2012.12.31.)1. 재학 중 국내외의 다른 학교에서 학점을 취득한 경우2. 입학 전 국내외의 고등학교와 「고등교육법」 제2조 각 호의 학교에서 대학교육과정에 상응하는 교과목을 이수한 경우② 학점의 인정범위 등 제1항의 시행에 필요한 사항은 총장이 따로 정한다. (개정 1998.6.23)③ 삭제 (1998.6.23.)",
#   "Reasoning": "The provided segment does not directly state the minimum standard of teaching hours that constitute one credit under the regulations of Article 35 of the statutes. However, it does mention that details regarding methods and types of credit acquisition special examinations, as well as the recognition of credits and the range of such recognition, are determined by the president. This implies that the specifics of credit hours may also be set by the president, but this information is not provided in the given segment."
# }
# ***
#  ===================17====================
# {
#   "Evidence": [
#     "제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초과목 및 전공과목으로 구분한다.(개정 2011.4.15., 2016.2.16.)",
#     "제33조(교양과목) 교양과목의 종류와 학점은 총장이 따로 정한다. (개정 1996.2.15)",
#     "제34조(전공과목) 전공과목은 필수과목과 선택과목으로 구분하되, 각각 그 종류와 학점은 소속 대학장의 제청에 의하여 총장이 따로 정한다. (개정 1985.3.5)",
#     "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으로 한다. (개정 1999.2.9)",
#     "이화여자대학교 학칙제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 1996.2"
#   ],
#   "Reasoning": "The given segment does not provide information about the founding spirit of Ewha Womans University or its educational ideology. It only provides information about the classification of courses, types of courses, and credits required for course completion. The question asks for an incorrect educational ideology based on the founding spirit of Ewha Womans University. The options provided are: (A) Strengthening academic competitiveness, (B) Harmony with Christian spirit, (C) Development of international leadership, (D) Cultivation of women leaders, (E) Establishment of a specific religious doctrine. Without information about the founding spirit and educational ideology of Ewha Womans University, it is impossible to determine which of the options is incorrect."
# }
# ***
# {
#   "Evidence": [
#     "입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다.",
#     "입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가한다. 다만, 제15조제1항의 단서의 경우나 특별전형, 기타 입학에 관하여 긴급한 필요가 있는 경우에는 대학장의 제청을 거치지 아니할 수 있다.",
#     "총장은 입학자격을 갖추지 못하였거나 제1항의 입학사정에 사용된 전형자료에 허위나 부정이 있다고 판단되는 경우에는 교무회의의 의결을 거쳐 합격취소 및 입학허가취소를 할 수 있다.",
#     "제2항의 합격취소 및 입학허가취소의 사유와 절차에 관한 사항은 총장이 따로 정한다."
#   ],
#   "Reasoning": [
#     "The provided segment does not directly address the founding spirit of Ewha Womans University or its educational ideals. However, it does provide information on the organizational structure of admissions and the process for granting admission.",
#     "The segment mentions that the details regarding the organization and operation of admissions officers are determined by the president, and that admission (including transfer and re-admission) is granted by the president with the recommendation of the dean. It also states that the president can cancel admission if the applicant does not meet the requirements or if there is fraud or irregularities in the application materials.",
#     "While the segment does not directly answer the question about the founding spirit of Ewha Womans University, it does provide some insight into the university's admissions process."
#   ]
# }
# ***
# [
#   "Evidence": "학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 않은 것은?",
#   "Reasoning": "학칙은 이화여자대학교의 학사 운영 규정을 다루는 문서이며, 설립 정신이나 교육 이념에 대한 정보를 담고 있지 않습니다. 따라서 학칙의 내용을 통해 학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 않은 것을 파악할 수 없습니다. 이 질문에 대한 답변은 이화여자대학교의 설립 정신이나 교육 이념에 대한 추가 정보를 찾아야 합니다."
# ]
# ***
#  ===================18====================
# {
#   "Evidence": [
#     "입학정원의 일부를 통합 모집할 수 있다.",
#     "총장이 세부 사항을 따로 정한다."
#   ],
#   "Reasoning": [
#     "The question asks for the condition that is not correct according to the school regulations. The evidence provided shows that the school allows for the integration of some of the admission quota and that the president can set the details of this integration. Therefore, options (A) and (D) are correct. Option (B) is not mentioned in the provided segment, so it cannot be confirmed. Option (C) is also not mentioned, so it cannot be confirmed. However, since the question asks for the condition that is not correct, the correct answer is (B), as it is not mentioned in the segment and cannot be confirmed to be correct or not.",
#     "The provided segment does not contain enough information to answer the question directly. However, it does provide some useful details that can be combined with information from other segments to answer the question. The segment mentions that the admission quota can be partially integrated and that the president can set the details of this integration. These details can be used to narrow down the possible answers to the question when combined with information from other segments."
#   ]
# }
# ***
# {
#   "Evidence": "제5조(입학정원) ① 본교의 입학정원은 법령이 정하는 범위 안에서 다음과 같이 한다. <개정 2015.2.6., 2016.1.22., 2017.8.16., 2019.8.13.>",
#   "Reasoning": "이 문장은 학칙 제5조에 대한 내용이지만, 모집단위별 통합 모집이 가능한 조건에 대한 정보는 포함되어 있지 않습니다. 따라서 이 문장은 질문에 대한 직접적인 답변이나 추가적인 이해를 제공하지 않습니다."
# }
# ***
# {
#   "Evidence": [
#     "⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)",
#     "② 전과의 허가는 매 학년도말에 할 수 있다. (개정 1999.2.9., 2017.8.16.)",
#     "③ 전과의 기준․대상․절차 등 세부사항은 총장이 따로 정한다. (개정 1992.3.16)",
#     "② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28)",
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라"
#   ],
#   "Reasoning": [
#     "The provided segment does not contain information related to the question about the conditions for integrated recruitment according to Article 5 (Admission Quotas) of the school regulations. Therefore, it does not provide any evidence or reasoning for the question."
#   ]
# }
# ***
#  ===================19====================
# {
#   "Evidence": ["엘텍공과대학의 건축학전공은 5년으로", "의과대학은 6년으로 하되 의예과는 2년, 의학과는 4년으로", "약학대학은 6년으로 하되 다른 학과 또는 학부 등에서 이수하는 기초․소양 교육은 2년으로 하고, 전공교육은 4년으로 한다."],
#   "Reasoning": "학칙 제23조(수업연한)에 따라 수업 연한이 4년으로 규정되지 않은 학과는 엘텍공과대학 건축학전공, 의과대학 의예과, 약학대학입니다. 따라서, 주어진 선택지 중에서 수업 연한이 4년으로 규정되지 않은 학과는 (A) 인문과학대학, (B) 경영대학, (E) 사범대학입니다."
# }
# ***
# {
#   "Evidence": [
#     "없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의학과는 8년을 초과할 수 없고, 엘텍공과대학의 건축학전공 학생의 재학연한은 10년을 초과할 수 없다. (개정 2014.11.21.,이화여자대학교 학칙2017.2.8.)",
#     "④ 재입학한 학생의 재학연한은 재입학전 재학기간을 산입하여 제1항부터 제3항까지의 해당 기간을 초과할 수 없다. (개정 2014.11.21., 2017.8.16.)"
#   ],
#   "Reasoning": "이 문서는 이화여자대학교의 학칙 중 일부로, 재학연한에 대한 규정을 설명하고 있습니다. 특히, 의과대학 학생의 재학연한이 4년, 의학과는 8년, 엘텍공과대학의 건축학전공 학생은 10년으로 규정되어 있습니다. 이 정보는 질문에서 언급된 학과의 수업연한과 관련이 있습니다. 그러나, 질문에서 언급된 학과 중 수업연한이 4년으로 규정되지 않은 학과는 문서에 명시되어 있지 않습니다. 따라서, 주어진 정보로는 질문에 대한 직접적인 답변을 제공하지 않습니다."
# }
# ***
# {
#   "Evidence": "제23조(수업연한) ① 이 학교의 수업연한은 4년으로 한다. 다만, 건축학전공은 5년으로 한다. (개정 1992.3.16, 2017.8.16.)",
#   "Reasoning": "The question asks for a department that does not have a 4-year class period as per the Articles of Association. The evidence provided states that the class period is 4 years for the entire school, except for the Architecture major, which has a class period of 5 years. Therefore, the Architecture major is the department that does not have a 4-year class period, so the answer is (C) Pharmaceutical College."
# }
# ***
#  ===================20====================
# [
#   "Evidence": "학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한 학기에 취득할 수 있는 최대 학점은?",
#   "Reasoning": "학칙 제45조(취득학점)에 대한 정보를 찾기 위해 주어진 문서를 살펴보겠습니다. 이 조항은 학생의 평균 성적에 따라 한 학기에 취득할 수 있는 최대 학점에 대해 언급하고 있습니다. 문서에서는 '학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한 학기에 취득할 수 있는 최대 학점은?'이라는 질문에 대한 직접적인 언급이 없습니다. 그러나 다른 조항에서는 학생이 한 학기에 취득할 수 있는 최대 학점에 대한 제한을 언급하고 있습니다. 예를 들어, '학칙 제35조(학점의 인정)에 따라 한 학기에 취득할 수 있는 최대 학점은 21학점입니다.'라는 내용이 있습니다. 이 정보를 바탕으로, 학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한 학기에 취득할 수 있는 최대 학점은 21학점입니다."
# ]
# ***
# {
#   "Evidence": "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으로 한다. (개정 1999.2.9)",
#   "Reasoning": "The question asks for the maximum number of credits a student can earn in one semester based on their previous semester's average grade. However, the provided segment does not directly provide an answer to this question. It only mentions the definition of credits in terms of hours spent in class. To answer the question, we need to find the relevant information in the scholarship regarding the maximum credits a student can earn, which is not available in the given segment."
# }
# ***
# {
#   "Evidence": [
#     "제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한 학기에 취득할 수 있는 최대 학점은?"
#   ],
#   "Reasoning": [
#     "질문을 분석해보면, 학칙 제45조에 따라 직전 학기 평균성적이 3.75 이상인 학생이 한 학기에 취득할 수 있는 최대 학점을 묻는 것으로 보입니다. 하지만, 주어진 문서 세그먼트에는 해당 학칙에 대한 구체적인 언급이 없습니다. 따라서, 이 세그먼트만으로는 질문에 대한 직접적인 답을 찾을 수 없습니다. 다른 세그먼트에서 관련 정보를 찾아보아야 합니다."
#   ]
# }
# ***
#  ===================21====================
# {
#   "Evidence": [
#     "제28조(제적) 다음 각 호의 1에 해당하는 학생은 총장이 이를 제적한다.",
#     "1. 휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자",
#     "2. 삭제 (2017.8.16.)",
#     "3. 수업료 기타 납입금을 소정 기일 내에 납입하지 아니한 자",
#     "4. 성적이 불량한 자 (개정 2002.11.8)",
#     "5. 재학연한 내에 본교 소정 전과정을 이수하지 못한 자 (개정 2014.11.21.)",
#     "6. 타교에 입학한 자",
#     "7. 삭제 (2003.2.7)",
#     "8. 징계에 의하여 퇴학처분을 받은 자 (신설 2002.2.14)"
#   ],
#   "Reasoning": "The question asks for a case that is not a reason for expulsion according to the school regulation Article 28 (Expulsion). The evidence contains a list of reasons for expulsion as per the school regulation Article 28 (Expulsion). Among the options provided, only option (C) - applying for transfer to another major in the middle of the semester - is not included in the list of reasons for expulsion. Therefore, option (C) is the correct answer."
# }
# ***
# {
#   "Evidence": "제28조(제적): 1) 휴학 기간 종료 후 3주 이내에 복학하지 않은 경우, 2) 등록금을 납부하지 않은 경우, 3) 학사 경고를 3회 연속 받은 경우, 4) 재학 연한을 초과한 경우",
#   "Reasoning": "The question asks for a reason that is not a ground for dismissal according to Article 28 of the School Regulations. The evidence provided lists the grounds for dismissal, which include not returning to school within three weeks after the end of the leave period, not paying tuition fees, receiving three consecutive academic warnings, and exceeding the prescribed period of study. Therefore, the option that is not a ground for dismissal is C) Applying for a transfer in the middle of a semester, as it is not listed in the evidence."
# }
# ***
# {
#   "Evidence": [
#     "제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다.",
#     "제7장 휴학, 복학, 제적, 자퇴 및 재입학 (개정 2017.8.16.)",
#     "제28조(제적) ① 학생이 다음 각 호의 하나에 해당하는 때에는 제적한다. (개정 2014.11.21.)",
#     "1. 휴학 기간이 끝난 후 3주 이내에 복학하지 않은 자",
#     "2. 등록금을 납부하지 않은 자",
#     "3. 학사 경고를 3회 연속 받은 자",
#     "4. 재학 연한을 초과한 자",
#     "② 제1항에 의한 제적된 자는 당해 학년도 말까지 복학하지 않은 경우에는 제적된 것으로 본다."
#   ],
#   "Reasoning": "위 내용을 보면, 학칙 제28조(제적)에 따라 제적 사유에 포함되는 것은 다음과 같습니다: 1. 휴학 기간이 끝난 후 3주 이내에 복학하지 않은 자, 2. 등록금을 납부하지 않은 자, 3. 학사 경고를 3회 연속 받은 자, 4. 재학 연한을 초과한 자입니다. 따라서, 학칙 제28조(제적)에 따라 제적 사유에 포함되지 않는 것은 '학기 중간에 전과를 신청한 경우'입니다."
# ***
#  ===================22====================
# {
#   "Evidence": [
#     "제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가를 얻어 휴학할 수 있다.",
#     "제7장 교내전학제25조(전과) ① 학생이 소속 학부 또는 학과의 변경(이하 ‘전과’라 한다)을 원할 때에는 「고등교육법 시행령」 제29조제3항의 규정이 정하는 범위내에서 허가할 수 있다.",
#     "② 전과의 허가는 매 학년도말에 할 수 있다. (개정 1999.2.9., 2017.8.16.)"
#   ],
#   "Reasoning": [
#     "이 문서 조각은 학칙의 일부로, 학생들의 휴학, 전과, 학적 변동 등에 대한 규정을 다루고 있습니다. 질문은 학칙 제12조(휴업일)에서 정기 휴업일로 포함되지 않는 날을 찾는 것입니다. 문서 조각에는 정기 휴업일에 대한 직접적인 언급은 없지만, 제26조(휴학)와 제7장 교내전학제25조(전과)에 관련된 내용이 포함되어 있습니다."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다.",
#     "제27조(복학) ① 휴학기간이 만료된 자는 총장의 허가를 얻어 복학하여야 한다.",
#     "제28조(제적) 다음 각 호의 1에 해당하는 학생은 총장이 이를 제적한다. 1. 휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자",
#     "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한"
#   ],
#   "Reasoning": "The provided segment does not contain information about the regular holidays in Article 12 of the school regulations. The segment discusses regulations related to leave of absence, reinstatement, expulsion, and withdrawal from school. The segment does not provide any information about the regular holidays, such as the summer vacation, commencement day, the spring and fall breaks, weekends, national holidays, and the like. Therefore, none of the options (A) Summer Vacation, (B) Commencement Day, (C) Spring and Fall Breaks, (D) Weekends, (E) National Holidays are included in the regular holidays according to the school regulations."
# }
# ***
# {
#   "Evidence": "④ 휴학기간은 통산하여 3년(건축학전공의 경우 4년, 의예과의 경우 3학기)을 초과할 수 없다. 다만, 임신, 출산 및 육아로 인한 휴학, 창업으로 인한 휴학은 2년 이내의 기간을, 군복무로 인한 휴학은 의무복무기간을 추가 휴학기간으로 허가할 수 있다. (개정 2013. 2.25., 2015.9.18., 2016.2.16.)",
#   "Reasoning": "The question is asking for the regular holiday that is not included in the school regulations. The provided segment, however, does not provide information about regular holidays, but rather about the maximum duration of leave of absence. It seems that the question is not related to the provided segment and does not have any relevant evidence or reasoning."
# }
# ***
#  ===================23====================
# {
#   "Evidence": [
#     "제32조(교과과정)",
#     "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)",
#     "제31조의2(법령 등에 의한 재입학의 특례) 법령이나 법령에 근거한 처분 또는 권고 등에 의하여 재입학을 인정할 필요가 있는 경우에는 총장은 제31조의 규정에 불구하고 재입학을 허가할 수 있다. [본조신설 2005.6.17.]"
#   ],
#   "Reasoning": [
#     "해당 문서는 교육기관의 학칙으로 보입니다. 스크랜튼학부 자유전공 입학생의 졸업 요건과 직접적으로 관련된 내용은 없습니다. 질문에 대한 답변을 위해 다른 문서를 참고해야 할 것 같습니다.",
#     "제31조와 제31조의2에서는 제적된 학생에 대한 재입학 요건과 특례에 대해 언급하고 있습니다. 이는 졸업 요건과는 별개의 사항입니다.",
#     "주어진 질문과 관련된 정보를 찾기 위해서는 스크랜튼학부 자유전공의 구체적인 졸업 요건을 다루는 문서를 참고해야 할 것입니다."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초과목 및 전공과목으로 구분한다.",
#     "제33조(교양과목) 교양과목의 종류와 학점은 총장이 따로 정한다.",
#     "제34조(전공과목) 전공과목은 필수과목과 선택과목으로 구분하되, 각각 그 종류와 학점은 소속 대학장의 제청에 의하여 총장이 따로 정한다.",
#     "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으로 한다.",
#     "제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다."
#   ],
#   "Reasoning": [
#     "The provided segment outlines the categorization of courses at the university, the definition of credits, and a special provision for obtaining credits for specific courses through a special examination. However, it does not directly address the graduation requirements for Scranton School of Liberal Arts first-year students. To answer the question, we need to find information about the specific requirements for graduation for these students.",
#     "The question asks for the correct description of the graduation requirements for Scranton School of Liberal Arts first-year students according to Article 50 (Graduation) of the school regulations. We need to look for information related to the graduation requirements for this specific group of students in the segment."
#   ]
# }
# ***
# {
#   "Evidence": "제6장 수업연한 및 재학연한 (개정 2014.11.21)제23조(수업연한) ① 각 대학의 수업연한은 4년으로 한다. 다만, 엘텍공과대학의 건축학전공은 5년으로 하고, 의과대학은 6년으로 하되 의예과는 2년, 의학과는 4년으로 하며, 약학대학은 6년으로 하되 다른 학과 또는 학부 등에서 이수하는 기초․소양 교육은 2년으로 하고, 전공교육은 4년으로 한다. (개정 2014.11.21., 2017.2.8.)",
#   "Reasoning": "해당 문장은 각 대학의 수업연한과 의과대학, 약학대학 등의 수업연한에 대한 내용입니다. 스크랜튼학부 자유전공 입학생의 졸업 요건과는 직접적인 연관이 없습니다."
# }
# ***
#  ===================24====================
# {
#   "Evidence": [
#     "의과대학 학생의 재학연한은 의예과는 4년, 의학과는 8년을 초과할 수 없고, 엘텍공과대학의 건축학전공 학생의 재학연한은 10년을 초과할 수 없다."
#   ],
#   "Reasoning": [
#     "이 정보는 의과대학 의학과 학생이 한 학기에 취득할 수 있는 최대 학점에 대한 직접적인 언급이 없습니다. 대신, 의과대학 의학과 학생의 재학연한에 대한 제한을 언급하고 있습니다. 따라서 이 정보는 질문에 대한 답을 찾는 데 도움이 되지 않습니다."
#   ]
# }
# ***
# {
#   "Evidence": "제23조(수업연한) ① 각 대학의 수업연한은 4년으로 한다. 다만, 엘텍공과대학의 건축학전공은 5년으로 하고, 의과대학은 6년으로 하되 의예과는 2년, 의학과는 4년으로 하며, 약학대학은 6년으로 하되 다른 학과 또는 학부 등에서 이수하는 기초․소양 교육은 2년으로 하고, 전공교육은 4년으로 한다. (개정 2014.11.21., 2017.2.8.)",
#   "Reasoning": "의과대학 의학과 학생의 수업연한은 4년입니다. 따라서, 취득할 수 있는 최대 학점은 해당 수업연한 내에서 결정됩니다. 학칙 제45조(취득학점)에 따르면, 한 학기에 취득할 수 있는 최대 학점은 18학점입니다. 따라서, 정답은 (A) 18학점입니다."
# }
# ***
# {
#   "Evidence": "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으로 한다. (개정 1999.2.9)",
#   "Reasoning": "학칙 제45조(취득학점)에 따라 한 학기에 취득할 수 있는 최대 학점에 대한 구체적인 언급이 없으므로, 주어진 정보를 바탕으로 직접적인 답변을 제공할 수 없습니다. 그러나 제35조에서는 1학기간 15시간 이상의 수업을 1학점으로 한다는 규정이 있으므로, 이를 바탕으로 학점 취득에 대한 이해를 높일 수 있습니다."
# }
# ***
#  ===================25====================
# {
#   "Evidence": "제59조(징계) ① 총장은 학생이 다음 각 호의 1에 해당하는 행위를 하였을 때에는 징계한다.\n1. 품위를 손상하는 행위를 한 자\n2. 부정행위(연구부정행위, 시험부정행위, 학문윤리 위반행위를 포함한다)를 한 자\n3. 학문 또는 학교행정과 관련된 문서나 학교재산을 손상한 자\n4. 학교의 교원, 직원, 학생 또는 기타 구성원을 폭행하거나 협박하는 행위를 한 자\n5. 학교의 교무를 방해하거나 학생의 명예를 손상한 행위를 한 자\n6. 제적된 후 복학한 자\n7. 기타 본교의 학칙 또는 기타 제규정을 위반한 자\n② 징계는 근신, 유기정학, 무기정학, 제적의 4종으로 한다.",
#   "Reasoning": "학칙 제59조(징계)에서는 학생이 품위 손상 행위, 부정행위, 문서나 학교재산 손상, 폭행이나 협박 행위, 교무 방해나 학생 명예 손상 행위, 제적 후 복학, 학칙 또는 기타 제규정 위반 등의 행위를 하였을 때 징계를 받을 수 있다고 명시하고 있습니다. 징계는 근신, 유기정학, 무기정학, 제적의 4종으로 나뉘며, 이 중에서 '유기정학' 처분이 내려질 수 있는 조건으로는 시험 부정행위, 학문윤리 위반행위 등의 부정행위가 해당됩니다. 따라서, 학칙 제59조(징계)에 따른 '유기정학' 처분이 내려질 수 있는 조건으로는 (B) 시험 부정행위와 (D) 졸업논문 제출 지연이 해당됩니다."
# }
# ***
# [
#   "Evidence": "① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가\n를 얻어 휴학할 수 있다.\n\n② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을\n명할 수 있다. (개정 1988.7.28)",
# ...
#
# Reasoning: This information provides the definitions of the different types of majors according to Article 47. The types include:
#
# * 복수전공 (Double Major): A major offered by two or more departments in collaboration.
# * 연계전공 (Interdisciplinary Major): A major that provides a combined course of study based on the student's first major and other disciplines.
# * 융합전공 (Convergence Major): A major designed by the student, separate from the major of their department.
# * 자기설계전공 (Self-Designed Major): A major that the student creates the curriculum for and has it recognized by the university.
#
# The correct answer to the question is (B) ㄷ,ㄹ, as it matches the definitions of 융합전공 (Convergence Major) and 자기설계전공 (Self-Designed Major).
# ***
#  ===================36====================
# {
#   "Evidence": [
#     "① 학생이 소속 학부 또는 학과의 변경(이하 “전과”라 한다)을 원할 때에는 「고등교육법 시행령」 제29조제3항의 규정이 정하는 범위내에서 허가할 수 있다. (개정 1999.2.9., 2015.9.18.)",
#     "② 전과의 허가는 매 학년도말에 할 수 있다. (개정 1999.2.9., 2017.8.16.)",
#     "③ 전과의 기준․대상․절차 등 세부사항은 총장이 따로 정한다. (개정 1992.3.16)",
#     "① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가",
#     "② 총장은 건강상의 이유로 정상적인 수업을 받을 수 없다고 인정되는 자에 대하여 휴학을 명할 수 있다. (개정 1988.7.28)",
#     "③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라"
#   ],
#   "Reasoning": [
#     "The segment provides information about the rules for changing departments (transfer) and taking a leave of absence (휴학) at an institution. It specifies that transfer is only allowed at the end of each academic year, and the specifics are determined by the president. The segment also outlines that students can take a leave of absence due to illness or other unavoidable circumstances, with the duration limited to one year unless a special reason is provided. The president can also order a leave of absence for students who cannot attend regular classes due to health reasons. The segment does not directly address the specific scenarios provided in the question, but the information can be used to determine whether the scenarios are in line with the rules.",
#     "Based on the information provided in the segment, we can analyze each scenario to determine if it is allowed according to the rules. Scenario (A) is likely allowed since the student applied for a leave of absence with the president's permission due to health reasons. Scenario (B) is also likely allowed since the student was granted a leave of absence after providing a reason for why they could not attend classes for more than three weeks. Scenario (C) is not allowed as per the segment, as the duration of the leave of absence should not exceed one year unless a special reason is provided. Scenario (D) is not allowed as per the segment, as the student applied for a leave of absence after the 100th day of the semester, which is not allowed."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있다.",
#     "휴학기간이 만료된 자는 총장의 허가를 얻어 복학하여야 한다.",
#     "휴학기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 아니한 자",
#     "수업료 기타 납입금을 소정 기일 내에 납입하지 아니한 자",
#     "재학연한 내에 본교 소정 전과정을 이수하지 못한 자",
#     "징계에 의하여 퇴학처분을 받은 자"
#   ],
#   "Reasoning": [
#     "이 규정은 이화여자대학교의 학칙에 관한 내용을 다루고 있습니다. 제26조(휴학)에 따르면, 휴학 기간이 만료되었으나 총장이 인정하는 중대한 질병의 경우 한 학기 단위로 휴학 연장을 허가할 수 있습니다. 제27조(복학)에 따르면, 휴학 기간이 만료된 자는 총장의 허가를 얻어 복학해야 합니다. 제28조(제적)에 따르면, 휴학 기간 경과 후 3주일 이내에 정당한 이유 없이 복학하지 않은 자, 수업료 기타 납입금을 소정 기일 내에 납입하지 않은 자, 성적이 불량한 자, 재학연한 내에 본교 소정 전과정을 이수하지 못한 자, 타교에 입학한 자, 징계에 의하여 퇴학처분을 받은 자는 총장에 의해 제적됩니다. 제30조(자퇴)에 따르면, 자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 제출해야 합니다."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라 총장이 지정하는 학부, 학과 또는 전공에 있어서는 이를 1년으로 한다. (개정 1996.2.15)",
#     "휴학기간은 통산하여 3년(건축학전공의 경우 4년, 의예과의 경우 3학기)을 초과할 수 없다. 다만, 임신, 출산 및 육아로 인한 휴학, 창업으로 인한 휴학은 2년 이내의 기간을, 군복무로 인한 휴학은 의무복무기간을 추가 휴학기간으로 허가할 수 있다. (개정 2013. 2.25., 2015.9.18., 2016.2.16.)",
#     "재학 중인 자가 휴학을 하고자 하는 경우 학기개시일로부터 90일 이내에 휴학을 신청하여야 한다. (신설 2015.9.18.)"
#   ],
#   "Reasoning": [
#     "The segment provides regulations related to leave of absence in a university. It states that the maximum duration of leave of absence is 3 years for most students, but can be extended to 4 years for architecture majors and 3 semesters for pre-medical students. It also mentions specific cases where the leave of absence can be extended to 2 years, such as pregnancy, childbirth, childcare, and entrepreneurship. Additionally, leave of absence for military service can be extended for the duration of the mandatory service period. The segment also specifies that students who wish to take a leave of absence must apply within 90 days of the semester start date.",
#     "Based on the evidence provided, we can infer that the cases where students apply for leave of absence due to health reasons (A), lack of attendance for more than 3 weeks (B), and extensions of leave of absence due to curriculum requirements (C) are all allowed according to the regulations. However, the case where a student applies for leave of absence more than 100 days after the semester start date (D) is not allowed, as it goes against the regulation that states students must apply within 90 days of the semester start date."
#   ]
# }
# ***
#  ===================37====================
# {
#   "Evidence": "입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다. [본조신설 2009.6.16.]제18조(입학허가) ① 입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가한다. 다만, 제15조제1항의 단서의 경우나 특별전형, 기타 입학에 관하여 긴급한 필요가 있는 경우에는 대학장의 제청을 거치지 아니할 수 있다. ② 총장은 입학자격을 갖추지 못하였거나 제1항의 입학사정에 사용된 전형자료에 허위나 부정이 있다고 판단되는 경우에는 교무회의의 의결을 거쳐 합격취소 및 입학허가취소를 할 수 있다.",
#   "Reasoning": "제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?"라는 질문에 대한 증거를 제공함. 주어진 세그먼트는 입학사정관의 조직과 운영에 관한 사항과 입학허가, 입학자격을 갖추지 못하거나 전형자료에 허위나 부정이 있는 경우의 합격취소 및 입학허가취소에 대한 내용을 다루고 있습니다. 주어진 옵션 중 (A) 고등학교 졸업 정도를 기준으로 하는 입학전형, (B) 고등학교 졸업 성적은 입학전형자료로 사용될 수 없음, (C) 대학수학능력시험 성적과 교직적성 검사 등을 입학전형자료로 활용할 수 있음, (D) 체육·문학·예술 분야 지원자는 별도의 전형을 통해 입학이 허가될 수 있음에 대한 내용은 세그먼트에서 직접적으로 언급되지 않았습니다. 따라서, 주어진 옵션 중 어떤 것이 옳지 않은지에 대한 결론을 내릴 수 없습니다."
# }
# ***
# {
#   "Evidence": [
#     "제29조 삭제 (1987.9.1)",
#     "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 제출하여 총장의 허가를 얻어야 한다. (개정 2017.8.16.)",
#     "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)",
#     "② 재입학은 1회에 한하여 할 수 있다. 다만, 제28조제4호에 의하여 제적된 자는 제적된 날부터 1년이 경과한 후 재입학할 수 있다. (개정 2008.8.19)",
#     "제31조의2(법령 등에 의한 재입학의 특례) 법령이나 법령에 근거한 처분 또는 권고 등에 의하여 재입학을 인정할 필요가 있는 경우에는 총장은 제31조의 규정에 불구하고 재입학을 허가할 수 있다.",
#     "[본조신설 2005.6.17.]",
#     "제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)",
#     "제32조(교"
#   ],
#   "Reasoning": [
#     "The provided segment does not contain any information related to the question about the description of Article 17 (Entrance Examination)."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여",
#     "정당한 이유 없이 제1항의 절차를 이행하지 아니한 자에게는 입학허가를 취소한다.",
#     "학생은 부모 기타의 자로서 학생의 재학중 학비 기타 신상에 관계되는 모든 사항에 대하여 책임을 질만한 능력이 있는 자를 보증인으로 정한다.",
#     "학생은 매 학기초 소정 기일 내에 소정 절차에 의한 등록을 완료하여야 한다.",
#     "학생은 소정 기일 내에 그 학기에 수강할 교과목을 지도교수의 지도를받아 신청하여야 한다."
#   ],
#   "Reasoning": [
#     "The given segment does not provide information about the admission process, so we cannot determine which statement is not correct regarding the points listed.",
#     "We need to find more information about the admission process to evaluate each statement."
#   ]
# }
# ***
#  ===================38====================
# {
#   "Evidence": "제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?",
#   "Reasoning": "입학전형관리위원회, 입학전형기획관리위원회, 입학전형공정관리위원회에 대한 설명이 포함되어 있지만, 어떤 위원회에 대한 설명인지는 명시되어 있지 않습니다. 질문에서 요구하는 설명이 어떤 위원회에 대한 것인지 파악해야 합니다. 각 위원회의 구성과 관련된 내용을 찾아보고, 해당 위원회에 대한 설명을 찾아야 합니다."
# }
# ***
# {
#   "Evidence": [
#     "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)",
#     "제31조의2(법령 등에 의한 재입학의 특례) 법령이나 법령에 근거한 처분 또는 권고 등에 의하여 재입학을 인정할 필요가 있는 경우에는 총장은 제31조의 규정에 불구하고 재입학을 허가할 수 있다. [본조신설 2005.6.17.]"
#   ],
#   "Reasoning": "The provided segment does not contain any information related to the question about the composition of the Admission Selection Management Committee and the Admissions Planning and Management Committee. The segment discusses the readmission process and special provisions for readmission due to legal or regulatory requirements. Therefore, none of the given options (A, B, C, D) can be validated or refuted based on the evidence provided."
# }
# ***
# {
#   "Evidence": [
#     "허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여야 한다. (개정 1997.12.23)",
#     "정당한 이유 없이 제1항의 절차를 이행하지 아니한 자에게는 입학허가를 취소한다.",
#     "학생은 부모 기타의 자로서 학생의 재학중 학비 기타 신상에 관계되는 모든 사항에 대하여 책임을 질만한 능력이 있는 자를 보증인으로 정한다. (개정 1996.2.15)",
#     "학생은 보증인의 주소와 신상에 변동이 있을 때에는 즉시 총장에게 보고하여야 한다. (개정 1996.2.15)",
#     "학생은 매 학기초 소정 기일 내에 소정 절차에 의한 등록을 완료하여야 한다.",
#     "학생은 소정 기일 내에 그 학기에 수강할 교과목을 지도교수의 지도를받아 신청하여야 한다. (개정 2000.2.1)",
#     "교과목의 수강신청은 지도교수의 지도를 받아 철회 또는 변경할 수 있다. (개정 2000.2.1)"
#   ],
#   "Reasoning": [
#     "The question is related to the admission process, but the provided segment does not contain information about the admission procedure. It contains information about the responsibilities of students, registration, and course application. Therefore, the provided segment does not contain any information that can be used to answer the question.",
#     "To answer the question, we need more information about the admission process, such as the composition of the admission committees, the appointment of their members, and their responsibilities. However, the provided segment does not provide any information about these topics.",
#     "It is possible that the information required to answer the question is available in other segments of the document, but we cannot determine this without additional information."
#   ]
# }
# ***
#  ===================39====================
# {
#   "Evidence": [
#     "제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)",
#     "제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초과목 및 전공과목으로 구분한다.",
#     "제33조(교양과목) 교양과목의 종류와 학점은 총장이 따로 정한다.",
#     "제34조(전공과목) 전공과목은 필수과목과 선택과목으로 구분하되, 각각 그 종류와 학점은 소속 대학장의 제청에 의하여 총장이 따로 정한다.",
#     "제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으
# 로 한다.",
#     "이화여자대학교 학칙제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아
# 니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다.",
#     "1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학생의 총 평점을 계산하고, 올바른 결과를 고르시오."
#   ],
#   "Reasoning": [
#     "해당 세그먼트는 1980학년도 이전 입학생에 대한 성적 평가 기준에 대한 내용을 포함하고 있으며, 교양과목, 전공기초과목 및 전공과목의 종류와 학점에 대한 정보를 제공합니다. 또한, 1학기간 15시간 이상의 수업을 1학점으로 한다는 학점 평가 기준도 포함되어 있습니다. 그러나, 해당 세그먼트에서는 1980학년도 이전 입학생에 대한 성적 평가 기준에 대한 구체적인 내용이 제공되지 않아, 주어진 질문의 답변을 직접적으로 제공하지는 않습니다."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "제35조의3(학점의 인정) ① 다음 각 호의 경우에 취득한 학점은 총장의 승인을 얻어 졸업에 필요한 학점의 2분의 1의 범위 안에서 이를 본교에서 취득한 것으로 본다. (개정 2012.12.31.)",
#     "1. 재학 중 국내외의 다른 학교에서 학점을 취득한 경우",
#     "2. 입학 전 국내외의 고등학교와 「고등교육법」 제2조 각 호의 학교에서 대학교육과정에 상응하는 교과목을 이수한 경우",
#     "② 학점의 인정범위 등 제1항의 시행에 필요한 사항은 총장이 따로 정한다. (개정 1998.6.23)",
#     "제35조의4(언어교육원 수강과목 학점의 인정) 입학 전 본교 언어교육원에서 소정의 과정을 이수한 경우 입학 후 대학의 학점으로 인정할 수 있다. 학점인정대상자 및 범위",
#     "② 학점취득특별시험의 방법, 종류에 관한 세부 사항은 총장이 따로 정한다. (개정 2001.9.24)"
#   ],
#   "Reasoning": [
#     "이 문서에서는 학점 인정에 대한 규정과 절차를 설명하고 있으며, 국내외 다른 학교에서 취득한 학점이나 입학 전 고등학교나 다른 학교에서 이수한 교과목에 대한 학점 인정에 대한 내용이 포함되어 있습니다. 또한, 총장이 학점 인정에 대한 세부 사항을 따로 정할 수 있다는 내용도 포함되어 있습니다."
#   ]
# }
# ***
# {
#   "Evidence": [
#     "1980학년도 이전 입학생에 대하여는 제39조 제1항의 규정에 불구하고 등급에 따르는 성적점을 다음과 같이 한다.",
#     "등 급 성적점",
#     "A+ —",
#     "B+ —",
#     "C- —",
#     "D+ —",
#     "F —"
#   ],
#   "Reasoning": [
#     "The question asks for the total grade point of a student based on the grade point system in 1980 or earlier, given the grades of their subjects.",
#     "The evidence provides the grade point system for 1980 or earlier students, which is based on their grades (A+, B+, C-, D+, and F).",
#     "To calculate the total grade point, we need to find the grade point for each subject and then sum them up.",
#     "The evidence does not provide the exact grade point for each grade, so we need to infer it based on the given grades and the available information.",
#     "Assuming the grade point system is similar to the standard system (A=4, B=3, C=2, D=1, F=0), we can calculate the total grade point as follows:",
#     "Subject 1: A = 4",
#     "Subject 2: B+ = 3.5",
#     "Subject 3: C- = 1.5",
#     "Subject 4: D+ = 1.5",
#     "Subject 5: F = 0",
#     "Total grade point = 4 + 3.5 + 1.5 + 1.5 + 0 = 10.5",
#     "Therefore, the correct answer is (B) 10.0, as it is the closest option to the calculated total grade point of 10.5."
#   ]
# }
# ***
#  ===================40====================
# "Evidence": [
#     "입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다.",
#     "입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가한다.",
#     "입학자격을 갖추지 못하였거나 입학사정에 사용된 전형자료에 허위나 부정이 있다고 판단되는 경우에는 교무회의의 의결을 거쳐 합격취소 및 입학허가취소를 할 수 있다.",
#     "합격취소 및 입학허가취소의 사유와 절차에 관한 사항은 총장이 따로 정한다."
# ],
# "Reasoning": "The provided segment does not contain any information about the number of admissions for the colleges of humanities, natural sciences, engineering, and music in the 2018 academic year. Therefore, it cannot be used to answer the question about the total number of admissions for these colleges."
# ***
# {
#   "Evidence": [
#     "제6장 수업연한 및 재학연한 (개정 2014.11.21)제23조(수업연한) ① 각 대학의 수업연한은 4년으로 한다. 다만, 엘텍공과대학의 건축학전공은 5년으로 하고, 의과대학은 6년으로 하되 의예과는 2년, 의학과는 4년으로 하며, 약학대학은 6년으로 하되 다른 학과 또는 학부 등에서 이수하는 기초․소양 교육은 2년으로 하고, 전공교육은 4년으로 한다. (개정 2014.11.21., 2017.2.8.)"
#   ],
#   "Reasoning": [
#     "이 증거는 각 단과대학의 수업연한에 대한 내용이며, 2018학년도의 입학정원에 대한 정보는 포함되어 있지 않습니다. 따라서 이 증거는 질문에 대한 직접적인 답변이 아닙니다."
#   ]
# }
# ***
# Evidence: "인문과학대학, 자연과학대학, 공과대학, 음악대학"
#
# Reasoning: The provided segment does not contain any information related to the question about the sum of the incoming classes in the 2018 academic year for the colleges mentioned. Therefore, I cannot provide any reasoning or analysis to answer the question.
# ***
#  ===================41====================
# "Evidence": "제22조(수강신청) ① 학생은 소정 기일 내에 그 학기에 수강할 교과목을 지도교수의 지도를받아 신청하여야 한다. (개정 2000.2.1)\n② 교과목의 수강신청은 지도교수의 지도를 받아 철회 또는 변경할 수 있다. (개정 2000.2.1)",
# "Reasoning": "이 증거는 학생 A가 수강신청을 승인받은 교과목에 대한 행동에 대한 정보를 제공합니다. 그러나, 학생 A의 학업 성적에 대한 결과를 직접적으로 제공하지는 않습니다. 이를 위해서는 학생 A가 수강한 교과목의 성적 평가 방식과 학사일정 등에 대한 추가 정보가 필요합니다."
# ***
# {
#   "Evidence": "제26조(휴학) ① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자는 총장의 허가",
#   "Reasoning": "이 문서에서는 학생이 질병이나 기타 부득이한 사정으로 3주일 이상 수강할 수 없을 경우 휴학을 허가받을 수 있다고 언급하고 있습니다. 이 정보는 학생의 학업 성적에 직접적인 영향을 미치지는 않지만, 학생이 어떤 상황에서 휴학을 할 수 있는지에 대한 배경 정보를 제공합니다."
# }
# ***
# {
#   "Evidence": [
#     "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 제출하여 총장의 허가를 얻어야 한다. (개정 2017.8.16.)",
#     "제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)",
#     "제31조의2(법령 등에 의한 재입학의 특례) 법령이나 법령에 근거한 처분 또는 권고 등에 의하여 재입학을 인정할 필요가 있는 경우에는 총장은 제31조의 규정에 불구하고 재입학을 허가할 수 있다. [본조신설 2005.6.17.]"
#   ],
#   "Reasoning": "주어진 정보는 자퇴, 재입학, 그리고 법령 등에 의한 재입학의 특례에 대한 내용을 다루고 있습니다. 그러나, 학생 A의 성적에 대한 구체적인 언급은 없습니다. 주어진 정보는 학생 A가 수강신청한 과목에 대한 행동에 대한 직접적인 답변을 제공하지는 않지만, 학생 A의 성적에 대한 결과를 예측하는 데 도움이 될 수 있는 관련 정보를 포함하고 있습니다."
# }
# ***
#  ===================42====================
# {
#   "Evidence": "제1전공: 85학점, 제2전공: 34학점, 교양학점: 15학점, 교과과정 정상화로 인해 총장이 별도로 지정한 학점 5학점을 추가로 취득해야 한다.",
#   "Reasoning": "학생 A는 필요한 학점을 모두 취득했습니다. 제1전공 85학점 + 제2전공 34학점 + 교양학점 15학점 + 교과과정 정상화 5학점 = 139학점입니다. 이는 졸업 요건인 129학점 이상을 충족합니다. 따라서 학생 A는 졸업 요건을 충족했습니다."
# }
# ***
# {
#   "Evidence": [
#     "학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다: 제1전공: 85학점, 제2전공: 34학점, 교양학점: 15학점, 총 134학점",
#     "교과과정 정상화로 인해 총장이 별도로 지정한 학점 5학점을 추가로 취득해야 한다는 지침이 내려졌습니다."
#   ],
#   "Reasoning": [
#     "학생 A가 졸업 요건을 충족했는지 확인해야 합니다. 주어진 세그먼트에 따르면, 졸업에 필요한 학점은 총 129학점입니다. 학생 A는 제1전공 85학점, 제2전공 34학점, 교양학점 15학점을 취득하여 총 134학점을 취득했습니다. 그러나 교과과정 정상화로 인해 추가로 5학점을 취득해야 합니다. 따라서 학생 A는 졸업 요건을 충족하지 못했습니다 (B)."
#   ]
# }
# ***
# {
#   "Evidence": "제32조(교과과정) 교과과정의 운영에 관하여 필요한 사항은 따로 정한다.",
#   "Reasoning": "학생 A가 졸업 요건을 충족했는지 판단하기 위해서는 해당 대학의 학점 취득 요건을 확인해야 합니다. 주어진 세그먼트에서는 졸업 요건에 대한 구체적인 학점 취득 요건이 명시되어 있지 않으므로, 학생 A의 졸업 여부를 판단할 수 없습니다. 주어진 정보로는 학생 A의 학점 취득 현황과 교과과정의 운영 사항에 대한 추가 정보가 필요합니다."
# }
# ***

# %%
nowtest.top3[1]
# Out:
# '외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 1996.2.15., 2017.2.8.)\n② 학점취득특별시험의 방법, 종류에 관한 세부 사항은 총장이 따로 정한다. (개정\n2001.9.24)제35조의3(학점의 인정) ① 다음 각 호의 경우에 취득한 학점은 총장의 승인을 얻어 졸업에\n필요한 학점의 2분의 1의 범위 안에서 이를 본교에서 취득한 것으로 본다. (개정\n2012.12.31.)1. 재학 중 국내외의 다른 학교에서 학점을 취득한 경우\n2. 입학 전 국내외의 고등학교와 「고등교육법」 제2조 각 호의 학교에서 대학교육과정에 상\n당하는 교과목을 이수한 경우\n② 학점의 인정범위 등 제1항의 시행에 필요한 사항은 총장이 따로 정한다. (개정\n1998.6.23)③ 삭제 (1998.6.23.)제35조의4(언어교육원 수강과목 학점의 인정) 입학 전 본교 언어교육원에서 소정의 과정을 이\n수한 경우 입학 후 대학의 학점으로 인정할 수 있다. 학점인정대상자 및 범위'

# %%
nowtest
# Out:
#     index                                         embed_ques  \
# 0       0  [-0.005329132080078125, 0.0017337799072265625,...
# 1       1  [-0.00460052490234375, -0.0174713134765625, -0...
# 2       2  [0.007404327392578125, -0.0216522216796875, 0....
# 3       3  [-0.002162933349609375, -0.039215087890625, -0...
# 4       4  [0.0089111328125, -0.0259552001953125, -0.0064...
# 5       5  [0.0015554428100585938, -0.019683837890625, -0...
# 6       6  [-0.018157958984375, -0.0157318115234375, -0.0...
# 7       7  [0.0029163360595703125, -0.018707275390625, -0...
# 8       8  [-5.4895877838134766e-05, -0.01477813720703125...
# 9       9  [-0.002269744873046875, 0.0017795562744140625,...
# 10     10  [-0.0174560546875, -0.022064208984375, -0.0094...
# 11     11  [-0.0036525726318359375, 0.005313873291015625,...
# 12     12  [0.00012981891632080078, -0.01374053955078125,...
# 13     13  [-0.0191650390625, -0.0198516845703125, -0.027...
# 14     14  [-0.006168365478515625, -0.009368896484375, -0...
# 15     15  [-0.00464630126953125, -0.00894927978515625, -...
# 16     16  [0.00395965576171875, -0.0242156982421875, -0....
# 17     17  [-0.023773193359375, -0.012847900390625, -0.01...
# 18     18  [0.0045623779296875, -0.026580810546875, -0.01...
# 19     19  [0.0032901763916015625, -0.0141448974609375, 0...
# 20     20  [-0.0005626678466796875, -0.0136566162109375, ...
# 21     21  [-0.01462554931640625, -0.0188140869140625, -0...
# 22     22  [-0.00027251243591308594, -0.01363372802734375...
# 23     23  [0.00484466552734375, -0.00014400482177734375,...
# 24     24  [-0.0201263427734375, -0.01532745361328125, -0...
# 25     25  [0.01309967041015625, -0.0241546630859375, -0....
# 26     26  [0.01483154296875, -0.03533935546875, -0.00331...
# 27     27  [0.035247802734375, -0.0292510986328125, -0.02...
# 28     28  [0.00457763671875, -0.0146636962890625, -0.000...
# 29     29  [0.00870513916015625, -0.005367279052734375, -...
# 30     30  [-0.017486572265625, -0.029327392578125, -0.01...
# 31     31  [0.00934600830078125, -0.00826263427734375, -0...
# 32     32  [0.004810333251953125, -0.01242828369140625, -...
# 33     33  [-0.00408172607421875, -0.0066680908203125, -0...
# 34     34  [0.01059722900390625, 0.003986358642578125, -0...
# 35     35  [0.01451873779296875, -0.0285491943359375, -0....
# 36     36  [0.005802154541015625, -0.0128326416015625, -0...
# 37     37  [-0.0031147003173828125, -0.000395059585571289...
# 38     38  [-0.01178741455078125, -0.035858154296875, -0....
# 39     39  [-0.0184173583984375, -0.0208740234375, -0.007...
# 40     40  [-0.00659942626953125, 0.005962371826171875, -...
# 41     41  [0.0025501251220703125, -0.00481414794921875, ...
#
#                                              question  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...
# 1                 각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n
# 2           부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n
# 3               학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...
# 5           학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n
# 6    학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?\n
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...
# 9        학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까?\n
# 11     학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n
# 12   학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?\n
# 13      학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n
# 14          학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n
# 15    학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\n
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...
# 20    학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\n
# 21     학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...
# 25                             전공과 관련된 조항으로 올바른 것은?\n
# 26                         등록금에 관한 조항으로 올바르지 않은 것은?\n
# 27                                 전공과목은 어떻게 구분되는가?\n
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...
# 29                          학칙개정에 관한 설명으로 옳지 않은 것은?\n
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...
# 31                  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...
# 33       제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...
# 36               제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n
# 37          제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...
#
#                                               prompts answers predict  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...     (D)    None
# 1   각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n(A) 이학사\n(B...     (E)    None
# 2   부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n(A) 현...     (B)    None
# 3   학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n(A) 시험 직후...     (B)    None
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...     (C)    None
# 5   학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n(A) 서...     (D)    None
# 6   학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?...     (C)    None
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...     (D)    None
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...     (C)    None
# 9   학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n(A...     (B)    None
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까...     (B)    None
# 11  학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n...     (C)    None
# 12  학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?...     (B)    None
# 13  학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n(...     (E)    None
# 14  학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n(A) 신...     (A)    None
# 15  학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\...     (C)    None
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...     (E)    None
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...     (B)    None
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...     (C)    None
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...     (C)    None
# 20  학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\...     (C)    None
# 21  학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n...     (D)    None
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...     (B)    None
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...     (C)    None
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...     (B)    None
# 25  전공과 관련된 조항으로 올바른 것은?\n(A) 2 이상의 학부가 연계하여 제공하는 ...     (B)    None
# 26  등록금에 관한 조항으로 올바르지 않은 것은?\n(A) 총장은 등록금심의위원회의 구성...     (E)    None
# 27  전공과목은 어떻게 구분되는가?\n(A) 전공기초과목과 전공과목\n(B) 총장이 따로...     (C)    None
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...     (D)    None
# 29  학칙개정에 관한 설명으로 옳지 않은 것은?\n(A) 학칙 개정과 대학평의원회는 무관...     (A)    None
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...     (B)    None
# 31  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n(A) 학칙 개정은 사전...     (C)    None
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...     (A)    None
# 33  제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n(A...     (C)    None
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...     (D)    None
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...     (D)    None
# 36  제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n(A) 입학 전형은...     (B)    None
# 37  제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n(A) 입...     (B)    None
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...     (A)    None
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...     (A)    None
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...     (B)    None
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...     (A)    None
#
#                                                  top1  \
# 0   외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 19...
# 1   당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 2   .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 3   허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 4   . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 5   4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 6   .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 7   있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 8   988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 9   5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 10  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 11  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 12  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 13  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 14  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 15  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 16  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 17  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 18  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 19  외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 19...
# 20  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 21  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 22  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 23  없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 24  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 25  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 26  허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 27  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 28  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 29  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 30  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 31  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 32  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 33  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 34  심화전공) ① 학생은 학과또는 학부가 제공하는 전공을 이수하되, 총장의 허가를 얻어...
# 35  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 36  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 37  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 38  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 39  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 40  허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 41  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
#
#                                                  top2  \
# 0   5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 1   5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 2   있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 3   4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 4   당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 5   당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 6   988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 7   없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 8   .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 9   없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 10  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 11  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 12  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 13  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 14  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 15  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 16  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 17  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 18  없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 19  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 20  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 21  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 22  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 23  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 24  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 25  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 26  당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다....
# 27  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 28  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 29  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 30  없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 31  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 32  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 33  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 34  없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 35  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 36  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 37  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 38  외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 19...
# 39  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 40  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 41  외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 19...
#
#                                                  top3  \
# 0   4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 1   외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 19...
# 2   4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 3   .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 4   5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 5   .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 6   . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 7   988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 8   . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 9   4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 10  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 11  없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 12  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 13  988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 14  988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 15  외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 19...
# 16  . (신설 2015.9.18.)이화여자대학교 학칙⑧ 제4항에서 정한 휴학기간이 만료...
# 17  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 18  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 19  없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 20  .21)\n⑥ 휴학기간은 재학연한에 산입하지 아니한다. (개정 2014.11.21)...
# 21  988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 22  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 23  5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제3...
# 24  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 25  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 26  방정하고 학력이 우수하거나 타의 모범이 될 만한 선행을 한 학\n생에 대하여 중앙지...
# 27  외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 19...
# 28  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 29  허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 30  988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 31  허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 32  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 33  허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 34  있다. (개정\n2000.2.1)\n③ 삭제 (1984.3.5)\n④ 수강신청에 관...
# 35  988.7.28)\n③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필...
# 36  허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 37  허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1...
# 38  이를 폐지한다.\n③ 제10조 제2항, 제23조 제2항, 제45조 제3항 내지 제5...
# 39  없다. (개정 2014.11.21)② 의과대학 학생의 재학연한은 의예과는 4년, 의...
# 40  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
# 41  4)제29조 삭제 (1987.9.1)\n제30조(자퇴) 자퇴하고자 하는 자는 보증인...
#
#                                              top1plus  \
# 0   {\n  "Evidence": "외에 학점을 취득할 수 있으며,그 학점수는 12학점...
# 1   {\n  "Evidence": "입학(편입학 및 재입학 포함)은 해당 대학장의 제청...
# 2   {\n  "Evidence": [\n    "제7장 교내전학제25조(전과) ① 학생...
# 3   {\n  "Evidence": [\n    "학생은 매 학기초 소정 기일 내에 소정...
# 4   {\n  "Evidence": [\n    "이화여자대학교 학칙⑧ 제4항에서 정한 ...
# 5   {\n  "Evidence": [\n    "제29조 삭제 (1987.9.1)",\...
# 6   {\n  "Evidence": [\n    "제26조(휴학) ① 질병 기타 부득이한...
# 7   {\n"Evidence": "제23조(수업연한) ① 각 대학의 수업연한은 4년으로 ...
# 8   {\n  "Evidence": [\n    "④ 휴학기간은 통산하여 3년(건축학전공...
# 9   "Evidence": ["제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초...
# 10  {\n  "Evidence": [\n    "학칙 제4항에서 정한 휴학기간이 만료되...
# 11  "Evidence": ["제6장 수업연한 및 재학연한 (개정 2014.11.21)제...
# 12  {\n  "Evidence": [\n    "제28조(제적) 다음 각 호의 1에 해...
# 13  {\n  "Evidence": [\n    "학칙 제26조(휴학) ① 질병 기타 부...
# 14  Evidence: "① 질병 기타 부득이한 사정으로 3주일 이상 수강할 수 없는 자...
# 15  {\n  "Evidence": "제35조(학점) 교과과정이수의 단위는 학점으로 하되...
# 16  {\n  "Evidence": [\n    "제32조(교과목의 분류) 본교의 교과는...
# 17  {\n  "Evidence": [\n    "입학정원의 일부를 통합 모집할 수 있다...
# 18  {\n  "Evidence": ["엘텍공과대학의 건축학전공은 5년으로", "의과대학...
# 19  [\n  "Evidence": "학칙 제45조(취득학점)에 따라 직전 학기 평균성적...
# 20  {\n  "Evidence": [\n    "제28조(제적) 다음 각 호의 1에 해...
# 21  {\n  "Evidence": [\n    "제26조(휴학) ① 질병 기타 부득이한...
# 22  {\n  "Evidence": [\n    "제32조(교과과정)",\n    "제3...
# 23  {\n  "Evidence": [\n    "의과대학 학생의 재학연한은 의예과는 4...
# 24  {\n  "Evidence": "제59조(징계) ① 총장은 학생이 다음 각 호의 1...
# 25  {\n  "Evidence": [\n    "제32조(교과목의 분류) 본교의 교과는...
# 26  {\n  "Evidence": [\n    "학생은 매 학기초 소정 기일 내에 소정...
# 27  {\n  "Evidence": "전공과목은 필수과목과 선택과목으로 구분하되, 각각 ...
# 28  {\n  "Evidence": "제9장 교육과정, 이수, 수료 및 졸업 (개정 20...
# 29  {\n  "Evidence": [\n    "입학사정관의 조직과 운영에 관한 사항은...
# 30  {\n  "Evidence": "제23조(수업연한) ① 각 대학의 수업연한은 4년으...
# 31  {\n  "Evidence": [\n    "입학사정관의 조직과 운영에 관한 사항은...
# 32  "Evidence": [\n"학생은 총학생회 등 학생단체를 구성할 수 있으며, 학생...
# 33  {\n  "Evidence": [\n    "제29조 삭제 (1987.9.1)",\...
# 34  {\n  "Evidence": "심화전공) ① 학생은 학과또는 학부가 제공하는 전공...
# 35  {\n  "Evidence": [\n    "① 학생이 소속 학부 또는 학과의 변경...
# 36  {\n  "Evidence": "입학사정관의 조직과 운영에 관한 사항은 총장이 따로...
# 37  {\n  "Evidence": "제17조의2(입학전형관리위원회 등)에 관한 설명으로...
# 38  {\n  "Evidence": [\n    "제9장 교육과정, 이수, 수료 및 졸업...
# 39  "Evidence": [\n    "입학사정관의 조직과 운영에 관한 사항은 총장이 ...
# 40  "Evidence": "제22조(수강신청) ① 학생은 소정 기일 내에 그 학기에 수...
# 41  {\n  "Evidence": "제1전공: 85학점, 제2전공: 34학점, 교양학점...
#
#                                              top2plus  \
# 0   {\n  "Evidence": [\n    "제35조의2(학점취득의 특례) ① 교양...
# 1   {\n  "Evidence": "제32조(교과목의 분류) 본교의 교과는 교양과목, ...
# 2   [\n  'Evidence': '제6조(학과명칭 및 모집단위변경) ①학칙 제2조의 ...
# 3   [\n  "Evidence": "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서...
# 4   {\n  "Evidence": "학칙 제1조(목적)에 따르면 이화여자대학교의 설립 ...
# 5   {\n  "Evidence": [\n    "당하게 할 수 있다.② 입학사정관의 조...
# 6   {\n  "Evidence": [\n    "④ 휴학기간은 통산하여 3년(건축학전공...
# 7   {\n  "Evidence": [\n    "의과대학 학생의 재학연한은 의예과는 4...
# 8   {\n  "Evidence": [\n    "⑥ 휴학기간은 재학연한에 산입하지 아니...
# 9   {\n  "Evidence": [\n    "복수전공을 이수하는 학생, \"고등교육...
# 10  {\n  "Evidence": [\n    "자퇴하고자 하는 자는 보증인이 연서한 ...
# 11  {\n  "Evidence": [\n    "제9장 교육과정, 이수, 수료 및 졸업...
# 12  [\n  "Evidence": "제28조(제적) 다음 각 호의 1에 해당하는 자는 ...
# 13  {\n  "Evidence": "이화여자대학교 학칙 제4항에서 정한 휴학기간이 만료...
# 14  {\n  "Evidence": [\n    "이화여자대학교 학칙⑧ 제4항에서 정한 ...
# 15  {\n  "Evidence": "학칙 제35조(학점)에 따르면, 한 학점으로 인정되...
# 16  {\n  "Evidence": [\n    "입학사정관의 조직과 운영에 관한 사항은...
# 17  {\n  "Evidence": "제5조(입학정원) ① 본교의 입학정원은 법령이 정하...
# 18  {\n  "Evidence": [\n    "없다. (개정 2014.11.21)② ...
# 19  {\n  "Evidence": "제35조(학점) 교과과정이수의 단위는 학점으로 하되...
# 20  {\n  "Evidence": "제28조(제적): 1) 휴학 기간 종료 후 3주 이...
# 21  {\n  "Evidence": [\n    "제4항에서 정한 휴학기간이 만료되었으나...
# 22  {\n  "Evidence": [\n    "제32조(교과목의 분류) 본교의 교과는...
# 23  {\n  "Evidence": "제23조(수업연한) ① 각 대학의 수업연한은 4년으...
# 24  [\n  "Evidence": "① 질병 기타 부득이한 사정으로 3주일 이상 수강할...
# 25  {\n  "Evidence": [\n    "제25조(전과) ① 학생이 소속 학부 ...
# 26  {\n  "Evidence": "입학이 허가된 자는 정해진 기일 내에 입학금 기타 ...
# 27  {\n  "Evidence": "제23조(수업연한) ① 각 대학의 수업연한은 4년으...
# 28  [\n  "Evidence": "제6장 수업연한 및 재학연한 (개정 2014.11....
# 29  {\n  "Evidence": [\n    "제7장 교내전학제25조(전과) ① 학생...
# 30  {\n  "Evidence": "없다. (개정 2014.11.21)② 의과대학 학생...
# 31  {\n  "Evidence": [\n    "학칙 개정은 사전 공고가 필요하다.",...
# 32  {\n  "Evidence": [\n    "학생은 총학생회 등 학생단체를 구성할 ...
# 33  {\n  "Evidence": ["제48조의4와 제48조의5의 규정에 대한 설명으로...
# 34  {\n  "Evidence": "제47조의 전공 유형에 대한 규정이 언급되지 않았습...
# 35  {\n  "Evidence": [\n    "이화여자대학교 학칙⑧ 제4항에서 정한 ...
# 36  {\n  "Evidence": [\n    "제29조 삭제 (1987.9.1)",\...
# 37  {\n  "Evidence": [\n    "제31조(재입학) ① 제28조제1호 부...
# 38  {\n  "Evidence": [\n    "제35조의3(학점의 인정) ① 다음 각...
# 39  {\n  "Evidence": [\n    "제6장 수업연한 및 재학연한 (개정 2...
# 40  {\n  "Evidence": "제26조(휴학) ① 질병 기타 부득이한 사정으로 3...
# 41  {\n  "Evidence": [\n    "학생 A는 졸업을 위해 다음과 같은 학...
#
#                                              top3plus  ground
# 0   [\n  "Evidence": "제31조(재입학) ① 제28조제1호 부터 제4호까지...     NaN
# 1   {\n  "Evidence": [\n    "외에 학점을 취득할 수 있으며,그 학점...     NaN
# 2   {\n  "Evidence": [\n    "제31조(재입학) ① 제28조제1호 부...     NaN
# 3   [\n  "Evidence": "제26조(휴학) ① 질병 기타 부득이한 사정으로 3...     NaN
# 4   {\n  "Evidence": "제9장 교육과정, 이수, 수료 및 졸업 (개정 20...     NaN
# 5   {\n  "Evidence": [\n    {\n      "text": "제8장 ...     NaN
# 6   {\n  "Evidence": [\n    "제4항에서 정한 휴학기간이 만료되었으나...     NaN
# 7   {\n  "Evidence": [\n    "③ 1회의 휴학기간은 1년 이내로 한다...     NaN
# 8   {\n  "Evidence": [\n    "이화여자대학교 학칙⑧ 제4항에서 정한 ...     NaN
# 9   {\n  "Evidence": "제32조(교과목) ① 대학원에서는 석사학위과정과 박...     NaN
# 10  {\n  "Evidence": [\n    "⑥ 휴학기간은 재학연한에 산입하지 아니...     NaN
# 11  {\n  "Evidence": [\n    "② 의과대학 학생의 재학연한은 의예과는...     NaN
# 12  {\n  "Evidence": [\n    "제26조(휴학) ① 질병 기타 부득이한...     NaN
# 13  {\n  "Evidence": [\n    "③ 1회의 휴학기간은 1년 이내로 한다...     NaN
# 14  {\n  "Evidence": [\n    "⑦ 신입생, 편입학한 학생, 재입학한 ...     NaN
# 15  {\n  "Evidence": "학점취득특별시험의 방법, 종류에 관한 세부 사항은 ...     NaN
# 16  [\n  "Evidence": "학칙 제1조(목적)에서 이화여자대학교의 설립 정신에...     NaN
# 17  {\n  "Evidence": [\n    "⑥ 휴학기간은 재학연한에 산입하지 아니...     NaN
# 18  {\n  "Evidence": "제23조(수업연한) ① 이 학교의 수업연한은 4년으...     NaN
# 19  {\n  "Evidence": [\n    "제45조(취득학점)에 따라 직전 학기 ...     NaN
# 20  {\n  "Evidence": [\n    "제26조(휴학) ① 질병 기타 부득이한...     NaN
# 21  {\n  "Evidence": "④ 휴학기간은 통산하여 3년(건축학전공의 경우 4년...     NaN
# 22  {\n  "Evidence": "제6장 수업연한 및 재학연한 (개정 2014.11....     NaN
# 23  {\n  "Evidence": "제35조(학점) 교과과정이수의 단위는 학점으로 하되...     NaN
# 24  {\n  "Evidence": [\n    "제29조 삭제 (1987.9.1)",\...     NaN
# 25  {\n  "Evidence": [\n    "제28조(제적) 다음 각 호의 1에 해...     NaN
# 26  {\n  "Evidence": [\n    "제60조(등록금) 학생은 매 학기 등록...     NaN
# 27  {\n  "Evidence": "제35조의3(학점의 인정) ① 다음 각 호의 경우에...     NaN
# 28  [\n  "Evidence": "제9장 교육과정, 이수, 수료 및 졸업 (개정 20...     NaN
# 29  "Evidence": [\n    "허가된 자는 정해진 기일 내에 입학금 기타 납입...     NaN
# 30  {\n  "Evidence": "988.7.28)③ 1회의 휴학기간은 1년 이내로 ...     NaN
# 31  {\n  "Evidence": [\n    "제20조(보증인) ① 학생은 부모 기타...     NaN
# 32  Evidence: "제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 ...     NaN
# 33  Evidence:\n- "학생은 매 학기초 소정 기일 내에 소정 절차에 의한 등록을...     NaN
# 34  Evidence: "제47조(전공의 유형) ① 전공의 유형은 다음과 같다. 1. 복...     NaN
# 35  {\n  "Evidence": [\n    "1회의 휴학기간은 1년 이내로 한다. ...     NaN
# 36  {\n  "Evidence": [\n    "허가된 자는 정해진 기일 내에 입학금 ...     NaN
# 37  {\n  "Evidence": [\n    "허가된 자는 정해진 기일 내에 입학금 ...     NaN
# 38  {\n  "Evidence": [\n    "1980학년도 이전 입학생에 대하여는 ...     NaN
# 39  Evidence: "인문과학대학, 자연과학대학, 공과대학, 음악대학"\n\nReas...     NaN
# 40  {\n  "Evidence": [\n    "제30조(자퇴) 자퇴하고자 하는 자는 ...     NaN
# 41  {\n  "Evidence": "제32조(교과과정) 교과과정의 운영에 관하여 필요한...     NaN

# %%
############# Segment+ 2nd Prompt ##########

from langchain_core.prompts import PromptTemplate
from langchain_upstage import ChatUpstage


llm = ChatUpstage(api_key = api_key)

prompt_template = PromptTemplate.from_template(
    '''
    
    You are an assistant with expertise in Ewha University policies and history. Use the provided context to answer accurately.
    Let's think step by step.

    Context: {context1} {context2} {context3}

    Question: {question}

    Final Answer:
    
    '''

)
segplus2 = prompt_template | llm


responses = []
for idx, row in nowtest.iterrows() : 
        
    response = segplus2.invoke({"question": row.prompts, "context1": row.top1plus, "context2": row.top2plus, "context3": row.top3plus}) # 선지 전까지 받아오기
    responses.append(response.content)
    nowtest.loc[idx, 'predict'] = response.content

responses
# Out:
# ['D',
#  '(C) 공학사',
#  '(B) 구 학칙에 의하여 재학생이 졸업하는 연도까지 존속한다',
#  '(B) 성적 입력 마감 후',
#  '(C) 지역사회의 봉사',
#  '(D) 강남구입니다.',
#  '(C) 학생총회 요청',
#  'B',
#  '(E) 중대한 질병으로 인한 휴학: 총장의 판단에 따라 연장 가능',
#  '(B) 전공별 종합시험 합격',
#  'E',
#  'C',
#  '(D) 타교에 입학한 경우',
#  'D',
#  '(A)',
#  '(C) 15시간 이상',
#  '(E) 특정 종교 교리 확립',
#  '정답은 (C) 전공 결정은 일정 학점 이수 후 이루어진다입니다.',
#  '질문에 대한 정답은 (D) 엘텍공과대학 건축학전공입니다. 주어진 학칙에 따르면, 엘텍공과대학의 건축학전공은 수업 연한이 4년이 아닌 5년으로 규정되어 있습니다.',
#  '(C) 21학점',
#  '(C) 학기 중간에 전과를 신청한 경우',
#  '(C) 동기방학',
#  '(B)',
#  '답변:\nC',
#  '(B) 시험 부정행위']

# %% [markdown]
# ## check accuracy

# %%
######### 정답 확인 + wrong 뽑아내기 ######

# print accuracy

cnt = 0
wrong2 = []
for idx, (answer, response) in enumerate(zip(answers, nowtest['predict'])):
    print("-"*10)
    generated_answer = extract_answer(response)
    print(response)
    # check
    if generated_answer:
        print(f"idx: {idx} | generated answer: {generated_answer}, answer: {answer}")
    else:
        print("extraction fail")

    if generated_answer == None:
        wrong2.append(idx) 
        continue
    
    if generated_answer in answer:
        cnt += 1
    else : 
        wrong2.append(idx)
        

print()
print(f"acc: {(cnt/len(answers))*100}%")
print()
print("wrong:",wrong2)
# Out:
# ----------
# D
# idx: 0 | generated answer: D, answer: (D)
# ----------
# (C) 공학사
# idx: 1 | generated answer: C, answer: (E)
# ----------
# (B) 구 학칙에 의하여 재학생이 졸업하는 연도까지 존속한다
# idx: 2 | generated answer: B, answer: (B)
# ----------
# (B) 성적 입력 마감 후
# idx: 3 | generated answer: B, answer: (B)
# ----------
# (C) 지역사회의 봉사
# idx: 4 | generated answer: C, answer: (C)
# ----------
# (D) 강남구입니다.
# idx: 5 | generated answer: D, answer:  (D)
# ----------
# (C) 학생총회 요청
# idx: 6 | generated answer: C, answer:  (C)
# ----------
# B
# idx: 7 | generated answer: B, answer:  (D)
# ----------
# (E) 중대한 질병으로 인한 휴학: 총장의 판단에 따라 연장 가능
# idx: 8 | generated answer: E, answer:  (C)
# ----------
# (B) 전공별 종합시험 합격
# idx: 9 | generated answer: B, answer:  (B)
# ----------
# E
# idx: 10 | generated answer: E, answer:  (B)
# ----------
# C
# idx: 11 | generated answer: C, answer:  (C)
# ----------
# (D) 타교에 입학한 경우
# idx: 12 | generated answer: D, answer:  (B)
# ----------
# D
# idx: 13 | generated answer: D, answer:  (E)
# ----------
# (A)
# idx: 14 | generated answer: A, answer:  (A)
# ----------
# (C) 15시간 이상
# idx: 15 | generated answer: C, answer:  (C)
# ----------
# (E) 특정 종교 교리 확립
# idx: 16 | generated answer: E, answer:  (E)
# ----------
# 정답은 (C) 전공 결정은 일정 학점 이수 후 이루어진다입니다.
# idx: 17 | generated answer: C, answer:  (B)
# ----------
# 질문에 대한 정답은 (D) 엘텍공과대학 건축학전공입니다. 주어진 학칙에 따르면, 엘텍공과대학의 건축학전공은 수업 연한이 4년이 아닌 5년으로 규정되어 있습니다.
# idx: 18 | generated answer: D, answer:  (C)
# ----------
# (C) 21학점
# idx: 19 | generated answer: C, answer:  (C)
# ----------
# (C) 학기 중간에 전과를 신청한 경우
# idx: 20 | generated answer: C, answer:  (C)
# ----------
# (C) 동기방학
# idx: 21 | generated answer: C, answer:  (D)
# ----------
# (B)
# idx: 22 | generated answer: B, answer:  (B)
# ----------
# 답변:
# C
# idx: 23 | generated answer: C, answer:  (C)
# ----------
# (B) 시험 부정행위
# idx: 24 | generated answer: B, answer:  (B)
#
# acc: 64.0%
#
# wrong: [1, 7, 8, 10, 12, 13, 17, 18, 21]

# %% [markdown]
# ## groundedness check
#
# ### 질문할 때마다 답이 달라져서 안 할 거임

# %%
import os
from langchain_upstage import UpstageGroundednessCheck # langchain_upstage==0.1.3
 
groundedness_check = UpstageGroundednessCheck()
 
request_input = {
    "context": f"Mauna Kea is an inactive volcano on the island of Hawai'i. Its peak is 4,207.3 m above sea level, making it the highest point in Hawaii and second-highest peak of an island on Earth.",
    "answer": "Mauna Kea is 5,207.3 meters tall.",
}
response = groundedness_check.invoke(request_input)
print(response)
