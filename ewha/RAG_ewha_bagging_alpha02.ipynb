# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/UpstageAI/cookbook/blob/main/cookbooks/upstage/Solar-Full-Stack LLM-101/05_3_OracleDB.ipynb">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # EWHA bagging _ alpha (솔빈이 코드 추가)

# %%
# set parameters

file = open("info/api.txt", "r")
api_key = file.read()
file.close()

file = open("info/datapath.txt", "r")
data_path = file.read()
file.close()

file = open("info/resultspath.txt", "r")
results_path = file.read()
file.close()

# %%
from langchain_upstage import UpstageEmbeddings
from langchain_upstage import ChatUpstage

# 쿼리 전용 임베딩 모델
query_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-query")

# 문장 전용 임베딩 모델
passage_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-passage")

# %%
# funcion to extract an answer from response

import re

def extract_answer(response):
    """
    extracts the answer from the response using a regular expression.
    expected format: "[ANSWER]: (A) convolutional networks"

    if there are any answers formatted like the format, it returns None.
    """
    pattern = r"\[ANSWER\]:\s*\((A|B|C|D|E)\)"  # Regular expression to capture the answer letter and text
    match = re.search(pattern, response)

    if match:
        return match.group(1) # Extract the letter inside parentheses (e.g., A)
    else:
        return extract_again(response)

def extract_again(response):
    pattern = r"\b[A-J]\b(?!.*\b[A-J]\b)"
    match = re.search(pattern, response)
    if match:
        return match.group(0)
    else:
        return None

# %% [markdown]
# ## 1. build DB

# %%
from langchain_upstage import UpstageLayoutAnalysisLoader
import os
import numpy as np


UPSTAGE_API_KEY = api_key

# .npy 파일 로드 (타입==넘파이)
ewhaDB = np.load(data_path+f'embedding/full_ewha500.npy')

ewhaDB_embed = np.load(data_path+f'embedding/full_ewha500_embed.npy')
ewhaDB_embed = ewhaDB_embed.tolist()

ewhaDB_embed
# Out:
# [[0.0098114013671875,
#   0.0006871223449707031,
#   -0.00771331787109375,
#   0.00971221923828125,
#   0.018707275390625,
#   -0.0097503662109375,
#   -0.0168304443359375,
#   0.0064849853515625,
#   0.02294921875,
#   0.011566162109375,
#   0.0031528472900390625,
#   0.005855560302734375,
#   -0.00281524658203125,
#   0.0150909423828125,
#   0.01238250732421875,
#   0.01226043701171875,
#   -0.001590728759765625,
#   0.003818511962890625,
#   -0.01739501953125,
#   -0.002407073974609375,
#   0.006038665771484375,
#   0.002857208251953125,
#   -0.01149749755859375,
#   -0.007183074951171875,
#   -0.0017614364624023438,
#   -0.0176239013671875,
#   -0.0161895751953125,
#   0.019287109375,
#   0.0132904052734375,
#   -0.0168914794921875,
#   -0.00962066650390625,
#   -0.00799560546875,
#   -0.00962066650390625,
#   -0.0239715576171875,
#   -0.0224761962890625,
#   -0.016265869140625,
#   0.01270294189453125,
#   0.0143890380859375,
#   0.027252197265625,
#   0.01047515869140625,
#   -0.01149749755859375,
#   -0.00548553466796875,
#   0.00812530517578125,
#   0.006870269775390625,
#   -0.01560211181640625,
#   -0.0038242340087890625,
#   -0.00909423828125,
#   -0.0023288726806640625,
#   -0.00981903076171875,
#   -0.0003948211669921875,
#   -0.020721435546875,
#   -0.0176849365234375,
#   0.0011205673217773438,
#   -0.005893707275390625,
#   0.0030345916748046875,
#   0.006137847900390625,
#   0.01215362548828125,
#   0.007778167724609375,
#   0.0018243789672851562,
#   -0.007495880126953125,
#   0.007080078125,
#   0.02001953125,
#   0.0159759521484375,
#   0.0086517333984375,
#   0.021453857421875,
#   -0.020050048828125,
#   -0.0014171600341796875,
#   -0.0018548965454101562,
#   0.0146942138671875,
#   -0.012176513671875,
#   -0.0014715194702148438,
#   -0.0144195556640625,
#   -0.031494140625,
#   -0.00403594970703125,
#   0.01380157470703125,
#   -0.0030727386474609375,
#   -0.02386474609375,
#   0.01157379150390625,
#   0.0195770263671875,
#   -0.0084228515625,
#   0.0016298294067382812,
#   ...]]

# %% [markdown]
# ## 3. test set 갖고오기

# %%
# read samples.csv file
import pandas as pd

def read_data(data_path):
    data = pd.read_csv(data_path)
    prompts = data['prompts']
    answers = data['answers']
    # returns two lists: prompts and answers
    return prompts, answers

# %%
prompts, answers = read_data(os.path.join(data_path, 'test_own_ewha.csv'))
testdata = pd.read_csv(data_path+'test_own_ewha.csv')

# %%
nowtest = pd.DataFrame(columns=['index', 'embed_ques', 'question', 'prompts', 'answers', 'top1', 'top2', 'top3', 'top1_1pred','top1_2pred','top1_3pred', 'top2pred', 'top3pred', 'predict' ])

for index, row in testdata.iterrows():
    #if index % 100 != 0 : continue # 일단 실험할 땐 100개 단위로 끊어서 가져옴
    q = row.prompts
    a = row.answers
    question = q.partition('(A)')[0]
    question = question.partition(') ')[2]
    q = q.partition(') ')[2]
    try : 
        embedded_query = query_embeddings.embed_query(question) # 질문만 받아와서 embedding 하기
        nowtest.loc[len(nowtest)] = {'index':index, 'embed_ques' : embedded_query, 'question' : question, 'prompts' : q, 'answers' : a}

    except :
        print(f'pass: {index}')
        continue

# %%
nowtest
# Out:
#     index                                         embed_ques  \
# 0       0  [-0.005329132080078125, 0.0017337799072265625,...
# 1       1  [-0.00460052490234375, -0.0174713134765625, -0...
# 2       2  [0.007404327392578125, -0.0216522216796875, 0....
# 3       3  [-0.002162933349609375, -0.039215087890625, -0...
# 4       4  [0.0089111328125, -0.0259552001953125, -0.0064...
# 5       5  [0.0016117095947265625, -0.019683837890625, -0...
# 6       6  [-0.018157958984375, -0.0157318115234375, -0.0...
# 7       7  [0.0029163360595703125, -0.018707275390625, -0...
# 8       8  [-5.4895877838134766e-05, -0.01477813720703125...
# 9       9  [-0.002269744873046875, 0.0017795562744140625,...
# 10     10  [-0.0174560546875, -0.022064208984375, -0.0094...
# 11     11  [-0.003711700439453125, 0.005283355712890625, ...
# 12     12  [0.00012981891632080078, -0.01374053955078125,...
# 13     13  [-0.0191650390625, -0.0198516845703125, -0.027...
# 14     14  [-0.006168365478515625, -0.009368896484375, -0...
# 15     15  [-0.00464630126953125, -0.00894927978515625, -...
# 16     16  [0.00395965576171875, -0.0242156982421875, -0....
# 17     17  [-0.023773193359375, -0.012847900390625, -0.01...
# 18     18  [0.0045623779296875, -0.026580810546875, -0.01...
# 19     19  [0.0033092498779296875, -0.0141143798828125, 0...
# 20     20  [-0.0005626678466796875, -0.0136566162109375, ...
# 21     21  [-0.01462554931640625, -0.0188140869140625, -0...
# 22     22  [-0.00027251243591308594, -0.01363372802734375...
# 23     23  [0.00484466552734375, -0.00014400482177734375,...
# 24     24  [-0.0201263427734375, -0.01532745361328125, -0...
# 25     25  [0.01309967041015625, -0.0241546630859375, -0....
# 26     26  [0.01483154296875, -0.03533935546875, -0.00331...
# 27     27  [0.035247802734375, -0.0292510986328125, -0.02...
# 28     28  [0.00457763671875, -0.0146636962890625, -0.000...
# 29     29  [0.00870513916015625, -0.005367279052734375, -...
# 30     30  [-0.017486572265625, -0.029327392578125, -0.01...
# 31     31  [0.00934600830078125, -0.00826263427734375, -0...
# 32     32  [0.004810333251953125, -0.01242828369140625, -...
# 33     33  [-0.00408172607421875, -0.0066680908203125, -0...
# 34     34  [0.01059722900390625, 0.003986358642578125, -0...
# 35     35  [0.01451873779296875, -0.0285491943359375, -0....
# 36     36  [0.005802154541015625, -0.0128326416015625, -0...
# 37     37  [-0.0031147003173828125, -0.000395059585571289...
# 38     38  [-0.01178741455078125, -0.035858154296875, -0....
# 39     39  [-0.0184173583984375, -0.0208740234375, -0.007...
# 40     40  [-0.00659942626953125, 0.005962371826171875, -...
# 41     41  [0.0025501251220703125, -0.00481414794921875, ...
#
#                                              question  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...
# 1                 각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n
# 2           부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n
# 3               학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...
# 5           학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n
# 6    학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?\n
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...
# 9        학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까?\n
# 11     학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n
# 12   학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?\n
# 13      학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n
# 14          학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n
# 15    학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\n
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...
# 20    학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\n
# 21     학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...
# 25                             전공과 관련된 조항으로 올바른 것은?\n
# 26                         등록금에 관한 조항으로 올바르지 않은 것은?\n
# 27                                 전공과목은 어떻게 구분되는가?\n
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...
# 29                          학칙개정에 관한 설명으로 옳지 않은 것은?\n
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...
# 31                  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...
# 33       제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...
# 36               제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n
# 37          제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...
#
#                                               prompts answers  top1  top2  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...     (D)   NaN   NaN
# 1   각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n(A) 이학사\n(B...     (E)   NaN   NaN
# 2   부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n(A) 현...     (B)   NaN   NaN
# 3   학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n(A) 시험 직후...     (B)   NaN   NaN
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...     (C)   NaN   NaN
# 5   학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n(A) 서...     (D)   NaN   NaN
# 6   학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?...     (C)   NaN   NaN
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...     (D)   NaN   NaN
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...     (C)   NaN   NaN
# 9   학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n(A...     (B)   NaN   NaN
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까...     (B)   NaN   NaN
# 11  학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n...     (C)   NaN   NaN
# 12  학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?...     (B)   NaN   NaN
# 13  학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n(...     (E)   NaN   NaN
# 14  학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n(A) 신...     (A)   NaN   NaN
# 15  학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\...     (C)   NaN   NaN
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...     (E)   NaN   NaN
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...     (B)   NaN   NaN
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...     (C)   NaN   NaN
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...     (C)   NaN   NaN
# 20  학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\...     (C)   NaN   NaN
# 21  학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n...     (D)   NaN   NaN
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...     (B)   NaN   NaN
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...     (C)   NaN   NaN
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...     (B)   NaN   NaN
# 25  전공과 관련된 조항으로 올바른 것은?\n(A) 2 이상의 학부가 연계하여 제공하는 ...     (B)   NaN   NaN
# 26  등록금에 관한 조항으로 올바르지 않은 것은?\n(A) 총장은 등록금심의위원회의 구성...     (E)   NaN   NaN
# 27  전공과목은 어떻게 구분되는가?\n(A) 전공기초과목과 전공과목\n(B) 총장이 따로...     (C)   NaN   NaN
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...     (D)   NaN   NaN
# 29  학칙개정에 관한 설명으로 옳지 않은 것은?\n(A) 학칙 개정과 대학평의원회는 무관...     (A)   NaN   NaN
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...     (B)   NaN   NaN
# 31  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n(A) 학칙 개정은 사전...     (C)   NaN   NaN
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...     (A)   NaN   NaN
# 33  제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n(A...     (C)   NaN   NaN
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...     (D)   NaN   NaN
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...     (D)   NaN   NaN
# 36  제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n(A) 입학 전형은...     (B)   NaN   NaN
# 37  제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n(A) 입...     (B)   NaN   NaN
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...     (A)   NaN   NaN
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...     (A)   NaN   NaN
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...     (B)   NaN   NaN
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...     (A)   NaN   NaN
#
#     top3  top1_1pred  top1_2pred  top1_3pred  top2pred  top3pred  predict
# 0    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 1    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 2    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 3    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 4    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 5    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 6    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 7    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 8    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 9    NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 10   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 11   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 12   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 13   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 14   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 15   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 16   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 17   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 18   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 19   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 20   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 21   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 22   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 23   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 24   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 25   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 26   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 27   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 28   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 29   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 30   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 31   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 32   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 33   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 34   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 35   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 36   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 37   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 38   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 39   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 40   NaN         NaN         NaN         NaN       NaN       NaN      NaN
# 41   NaN         NaN         NaN         NaN       NaN       NaN      NaN

# %% [markdown]
# ## 4. Prompt engineering

# %%
import numpy as np


for idx, row in nowtest.iterrows() : # 질문 받아오기 

    embed_ques= row.embed_ques

    # 유사도 기준 내림차순 정렬
    sorted_idx = (np.array(embed_ques) @ np.array(ewhaDB_embed).T).argsort()[::-1]

    nowtest.loc[idx, 'top1'] = ewhaDB[sorted_idx[0]]
    nowtest.loc[idx, 'top2'] = ewhaDB[sorted_idx[1]]
    nowtest.loc[idx, 'top3'] = ewhaDB[sorted_idx[2]]
# Out:
# /tmp/ipykernel_3887407/3603593849.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 1996.2.15., 2017.2.8.)
# ② 학점취득특별시험의 방법, 종류에 관한 세부 사항은 총장이 따로 정한다. (개정
# 2001.9.24)제35조의3(학점의 인정) ① 다음 각 호의 경우에 취득한 학점은 총장의 승인을 얻어 졸업에
# 필요한 학점의 2분의 1의 범위 안에서 이를 본교에서 취득한 것으로 본다. (개정
# 2012.12.31.)1. 재학 중 국내외의 다른 학교에서 학점을 취득한 경우
# 2. 입학 전 국내외의 고등학교와 「고등교육법」 제2조 각 호의 학교에서 대학교육과정에 상
# 당하는 교과목을 이수한 경우
# ② 학점의 인정범위 등 제1항의 시행에 필요한 사항은 총장이 따로 정한다. (개정
# 1998.6.23)③ 삭제 (1998.6.23.)제35조의4(언어교육원 수강과목 학점의 인정) 입학 전 본교 언어교육원에서 소정의 과정을 이
# 수한 경우 입학 후 대학의 학점으로 인정할 수 있다. 학점인정대상자 및 범위' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, 'top1'] = ewhaDB[sorted_idx[0]]
# /tmp/ipykernel_3887407/3603593849.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제32조(교과목의 분류) 본교의 교과는 교양과목, 전공기초과목 및 전공과목으로 구분한다.(개정 2011.4.15., 2016.2.16.)
# 제33조(교양과목) 교양과목의 종류와 학점은 총장이 따로 정한다. (개정 1996.2.15)
# 제33조의2 삭제 (2016.2.16.)
# 제34조(전공과목) 전공과목은 필수과목과 선택과목으로 구분하되, 각각 그 종류와 학점은 소속 대학장의 제청에 의하여 총장이 따로 정한다. (개정 1985.3.5)
# 제35조(학점) 교과과정이수의 단위는 학점으로 하되, 1학기간 15시간 이상의 수업을 1학점으
# 로 한다. (개정 1999.2.9)이화여자대학교 학칙제35조의2(학점취득의 특례) ① 교양과목과 전공기초과목 중 특정교과목은 이를 수강하지 아
# 니하여도 학점취득특별시험에 의하여 학기당 최대취득학점 외에 학점을 취득할 수 있으며,그 학점수는 12학점을 초과할 수 없다. (개정 1996.2' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, 'top2'] = ewhaDB[sorted_idx[1]]
# /tmp/ipykernel_3887407/3603593849.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4)제29조 삭제 (1987.9.1)
# 제30조(자퇴) 자퇴하고자 하는 자는 보증인이 연서한 자퇴원을 제출하여 총장의 허가를 얻어야 한다. (개정 2017.8.16.)제31조(재입학) ① 제28조제1호 부터 제4호까지에 따라 제적된 자 및 제30조에 의하여 자퇴
# 한 자에게는 소속 대학장의 제청에 의하여 총장이 그 정상을 참작하여 정원의 결원이 있을
# 때에 재입학을 허가할 수 있다. (개정 2008.8.19., 2017.8.16.)
# ② 재입학은 1회에 한하여 할 수 있다. 다만, 제28조제4호에 의하여 제적된 자는 제적된
# 날부터 1년이 경과한 후 재입학할 수 있다. (개정 2008.8.19)제31조의2(법령 등에 의한 재입학의 특례) 법령이나 법령에 근거한 처분 또는 권고 등에 의
# 하여 재입학을 인정할 필요가 있는 경우에는 총장은 제31조의 규정에 불구하고 재입학을
# 허가할 수 있다.
# [본조신설 2005.6.17.]제9장 교육과정, 이수, 수료 및 졸업 (개정 2015.2.6.)제32조(교' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, 'top3'] = ewhaDB[sorted_idx[2]]

# %%
try : del [[bagging_pred]]
except : pass
bagging_pred = pd.DataFrame(columns=['questionNum', 'answer', 'top1_1pred', 'top1_2pred', 'top1_3pred', 'top2pred', 'top3pred', 'predict'])

# %% [markdown]
# # --------------------qa_chain---------------------------

# %%
# # Step 4: Prompt Templates with One-Shot Example

# from langchain.prompts import PromptTemplate

# qa_prompt_template = """
#     You are an assistant with expertise in Ewha University policies and history. Use the provided context to answer accurately.

#     Context: {context}

#     Question: {question}

#     Final Answer:
# """

# # Prompt for context retrieval and feedback
# qa_prompt = PromptTemplate(input_variables=["context", "query"], template=qa_prompt_template)



# # FAISS 벡터 스토어 생성
# vector_store = FAISS.from_embeddings(
#     text_embeddings=text_embedding_pairs,  # 텍스트-임베딩 쌍 리스트
#     embedding=embeddings  # Embeddings 객체 전달
# )


# # Step 5: RAG-based QA System
# retriever = vector_store.as_retriever(search_kwargs={"k": 5})
# qa_chain = RetrievalQA.from_chain_type(
#     llm=llm,
#     retriever=retriever,
#     chain_type="stuff",  # "stuff" processes all context at once
#     chain_type_kwargs={"prompt": qa_prompt}  # Pass custom prompt
# )

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

llm = ChatUpstage(
    api_key=api_key,
    temperature=0, 
    max_tokens=2048,
    top_p=0.0,
    frequency_penalty=0.0,
    presence_penalty=0.0
)


prompt_template = PromptTemplate.from_template(
    '''
    You are an assistant with expertise in Ewha University policies and history. Use the provided context to answer accurately.

    Context: {context}

    Question: {question}

    Final Answer:
        
    '''

)

qa_chain = prompt_template | llm

# %%
############# PREDICTION ##########

for idx, row in nowtest.iterrows() :
    #if idx == 50 : break
        
    response = qa_chain.invoke({"question": row.prompts, "context": row.top1})

    if isinstance(response, dict): answer_text = response.get('content', response.get('text', str(response)))
    else: answer_text = str(response)

    nowtest.loc[idx, 'top1pred'] = answer_text.strip()
    generated_answer = extract_answer(answer_text.strip())
    bagging_pred.loc[len(bagging_pred)] = {'questionNum': row.question, 'answer': row.answers, 'top1_1pred': generated_answer}

#
    context = row.top1 + ' ' + row.top2
    response = qa_chain.invoke({"question": row.prompts, "context": context})

    if isinstance(response, dict): answer_text = response.get('content', response.get('text', str(response)))
    else: answer_text = str(response)

    nowtest.loc[idx, 'top2pred'] = answer_text.strip()
    generated_answer = extract_answer(answer_text.strip())
    bagging_pred.loc[idx, f'top2pred'] = generated_answer

#
    context = row.top1 + ' ' + row.top2 + ' ' + row.top3
    response = qa_chain.invoke({"question": row.prompts, "context": context})

    if isinstance(response, dict): answer_text = response.get('content', response.get('text', str(response)))
    else: answer_text = str(response)

    nowtest.loc[idx, 'top3pred'] = answer_text.strip()
    generated_answer = extract_answer(answer_text.strip())
    bagging_pred.loc[idx, f'top3pred'] = generated_answer



for i in range(2,4) : 
    for idx, row in nowtest.iterrows() :
        #if idx == 50 : break
            
        response = qa_chain.invoke({"question": row.prompts, "context": row.top1})

        if isinstance(response, dict): answer_text = response.get('content', response.get('text', str(response)))
        else: answer_text = str(response)

        nowtest.loc[idx, f'top1_{i}pred'] = answer_text.strip()
        generated_answer = extract_answer(answer_text.strip())
        bagging_pred.loc[idx, f'top1_{i}pred'] = generated_answer
# Out:
# /tmp/ipykernel_3887407/409691007.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'content='(D) 3학점' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 751, 'total_tokens': 759, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-240612', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-441d2295-e5d6-4698-94c3-1b775a1c83c0-0' usage_metadata={'input_tokens': 751, 'output_tokens': 8, 'total_tokens': 759, 'input_token_details': {}, 'output_token_details': {}}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, 'top2pred'] = answer_text.strip()
# /tmp/ipykernel_3887407/409691007.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'D' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   bagging_pred.loc[idx, f'top2pred'] = generated_answer
# /tmp/ipykernel_3887407/409691007.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'content='(D) 3학점' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 1075, 'total_tokens': 1083, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-240612', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-de5bbd54-f350-4a1c-9e80-ac50e8f8bfe3-0' usage_metadata={'input_tokens': 1075, 'output_tokens': 8, 'total_tokens': 1083, 'input_token_details': {}, 'output_token_details': {}}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, 'top3pred'] = answer_text.strip()
# /tmp/ipykernel_3887407/409691007.py:35: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'D' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   bagging_pred.loc[idx, f'top3pred'] = generated_answer
# /tmp/ipykernel_3887407/409691007.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'content='(A) 인정 안됨\n\n해설:\n주어진 문맥에서는 영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우에 대한 학점 인정에 대한 언급이 없습니다. 따라서 주어진 옵션 중 어느 것도 정답이 아닙니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 408, 'total_tokens': 461, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-240612', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-66015876-392a-4101-8510-04597af363a7-0' usage_metadata={'input_tokens': 408, 'output_tokens': 53, 'total_tokens': 461, 'input_token_details': {}, 'output_token_details': {}}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, f'top1_{i}pred'] = answer_text.strip()
# /tmp/ipykernel_3887407/409691007.py:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   bagging_pred.loc[idx, f'top1_{i}pred'] = generated_answer
# /tmp/ipykernel_3887407/409691007.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'content='(A) 인정 안됨\n\n해설:\n주어진 문맥에서는 영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우에 대한 학점 인정에 대한 언급이 없습니다. 따라서 주어진 옵션 중 어느 것도 정답이 아닙니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 408, 'total_tokens': 462, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-240612', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-27d05867-8efd-480a-ae13-2054b605777a-0' usage_metadata={'input_tokens': 408, 'output_tokens': 54, 'total_tokens': 462, 'input_token_details': {}, 'output_token_details': {}}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nowtest.loc[idx, f'top1_{i}pred'] = answer_text.strip()
# /tmp/ipykernel_3887407/409691007.py:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   bagging_pred.loc[idx, f'top1_{i}pred'] = generated_answer

# %% [markdown]
# # --------------------------------------------------

# %%
bagging_pred
# Out:
#                                           questionNum answer top1_1pred  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...    (D)          A
# 1                 각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n    (E)          E
# 2           부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n    (B)          B
# 3               학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n    (B)          B
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...    (C)          D
# 5           학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n    (D)          D
# 6    학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?\n    (C)          C
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...    (D)          A
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...    (C)          D
# 9        학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n    (B)          B
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까?\n    (B)          D
# 11     학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n    (C)          C
# 12   학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?\n    (B)          B
# 13      학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n    (E)          C
# 14          학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n    (A)          A
# 15    학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\n    (C)          C
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...    (E)          E
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...    (B)          B
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...    (C)          C
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...    (C)          B
# 20    학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\n    (C)          C
# 21     학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n    (D)          D
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...    (B)          B
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...    (C)          C
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...    (B)          B
# 25                             전공과 관련된 조항으로 올바른 것은?\n    (B)          B
# 26                         등록금에 관한 조항으로 올바르지 않은 것은?\n    (E)          E
# 27                                 전공과목은 어떻게 구분되는가?\n    (C)          C
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...    (D)          D
# 29                          학칙개정에 관한 설명으로 옳지 않은 것은?\n    (A)          C
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...    (B)          E
# 31                  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n    (C)          C
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...    (A)          A
# 33       제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n    (C)          D
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...    (D)          C
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...    (D)          C
# 36               제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n    (B)          B
# 37          제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n    (B)          B
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...    (A)          C
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...    (A)       None
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...    (B)          F
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...    (A)          A
#
#    top1_2pred top1_3pred top2pred top3pred  predict
# 0           A          A        D        D      NaN
# 1           E          E        E        E      NaN
# 2           B          B        B        B      NaN
# 3           B          B        B        B      NaN
# 4           D          D        D        D      NaN
# 5           D          D        D        D      NaN
# 6           C          C        C        C      NaN
# 7           A          A        A        A      NaN
# 8           D          D        D        D      NaN
# 9           B          B        B        B      NaN
# 10          D          D        D        D      NaN
# 11          C          C        C        C      NaN
# 12          B          B        B        B      NaN
# 13          C          C        C        D      NaN
# 14          A          A        A        A      NaN
# 15          C          C        C        C      NaN
# 16          E          E        E        E      NaN
# 17          B          B        B        B      NaN
# 18          C          C        D        D      NaN
# 19          B          B        B        B      NaN
# 20          C          C        C        C      NaN
# 21          D          D        D        D      NaN
# 22          B          B        B        B      NaN
# 23          C          C        B        B      NaN
# 24          B          B        B        B      NaN
# 25          B          B        B        B      NaN
# 26          E          E        E        E      NaN
# 27          C          C        C        C      NaN
# 28          D          D        D        D      NaN
# 29          C          C        C        C      NaN
# 30          E          E        C        C      NaN
# 31          C          C        C        C      NaN
# 32          A          A        A        A      NaN
# 33          B          D        B        A      NaN
# 34          C          C        C        C      NaN
# 35          C          C        D        D      NaN
# 36          B          B        B        B      NaN
# 37          B          B        A        A      NaN
# 38          C          C        B        C      NaN
# 39       None       None        C     None      NaN
# 40          F          F        F        F      NaN
# 41          A          B        B        A      NaN

# %% [markdown]
# # bagging

# %%
from collections import Counter

final_pred = []
for idx, row in bagging_pred.iterrows() :

    pred = []
    pred.append(row.top1_1pred)
    pred.append(row.top1_2pred)
    pred.append(row.top1_3pred)
    pred.append(row.top2pred)
    pred.append(row.top3pred)

    counts = Counter(pred)

    prediction = counts.most_common(1)[0][0]
    if prediction == None :
        try : prediction = counts.most_common(2)[1][0]
        except : pass
    final_pred.append(prediction)
    bagging_pred.loc[idx, 'predict'] = prediction

# final_pred
# Out:
# /tmp/ipykernel_3887407/908629431.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   bagging_pred.loc[idx, 'predict'] = prediction

# %%
######### 정답 확인 + wrong 뽑아내기 ######

# print accuracy

cnt = 0
wrong = []
for idx, (answer, response) in enumerate(zip(answers, final_pred)):
    print("-"*10)
    generated_answer = extract_answer(response)
    print(response)
    # check
    if generated_answer:
        print(f"idx: {idx} | generated answer: {generated_answer}, answer: {answer}")
    else:
        print("extraction fail")

    if generated_answer == None:
        wrong.append(idx+1)
        bagging_pred.loc[idx, 'iswrong'] = '-'
        continue
    
    if generated_answer in answer:
        cnt += 1
    else : 
        wrong.append(idx+1)
        bagging_pred.loc[idx, 'iswrong'] = '-'
        
acc = cnt/len(answers)*100
print(f"acc: {acc}%")
print()
print("wrong:", wrong)
bagging_pred.loc[len(bagging_pred), 'predict'] = acc
# Out:
# ----------
# A
# idx: 0 | generated answer: A, answer: (D)
# ----------
# E
# idx: 1 | generated answer: E, answer: (E)
# ----------
# B
# idx: 2 | generated answer: B, answer: (B)
# ----------
# B
# idx: 3 | generated answer: B, answer: (B)
# ----------
# D
# idx: 4 | generated answer: D, answer: (C)
# ----------
# D
# idx: 5 | generated answer: D, answer:  (D)
# ----------
# C
# idx: 6 | generated answer: C, answer:  (C)
# ----------
# A
# idx: 7 | generated answer: A, answer:  (D)
# ----------
# D
# idx: 8 | generated answer: D, answer:  (C)
# ----------
# B
# idx: 9 | generated answer: B, answer:  (B)
# ----------
# D
# idx: 10 | generated answer: D, answer:  (B)
# ----------
# C
# idx: 11 | generated answer: C, answer:  (C)
# ----------
# B
# idx: 12 | generated answer: B, answer:  (B)
# ----------
# C
# idx: 13 | generated answer: C, answer:  (E)
# ----------
# A
# idx: 14 | generated answer: A, answer:  (A)
# ----------
# C
# idx: 15 | generated answer: C, answer:  (C)
# ----------
# E
# idx: 16 | generated answer: E, answer:  (E)
# ----------
# B
# idx: 17 | generated answer: B, answer:  (B)
# ----------
# C
# idx: 18 | generated answer: C, answer:  (C)
# ----------
# B
# idx: 19 | generated answer: B, answer:  (C)
# ----------
# C
# idx: 20 | generated answer: C, answer:  (C)
# ----------
# D
# idx: 21 | generated answer: D, answer:  (D)
# ----------
# B
# idx: 22 | generated answer: B, answer:  (B)
# ----------
# C
# idx: 23 | generated answer: C, answer:  (C)
# ----------
# B
# idx: 24 | generated answer: B, answer:  (B)
# ----------
# B
# idx: 25 | generated answer: B, answer:  (B)
# ----------
# E
# idx: 26 | generated answer: E, answer:  (E)
# ----------
# C
# idx: 27 | generated answer: C, answer:  (C)
# ----------
# D
# idx: 28 | generated answer: D, answer:  (D)
# ----------
# C
# idx: 29 | generated answer: C, answer:  (A)
# ----------
# E
# idx: 30 | generated answer: E, answer:  (B)
# ----------
# C
# idx: 31 | generated answer: C, answer:  (C)
# ----------
# A
# idx: 32 | generated answer: A, answer:  (A)
# ----------
# D
# idx: 33 | generated answer: D, answer:  (C)
# ----------
# C
# idx: 34 | generated answer: C, answer:  (D)
# ----------
# C
# idx: 35 | generated answer: C, answer:  (D)
# ----------
# B
# idx: 36 | generated answer: B, answer:  (B)
# ----------
# B
# idx: 37 | generated answer: B, answer:  (B)
# ----------
# C
# idx: 38 | generated answer: C, answer:  (A)
# ----------
# C
# idx: 39 | generated answer: C, answer:  (A)
# ----------
# F
# idx: 40 | generated answer: F, answer:  (B)
# ----------
# A
# idx: 41 | generated answer: A, answer:  (A)
# acc: 64.28571428571429%
#
# wrong: [1, 5, 8, 9, 11, 14, 20, 30, 31, 34, 35, 36, 39, 40, 41]

# %%
bagging_pred
# Out:
#                                           questionNum answer top1_1pred  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...    (D)          A
# 1                 각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n    (E)          E
# 2           부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n    (B)          B
# 3               학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n    (B)          B
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...    (C)          D
# 5           학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n    (D)          D
# 6    학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?\n    (C)          C
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...    (D)          A
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...    (C)          D
# 9        학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n    (B)          B
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까?\n    (B)          D
# 11     학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n    (C)          C
# 12   학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?\n    (B)          B
# 13      학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n    (E)          C
# 14          학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n    (A)          A
# 15    학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\n    (C)          C
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...    (E)          E
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...    (B)          B
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...    (C)          C
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...    (C)          B
# 20    학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\n    (C)          C
# 21     학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n    (D)          D
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...    (B)          B
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...    (C)          C
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...    (B)          B
# 25                             전공과 관련된 조항으로 올바른 것은?\n    (B)          B
# 26                         등록금에 관한 조항으로 올바르지 않은 것은?\n    (E)          E
# 27                                 전공과목은 어떻게 구분되는가?\n    (C)          C
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...    (D)          D
# 29                          학칙개정에 관한 설명으로 옳지 않은 것은?\n    (A)          C
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...    (B)          E
# 31                  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n    (C)          C
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...    (A)          A
# 33       제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n    (C)          D
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...    (D)          C
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...    (D)          C
# 36               제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n    (B)          B
# 37          제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n    (B)          B
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...    (A)          C
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...    (A)       None
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...    (B)          F
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...    (A)          A
# 42                                                NaN    NaN        NaN
#
#    top1_2pred top1_3pred top2pred top3pred    predict iswrong
# 0           A          A        D        D          A       -
# 1           E          E        E        E          E     NaN
# 2           B          B        B        B          B     NaN
# 3           B          B        B        B          B     NaN
# 4           D          D        D        D          D       -
# 5           D          D        D        D          D     NaN
# 6           C          C        C        C          C     NaN
# 7           A          A        A        A          A       -
# 8           D          D        D        D          D       -
# 9           B          B        B        B          B     NaN
# 10          D          D        D        D          D       -
# 11          C          C        C        C          C     NaN
# 12          B          B        B        B          B     NaN
# 13          C          C        C        D          C       -
# 14          A          A        A        A          A     NaN
# 15          C          C        C        C          C     NaN
# 16          E          E        E        E          E     NaN
# 17          B          B        B        B          B     NaN
# 18          C          C        D        D          C     NaN
# 19          B          B        B        B          B       -
# 20          C          C        C        C          C     NaN
# 21          D          D        D        D          D     NaN
# 22          B          B        B        B          B     NaN
# 23          C          C        B        B          C     NaN
# 24          B          B        B        B          B     NaN
# 25          B          B        B        B          B     NaN
# 26          E          E        E        E          E     NaN
# 27          C          C        C        C          C     NaN
# 28          D          D        D        D          D     NaN
# 29          C          C        C        C          C       -
# 30          E          E        C        C          E       -
# 31          C          C        C        C          C     NaN
# 32          A          A        A        A          A     NaN
# 33          B          D        B        A          D       -
# 34          C          C        C        C          C       -
# 35          C          C        D        D          C       -
# 36          B          B        B        B          B     NaN
# 37          B          B        A        A          B     NaN
# 38          C          C        B        C          C       -
# 39       None       None        C     None          C       -
# 40          F          F        F        F          F       -
# 41          A          B        B        A          A     NaN
# 42        NaN        NaN      NaN      NaN  64.285714     NaN

# %%
#bagging_pred.to_csv(results_path+'ewha_bagging_alpha02.csv')
