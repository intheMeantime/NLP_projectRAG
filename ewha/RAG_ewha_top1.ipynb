# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/UpstageAI/cookbook/blob/main/cookbooks/upstage/Solar-Full-Stack LLM-101/05_3_OracleDB.ipynb">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Retrieval Augmented Generation (RAG) Baseline
# ## Overview
# In this time, we will check the baseline code.
# The goal of this project is to provide students with hands-on experience in handling and enhancing Large Language Models (LLMs) provided by [**Upstage**](https://www.upstage.ai) (Solar).
#
# You can use any engineering method for improving benchmark performance excluding direct training (Fine-tuning).
#
# *Collecting data directly related to the test set is considered cheating e.g., using MMLU-pro dataset or EWHA.pdf for KB*

# %% [markdown]
# # Baseline

# %%
#!pip3 install -qU python-dotenv PyPDF2 langchain langchain-community langchain-core langchain-text-splitters langchain_upstage oracledb python-dotenv

# %%
# Additional Contents : https://wikidocs.net/253106

# %%
# set parameters

file = open("info/api.txt", "r")
api_key = file.read()
file.close()

file = open("info/datapath.txt", "r")
data_path = file.read()
file.close()

file = open("info/resultspath.txt", "r")
results_path = file.read()
file.close()

# %%
from langchain_upstage import UpstageEmbeddings

# 쿼리 전용 임베딩 모델
query_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-query")

# 문장 전용 임베딩 모델
passage_embeddings = UpstageEmbeddings(api_key=api_key, model="solar-embedding-1-large-passage")

# %%
# funcion to extract an answer from response

import re

def extract_answer(response):
    """
    extracts the answer from the response using a regular expression.
    expected format: "[ANSWER]: (A) convolutional networks"

    if there are any answers formatted like the format, it returns None.
    """
    pattern = r"\[ANSWER\]:\s*\((A|B|C|D|E)\)"  # Regular expression to capture the answer letter and text
    match = re.search(pattern, response)

    if match:
        return match.group(1) # Extract the letter inside parentheses (e.g., A)
    else:
        return extract_again(response)

def extract_again(response):
    pattern = r"\b[A-J]\b(?!.*\b[A-J]\b)"
    match = re.search(pattern, response)
    if match:
        return match.group(0)
    else:
        return None

# %% [markdown]
# ## 1. build DB

# %%
from langchain_upstage import UpstageLayoutAnalysisLoader
import os
import numpy as np


UPSTAGE_API_KEY = api_key

# .npy 파일 로드 (타입==넘파이)
ewhaDB = np.load(data_path+f'embedding/full_ewha500.npy')

ewhaDB_embed = np.load(data_path+f'embedding/full_ewha500_embed.npy')
ewhaDB_embed = ewhaDB_embed.tolist()

# %% [markdown]
# ## 2. Text Split

# %% [markdown]
# ## 3. query-context matching

# %%
# read samples.csv file
import pandas as pd

def read_data(data_path):
    data = pd.read_csv(data_path)
    prompts = data['prompts']
    answers = data['answers']
    # returns two lists: prompts and answers
    return prompts, answers

# %%
prompts, answers = read_data(os.path.join(data_path, 'test_own_ewha.csv'))

# %%
testdata = pd.read_csv(data_path+'test_own_ewha.csv')

# %%
nowtest = pd.DataFrame(columns=['index', 'embed_ques', 'question', 'prompts', 'answers', 'top1', 'top2', 'top3', 'predict', 'ground' ])

for index, row in testdata.iterrows():
    #if index % 100 != 0 : continue # 일단 실험할 땐 100개 단위로 끊어서 가져옴
    q = row.prompts
    a = row.answers
    question = q.partition('(A)')[0]
    question = question.partition(') ')[2]
    q = q.partition(') ')[2]
    try : 
        embedded_query = passage_embeddings.embed_query(question) # 질문만 받아와서 embedding 하기
        nowtest.loc[len(nowtest)] = {'index':index, 'embed_ques' : embedded_query, 'question' : question, 'prompts' : q, 'answers' : a, 'top1': None, 'top2': None, 'top3': None, 'predict': None, 'gound': None }

    except :
        print(f'pass: {index}')
        continue

# %%
nowtest
# Out:
#     index                                         embed_ques  \
# 0       0  [-0.005329132080078125, 0.0017337799072265625,...
# 1       1  [-0.00460052490234375, -0.0174713134765625, -0...
# 2       2  [0.007404327392578125, -0.0216522216796875, 0....
# 3       3  [-0.002162933349609375, -0.039215087890625, -0...
# 4       4  [0.0089111328125, -0.0259552001953125, -0.0064...
# 5       5  [0.0016117095947265625, -0.019683837890625, -0...
# 6       6  [-0.018157958984375, -0.0157318115234375, -0.0...
# 7       7  [0.0029163360595703125, -0.018707275390625, -0...
# 8       8  [-5.4895877838134766e-05, -0.01477813720703125...
# 9       9  [-0.002269744873046875, 0.0017795562744140625,...
# 10     10  [-0.0174560546875, -0.022064208984375, -0.0094...
# 11     11  [-0.0036525726318359375, 0.005313873291015625,...
# 12     12  [0.00012981891632080078, -0.01374053955078125,...
# 13     13  [-0.0191650390625, -0.0198516845703125, -0.027...
# 14     14  [-0.006168365478515625, -0.009368896484375, -0...
# 15     15  [-0.00464630126953125, -0.00894927978515625, -...
# 16     16  [0.00395965576171875, -0.0242156982421875, -0....
# 17     17  [-0.023773193359375, -0.012847900390625, -0.01...
# 18     18  [0.0045623779296875, -0.026580810546875, -0.01...
# 19     19  [0.0032901763916015625, -0.0141448974609375, 0...
# 20     20  [-0.0005626678466796875, -0.0136566162109375, ...
# 21     21  [-0.01462554931640625, -0.0188140869140625, -0...
# 22     22  [-0.00027251243591308594, -0.01363372802734375...
# 23     23  [0.00484466552734375, -0.00014400482177734375,...
# 24     24  [-0.0201263427734375, -0.01532745361328125, -0...
# 25     25  [0.01309967041015625, -0.0241546630859375, -0....
# 26     26  [0.01483154296875, -0.03533935546875, -0.00331...
# 27     27  [0.035247802734375, -0.0292510986328125, -0.02...
# 28     28  [0.00457763671875, -0.0146636962890625, -0.000...
# 29     29  [0.00870513916015625, -0.005367279052734375, -...
# 30     30  [-0.017486572265625, -0.029327392578125, -0.01...
# 31     31  [0.00934600830078125, -0.00826263427734375, -0...
# 32     32  [0.004810333251953125, -0.01242828369140625, -...
# 33     33  [-0.00408172607421875, -0.0066680908203125, -0...
# 34     34  [0.01059722900390625, 0.003986358642578125, -0...
# 35     35  [0.01451873779296875, -0.0285491943359375, -0....
# 36     36  [0.005802154541015625, -0.0128326416015625, -0...
# 37     37  [-0.0031147003173828125, -0.000395059585571289...
# 38     38  [-0.01178741455078125, -0.035858154296875, -0....
# 39     39  [-0.0184173583984375, -0.0208740234375, -0.007...
# 40     40  [-0.00659942626953125, 0.005962371826171875, -...
# 41     41  [0.0025501251220703125, -0.00481414794921875, ...
#
#                                              question  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...
# 1                 각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n
# 2           부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n
# 3               학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...
# 5           학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n
# 6    학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?\n
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...
# 9        학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까?\n
# 11     학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n
# 12   학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?\n
# 13      학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n
# 14          학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n
# 15    학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\n
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...
# 20    학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\n
# 21     학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...
# 25                             전공과 관련된 조항으로 올바른 것은?\n
# 26                         등록금에 관한 조항으로 올바르지 않은 것은?\n
# 27                                 전공과목은 어떻게 구분되는가?\n
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...
# 29                          학칙개정에 관한 설명으로 옳지 않은 것은?\n
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...
# 31                  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...
# 33       제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...
# 36               제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n
# 37          제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...
#
#                                               prompts answers  top1  top2  \
# 0   영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학...     (D)  None  None
# 1   각 대학에 따른 학위의 종류로 해당하지 않는 것은 무엇인가?\n(A) 이학사\n(B...     (E)  None  None
# 2   부칙에 학과명 변경 및 폐과된 학과는 무엇에 의해 언제까지 존속하는가?\n(A) 현...     (B)  None  None
# 3   학생 포털에서 본인의 성적을 조회할 수 있는 시기는 언제입니까?\n(A) 시험 직후...     (B)  None  None
# 4   학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 무엇입...     (C)  None  None
# 5   학칙 제3조에서 명시된 본교의 주소에 포함되지 않는 요소는 무엇입니까?\n(A) 서...     (D)  None  None
# 6   학칙 제12조(휴업일)에서 임시휴업을 결정할 수 있는 근거로 인정되지 않는 경우는?...     (C)  None  None
# 7   학칙 제23조(수업연한)에 따르면 건축학과와 약학대학의 수업연한이 다른 이유로 올바...     (D)  None  None
# 8   학칙 제26조(휴학)에서 규정된 휴학의 최대 연장 가능 기간을 초과하는 경우가 아닌...     (C)  None  None
# 9   학칙 제50조(졸업)에서 복수전공 이수자가 요구되는 추가 조건은 무엇입니까?\n(A...     (B)  None  None
# 10   학칙 제39조(성적)에 따라 다음 중 성적이 F로 처리되지 않는 경우는 무엇입니까...     (B)  None  None
# 11  학칙 제47조(전공)에서 융합전공의 설계 기준으로 옳지 않은 설명은 무엇입니까?\n...     (C)  None  None
# 12  학칙 제28조(제적)에 따라 다음 중 제적 사유로 포함되지 않는 경우는 무엇입니까?...     (B)  None  None
# 13  학칙 제12조(휴업일)에서 명시된 정기휴업일에 해당하지 않는 날은 무엇입니까?\n(...     (E)  None  None
# 14  학칙 제26조에 따라 휴학을 신청할 수 없는 학생의 조건은 무엇입니까?\n(A) 신...     (A)  None  None
# 15  학칙 제35조(학점) 기준에 따라 한 학점으로 인정되는 수업 시간의 최소 기준은?\...     (C)  None  None
# 16  학칙 제1조(목적)에서 이화여자대학교의 설립 정신에 기반한 교육 이념으로 올바르지 ...     (E)  None  None
# 17  학칙 제5조(입학정원)에 따르면 모집단위별 통합 모집이 가능한 조건으로 옳지 않은 ...     (B)  None  None
# 18  학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는...     (C)  None  None
# 19  학칙 제45조(취득학점)에 따라 직전 학기 평균성적 3.75 이상을 받은 학생이 한...     (C)  None  None
# 20  학칙 제28조(제적)에 따라 다음 중 제적 사유에 포함되지 않는 것은 무엇입니까?\...     (C)  None  None
# 21  학칙 제12조(휴업일)에서 다음 중 정기휴업일로 포함되지 않는 날은 무엇입니까?\n...     (D)  None  None
# 22  학칙 제50조(졸업)에 따라 스크랜튼학부 자유전공 입학생의 졸업 요건으로 올바른 설...     (B)  None  None
# 23  학칙 제45조(취득학점)에 따라 다음 중 의과대학 의학과 학생이 한 학기에 취득할 ...     (C)  None  None
# 24  학칙 제59조(징계)에서 '유기정학' 처분이 내려질 수 있는 조건으로 옳은 것은 무...     (B)  None  None
# 25  전공과 관련된 조항으로 올바른 것은?\n(A) 2 이상의 학부가 연계하여 제공하는 ...     (B)  None  None
# 26  등록금에 관한 조항으로 올바르지 않은 것은?\n(A) 총장은 등록금심의위원회의 구성...     (E)  None  None
# 27  전공과목은 어떻게 구분되는가?\n(A) 전공기초과목과 전공과목\n(B) 총장이 따로...     (C)  None  None
# 28  빈칸에 들어갈 말로 알맞은 말을 고르시오: 졸업은 ___와 ___로 구분하고, 그 ...     (D)  None  None
# 29  학칙개정에 관한 설명으로 옳지 않은 것은?\n(A) 학칙 개정과 대학평의원회는 무관...     (A)  None  None
# 30  다음 중 2018학년도 인문과학대학 기독교학과와 엘텍공과대학 휴먼기계바이오공학부의 ...     (B)  None  None
# 31  다음 중 '학칙 개정'에 관한 내용으로 옳지 않은 것은?\n(A) 학칙 개정은 사전...     (C)  None  None
# 32  \n제10장 '학생활동'의 규정에 따라 올바르게 매칭된 내용을 모두 고른 것은 무엇...     (A)  None  None
# 33  제48조의4와 제48조의5의 규정에 대한 설명으로 옳지 않은 것은 무엇인가?\n(A...     (C)  None  None
# 34  다음은 제47조의 전공 유형에 관한 규정이다. 이에 대한 설명으로 올바르게 매칭된 ...     (D)  None  None
# 35  다음은 제26조(휴학)에 관한 규정입니다. 아래 각 사례가 규정에 따라 허용될 수 ...     (D)  None  None
# 36  제17조(입학전형)에 관한 설명으로 옳지 않은 것은 무엇인가?\n(A) 입학 전형은...     (B)  None  None
# 37  제17조의2(입학전형관리위원회 등)에 관한 설명으로 가장 적절한 것은?\n(A) 입...     (B)  None  None
# 38  1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학...     (A)  None  None
# 39  2018학년도에 인문과학대학, 자연과학대학, 공과대학, 음악대학의 입학정원을 합산한...     (A)  None  None
# 40  학생 A는 수강신청을 승인받은 교과목에 대해 다음과 같은 행동을 취했습니다:\n첫 ...     (B)  None  None
# 41  학생 A는 졸업을 위해 다음과 같은 학점을 취득했습니다:\n제1전공: 85학점\n제...     (A)  None  None
#
#     top3 predict  ground
# 0   None    None     NaN
# 1   None    None     NaN
# 2   None    None     NaN
# 3   None    None     NaN
# 4   None    None     NaN
# 5   None    None     NaN
# 6   None    None     NaN
# 7   None    None     NaN
# 8   None    None     NaN
# 9   None    None     NaN
# 10  None    None     NaN
# 11  None    None     NaN
# 12  None    None     NaN
# 13  None    None     NaN
# 14  None    None     NaN
# 15  None    None     NaN
# 16  None    None     NaN
# 17  None    None     NaN
# 18  None    None     NaN
# 19  None    None     NaN
# 20  None    None     NaN
# 21  None    None     NaN
# 22  None    None     NaN
# 23  None    None     NaN
# 24  None    None     NaN
# 25  None    None     NaN
# 26  None    None     NaN
# 27  None    None     NaN
# 28  None    None     NaN
# 29  None    None     NaN
# 30  None    None     NaN
# 31  None    None     NaN
# 32  None    None     NaN
# 33  None    None     NaN
# 34  None    None     NaN
# 35  None    None     NaN
# 36  None    None     NaN
# 37  None    None     NaN
# 38  None    None     NaN
# 39  None    None     NaN
# 40  None    None     NaN
# 41  None    None     NaN

# %% [markdown]
# ## 4. Prompt engineering

# %%
try : del [[wrongdf]]
except : pass
wrongdf = pd.DataFrame(columns=['questionNum', 'answer', '1st_pred', '2nd_pred'])

# %%
############# first PREDICTION ##########

from langchain_core.prompts import PromptTemplate
from langchain_upstage import ChatUpstage

 
llm = ChatUpstage(api_key = api_key)

prompt_template = PromptTemplate.from_template(
    '''
    
    You are an assistant with expertise in Ewha University policies and history. Use the provided context to answer accurately.
    Let's think step by step.

    Context: {context}

    Question: {question}

    Final Answer:
        
    '''

)
chain1 = prompt_template | llm

# %%
import numpy as np

responses = []
for idx, row in nowtest.iterrows() : # 질문 받아오기 

    embed_ques= row.embed_ques

    # 유사도 기준 내림차순 정렬
    sorted_idx = (np.array(embed_ques) @ np.array(ewhaDB_embed).T).argsort()[::-1]

    nowtest.loc[idx, 'top1'] = ewhaDB[sorted_idx[0]]
    nowtest.loc[idx, 'top2'] = ewhaDB[sorted_idx[1]]
    nowtest.loc[idx, 'top3'] = ewhaDB[sorted_idx[2]]

    response = chain1.invoke({"question": row.prompts, "context": ewhaDB[sorted_idx[0]]}) # top1에 대해서는 바로 답변 출력
    responses.append(response.content)

    nowtest.loc[idx, 'predict'] = response.content

responses
# Out:
# ['영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학점에 대한 정보는 제공된 문맥에서 명시적으로 언급되지 않았습니다. 따라서 주어진 선택지 (A) 인정 안됨, (B) 1학점, (C) 2학점, (D) 3학점 중 어느 것도 최종 답변으로 선택할 수 없습니다.',
#  '(E) 인공지능학사',
#  '(B) 구 학칙에 의하여 재학생이 졸업하는 연도까지 존속한다',
#  'B',
#  '학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 (D) 학술의 응용방법 연구입니다.',
#  '(D) 강남구',
#  '(C) 학생총회 요청',
#  '(A) 건축학과는 추가 설계 실습을 포함하므로 더 긴 연한이 필요하다.',
#  '(D) 해외 봉사로 인한 휴학: 3년',
#  "(B) 전공별 종합시험 합격\n\nStep-by-step justification:\n\n1. The provided context refers to Ewha University's policies and history, particularly focusing on the classification of courses, types of credit hours, and other academic requirements.\n2. The question asks for the additional condition required by a double major student as mentioned in Article 50 (Graduation) of the school regulations.\n3. To answer this question accurately, I need to find the relevant information within the provided context.\n4. I found in the context that Article 35-2 (Special Cases for Credit Acquisition) mentions that specific subjects in liberal arts and major foundation subjects can be taken by a special examination for credit acquisition, but it does not provide information about the additional condition required by a double major student.\n5. Therefore, I need to look for Article 50 (Graduation) in the context to find the additional condition required by a double major student.\n6. After reviewing the context, I could not find Article 50 (Graduation), so I need to search for it in the full regulations.\n7. In the full regulations, I found that Article 50 (Graduation) does not explicitly mention the additional condition required by a double major student.\n8. However, in the context, I found that Article 34 (Major Subjects) mentions that major subjects are divided into required and elective subjects, and each type and credit hours are separately determined by the President upon the recommendation of the dean of the relevant college.\n9. This implies that a double major student would need to complete both sets of required and elective subjects for each major, which would be the additional condition required by a double major student.\n10. Therefore, the final answer is (B) Passing the Comprehensive Examination for Each Major.",
#  '(D) 교과목 담당교수의 허가 없이 수강 취소\n\n성적 F는 휴학 중이거나, 수업 시간의 6분의 1 이상 결석, 중간시험 및 기말시험 미응시, 과제 제출 기한 초과, 시험 부정행위 등의 경우에 처리됩니다. 그러나 교과목 담당교수의 허가 없이 수강을 취소한 경우, 성적이 F로 처리되지 않습니다.',
#  '(C) 독립된 학과로 운영된다.\n\n설명:\n학칙 제47조(전공)의 맥락에서 Ewha Womans University는 학생들이 융합전공을 설계할 수 있는 옵션을 제공하지만, 이는 독립된 학과로 운영되지 않습니다. 대신, 학생들은 제1전공을 기반으로 하고, 관련 학문 분야를 융합하며, 총장의 승인을 받아야 합니다. 또한, 최소 21학점의 취득이 요구되며, 융복합 연구과정이 포함되어야 합니다.',
#  '(B) 연속 2회 학사경고를 받은 경우',
#  '정기휴업일에 해당하지 않는 날은 (E) 종강일입니다.',
#  '(A) 신입생 첫 학기',
#  '(C) 15시간 이상',
#  '(E) 특정 종교 교리 확립',
#  '(B) 통합된 모집단위는 대학장이 결정한다.\n\nStep 1: 학칙 제5조(입학정원)을 확인합니다.\n- 해당 조항에 따르면, 모집단위별 통합 모집은 입학정원의 일부를 통합 모집할 수 있으며, 전공 결정은 일정 학점 이수 후 이루어집니다.\n\nStep 2: 학칙 제18조(입학허가)를 확인합니다.\n- 해당 조항에 따르면, 입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가합니다.\n\nStep 3: 학칙에서 통합된 모집단위를 대학장이 결정한다는 내용은 없습니다.\n- 따라서, (B) 통합된 모집단위는 대학장이 결정한다.는 옳지 않은 조건입니다.\n\nStep 4: 최종 답변을 작성합니다.\n- 학칙에 따르면 (B)가 옳지 않은 조건이므로, 최종 답변은 (B)입니다.',
#  '학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는 엘텍공과대학 건축학전공입니다. 따라서, 정답은 (D)입니다.',
#  "(C) 21학점\n\nStep-by-step justification:\n\n1. The context provides information about Ewha University's policies regarding the acquisition of credits.\n2. Article 35-2 states that students can acquire credits outside the university, with a maximum of 12 credits.\n3. Article 35-3 states that credits earned in certain cases can be counted towards graduation requirements, up to half of the total required credits.\n4. Article 35-4 mentions that credits can be earned for courses taken at the university's language education institute before admission.\n5. Article 45 of the school regulations states that students who have maintained an average grade of 3.75 or higher in the previous semester can take up to 21 credits in one semester.\n6. Based on this information, the correct answer is (C) 21학점.",
#  '(C) 학기 중간에 전과를 신청한 경우',
#  '(A) 하기방학',
#  '(B) 제1전공의 졸업요건 학점을 충족해야 한다.',
#  '이화여자대학교 학칙 제45조(취득학점)에 따르면, 의과대학 의학과 학생이 한 학기에 취득할 수 있는 최대 학점은 21학점입니다. 따라서, 정답은 (B)입니다.',
#  "(B) 시험 부정행위\n\nStep 1: Understand the context provided, which includes information about Ewha University policies and history.\nStep 2: Identify the relevant information, which in this case is the section related to disciplinary actions and the types of offenses that may lead to '유기정학' (suspension).\nStep 3: Analyze the options provided:\n    - (A) 수업 중 휴대폰 사용 (Using a mobile phone during class)\n    - (B) 시험 부정행위 (Cheating on exams)\n    - (C) 동아리 활동 불참 (Absence from club activities)\n    - (D) 졸업논문 제출 지연 (Delay in submitting the graduation thesis)\n    - (E) 교수와의 면담 거부 (Refusal to meet with a professor)\nStep 4: Match the options with the types of offenses that may lead to '유기정학' in the context provided.\nStep 5: Determine the correct answer based on the matching information.\n\nAnswer: (B) 시험 부정행위 (Cheating on exams)",
#  '(C) 2 이상의 전공을 자기설계전공이라 한다.\n\n이유:\n문맥에서 전공과목은 필수과목과 선택과목으로 구분되며, 그 종류와 학점은 소속 대학장의 제청에 따라 총장이 별도로 정한다고 언급되었습니다. 자기설계전공은 학생이 직접 2 이상의 전공을 선택하여 설계하는 것으로, 문맥에서 언급된 전공과목의 구분과 관련이 있습니다.',
#  '(E) 등록금이 과오납된 경우에는 금액을 반환할 수 없다.',
#  '(C) 필수과목과 선택과목',
#  '(D) 전기, 후기, 학기말\n\n설명: 주어진 문맥에서 졸업은 전기와 후기로 구분하고, 그 시기는 학기말로 한다고 언급되었습니다. 따라서, (D)가 올바른 답입니다.',
#  '(C) 학칙의 개정은 총장이 행한다.',
#  'The information provided does not include the specific numbers for the 2018학년도 admission quotas for the Department of Religion (Christianity) in the College of Humanities and the Department of Human-Machine Convergence in the College of Engineering. Therefore, it is not possible to determine the difference in admission quotas between these two departments based on the given context.\n\nFinal Answer: (E) 차이 없음',
#  '(C) 학칙 개정은 총장의 단독 결재로 진행된다.',
#  "(A) ㄱ, ㄷ, ㅁ\n\n설명:\n주어진 문맥은 이화여자대학교의 학칙이며, 제10장 '학생활동'의 규정은 언급되지 않았습니다. 그러나 학칙에는 학생 단체의 조직과 운영에 관한 사항이 따로 정해지고, 학생 단체 또는 학생 간행물의 발간 및 배포에 관한 사항이 따로 정해지는 내용이 있습니다. 또한, 학생의 사회봉사활동 지원에 관한 사항도 총장이 정한 세부사항에 따라 이루어지는 내용이 있습니다. 따라서, 주어진 옵션 중 학칙의 내용과 일치하는 것은 (A) ㄱ, ㄷ, ㅁ입니다.",
#  '(A) 수업연한 이상을 등록하고 훈련학점 4학점 및 72학점 이상을 취득한 학생은 의예과 수료로 인정받을 수 있다.\n\n설명:\n문맥에서는 제48조의4와 제48조의5에 대한 언급이 없습니다. 대신, 의예과 수료를 위한 조건에 대해 설명하고 있으며, 총 평균성적은 언급되지 않았습니다. 따라서, (B) 옵션은 옳지 않은 설명입니다.',
#  '(C) ㄴ,ㄷ',
#  '(C) 학생 C는 교과과정상의 필요에 따라 휴학 기간을 총 2년으로 연장하였다.\n\n제26조(휴학) ③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라 휴학기간을 연장할 수 있다.\n\n주어진 규정에 따르면, 학생 C의 휴학 기간 연장(2년)은 규정에 어긋나므로 옳지 않습니다. 규정에서는 1회의 휴학기간은 1년 이내로 하며, 교과과정상의 필요에 따라 휴학기간을 연장할 수 있다고 명시되어 있습니다. 학생 C의 경우, 휴학 기간을 1년을 초과하여 연장하였으므로 규정에 어긋납니다.',
#  '(B) 고등학교 졸업 성적은 입학전형자료로 사용될 수 없다.',
#  '(B) 입학전형기획관리위원회는 본교 교직원 중에서 위원을 선정하며, 총장이 임명한다.',
#  '1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학생의 총 평점을 계산하면:\n\n과목 1: A (4.0)\n과목 2: B+ (3.5)\n과목 3: C- (1.5)\n과목 4: D+ (1.5)\n과목 5: F (0.0)\n\n총 평점 = (4.0 + 3.5 + 1.5 + 1.5) / 5 = 10.5 / 5 = 2.1\n\n정답은: (C) 8.5 (하지만, 주어진 옵션 중 올바른 답은 없는 것 같습니다.)',
#  'The provided context does not contain any information about the admission quotas for the colleges of Humanities, Natural Sciences, Engineering, and Music at Ewha University for the 2018 academic year. Therefore, it is not possible to determine the correct answer to the question based on the given context.',
#  "(B) 첫 번째 교과목의 성적은 '미기록', 두 번째 교과목의 성적은 'U', 세 번째 교과목의 성적은 'F'로 기록된다.",
#  '학생 A는 졸업 요건을 충족하지 못했습니다. (B) 충족하지 못했다 (129학점 미달)\n\n다음은 단계별 추론입니다:\n\n1. 학생 A는 제1전공 85학점, 제2전공 34학점, 교양학점 15학점을 취득했습니다.\n2. 교과과정 정상화로 인해 총장이 별도로 지정한 학점 5학점을 추가로 취득해야 합니다.\n3. 학생 A가 취득한 총 학점은 85 + 34 + 15 + 5 = 139학점입니다.\n4. 졸업 요건은 129학점 이상입니다 (학칙 제32조 1항).\n5. 학생 A는 129학점 이상을 취득하지 못했으므로 졸업 요건을 충족하지 못했습니다.']

# %%
nowtest.top1[1]
# Out:
# '당하게 할 수 있다.② 입학사정관의 조직과 운영에 관한 사항은 총장이 따로 정한다. (개정 2012.12.31.)\n[본조신설 2009.6.16.]제18조(입학허가) ① 입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가한\n다. 다만, 제15조제1항의 단서의 경우나 특별전형, 기타 입학에 관하여 긴급한 필요가 있는이화여자대학교 학칙경우에는 대학장의 제청을 거치지 아니할 수 있다. (개정 2015. 2.6.)\n② 총장은 입학자격을 갖추지 못하였거나 제1항의 입학사정에 사용된 전형자료에 허위나\n부정이 있다고 판단되는 경우에는 교무회의의 의결을 거쳐 합격취소 및 입학허가취소를 할\n수 있다. (신설 2005.7.6)\n③ 제2항의 합격취소 및 입학허가취소의 사유와 절차에 관한 사항은 총장이 따로 정한다.\n(신설 2005.7.6.)\n[제목개정 2015.2.6.]제19조(입학금 등) ① 입학이 허가된 자는 정해진 기일 내에 입학금 기타 납입금을 납입하여\n야 한다. (개정 1997.'

# %%
######### 정답 1차 확인 + wrong 뽑아내기 ######

# print accuracy

cnt = 0
wrong = []
for idx, (answer, response) in enumerate(zip(answers, nowtest['predict'])):
    print("-"*10)
    generated_answer = extract_answer(response)
    print(response)
    # check
    if generated_answer:
        print(f"idx: {idx} | generated answer: {generated_answer}, answer: {answer}")
    else:
        print("extraction fail")

    if generated_answer == None:
        wrong.append(idx+1)
        wrongdf.loc[len(wrongdf)] = {"questionNum":idx+1, "answer" : answer, "1st_pred":generated_answer, "2nd_pred":"-"}
        continue
    
    if generated_answer in answer:
        cnt += 1
    else : 
        wrong.append(idx+1)
        wrongdf.loc[len(wrongdf)] = {"questionNum":idx+1, "answer" : answer, "1st_pred":generated_answer, "2nd_pred":None}
        
acc = cnt/len(answers)*100
print(f"acc: {acc}%")
print()
print("1st wrong:", wrong)
wrongdf.loc[len(wrongdf)] = {"questionNum":"-", "answer" : "-", "1st_pred":acc, "2nd_pred":None}
# Out:
# ----------
# 영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학점에 대한 정보는 제공된 문맥에서 명시적으로 언급되지 않았습니다. 따라서 주어진 선택지 (A) 인정 안됨, (B) 1학점, (C) 2학점, (D) 3학점 중 어느 것도 최종 답변으로 선택할 수 없습니다.
# idx: 0 | generated answer: D, answer: (D)
# ----------
# (E) 인공지능학사
# idx: 1 | generated answer: E, answer: (E)
# ----------
# (B) 구 학칙에 의하여 재학생이 졸업하는 연도까지 존속한다
# idx: 2 | generated answer: B, answer: (B)
# ----------
# B
# idx: 3 | generated answer: B, answer: (B)
# ----------
# 학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 (D) 학술의 응용방법 연구입니다.
# idx: 4 | generated answer: D, answer: (C)
# ----------
# (D) 강남구
# idx: 5 | generated answer: D, answer:  (D)
# ----------
# (C) 학생총회 요청
# idx: 6 | generated answer: C, answer:  (C)
# ----------
# (A) 건축학과는 추가 설계 실습을 포함하므로 더 긴 연한이 필요하다.
# idx: 7 | generated answer: A, answer:  (D)
# ----------
# (D) 해외 봉사로 인한 휴학: 3년
# idx: 8 | generated answer: D, answer:  (C)
# ----------
# (B) 전공별 종합시험 합격
#
# Step-by-step justification:
#
# 1. The provided context refers to Ewha University's policies and history, particularly focusing on the classification of courses, types of credit hours, and other academic requirements.
# 2. The question asks for the additional condition required by a double major student as mentioned in Article 50 (Graduation) of the school regulations.
# 3. To answer this question accurately, I need to find the relevant information within the provided context.
# 4. I found in the context that Article 35-2 (Special Cases for Credit Acquisition) mentions that specific subjects in liberal arts and major foundation subjects can be taken by a special examination for credit acquisition, but it does not provide information about the additional condition required by a double major student.
# 5. Therefore, I need to look for Article 50 (Graduation) in the context to find the additional condition required by a double major student.
# 6. After reviewing the context, I could not find Article 50 (Graduation), so I need to search for it in the full regulations.
# 7. In the full regulations, I found that Article 50 (Graduation) does not explicitly mention the additional condition required by a double major student.
# 8. However, in the context, I found that Article 34 (Major Subjects) mentions that major subjects are divided into required and elective subjects, and each type and credit hours are separately determined by the President upon the recommendation of the dean of the relevant college.
# 9. This implies that a double major student would need to complete both sets of required and elective subjects for each major, which would be the additional condition required by a double major student.
# 10. Therefore, the final answer is (B) Passing the Comprehensive Examination for Each Major.
# idx: 9 | generated answer: B, answer:  (B)
# ----------
# (D) 교과목 담당교수의 허가 없이 수강 취소
#
# 성적 F는 휴학 중이거나, 수업 시간의 6분의 1 이상 결석, 중간시험 및 기말시험 미응시, 과제 제출 기한 초과, 시험 부정행위 등의 경우에 처리됩니다. 그러나 교과목 담당교수의 허가 없이 수강을 취소한 경우, 성적이 F로 처리되지 않습니다.
# idx: 10 | generated answer: D, answer:  (B)
# ----------
# (C) 독립된 학과로 운영된다.
#
# 설명:
# 학칙 제47조(전공)의 맥락에서 Ewha Womans University는 학생들이 융합전공을 설계할 수 있는 옵션을 제공하지만, 이는 독립된 학과로 운영되지 않습니다. 대신, 학생들은 제1전공을 기반으로 하고, 관련 학문 분야를 융합하며, 총장의 승인을 받아야 합니다. 또한, 최소 21학점의 취득이 요구되며, 융복합 연구과정이 포함되어야 합니다.
# idx: 11 | generated answer: C, answer:  (C)
# ----------
# (B) 연속 2회 학사경고를 받은 경우
# idx: 12 | generated answer: B, answer:  (B)
# ----------
# 정기휴업일에 해당하지 않는 날은 (E) 종강일입니다.
# idx: 13 | generated answer: E, answer:  (E)
# ----------
# (A) 신입생 첫 학기
# idx: 14 | generated answer: A, answer:  (A)
# ----------
# (C) 15시간 이상
# idx: 15 | generated answer: C, answer:  (C)
# ----------
# (E) 특정 종교 교리 확립
# idx: 16 | generated answer: E, answer:  (E)
# ----------
# (B) 통합된 모집단위는 대학장이 결정한다.
#
# Step 1: 학칙 제5조(입학정원)을 확인합니다.
# - 해당 조항에 따르면, 모집단위별 통합 모집은 입학정원의 일부를 통합 모집할 수 있으며, 전공 결정은 일정 학점 이수 후 이루어집니다.
#
# Step 2: 학칙 제18조(입학허가)를 확인합니다.
# - 해당 조항에 따르면, 입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가합니다.
#
# Step 3: 학칙에서 통합된 모집단위를 대학장이 결정한다는 내용은 없습니다.
# - 따라서, (B) 통합된 모집단위는 대학장이 결정한다.는 옳지 않은 조건입니다.
#
# Step 4: 최종 답변을 작성합니다.
# - 학칙에 따르면 (B)가 옳지 않은 조건이므로, 최종 답변은 (B)입니다.
# idx: 17 | generated answer: B, answer:  (B)
# ----------
# 학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는 엘텍공과대학 건축학전공입니다. 따라서, 정답은 (D)입니다.
# idx: 18 | generated answer: D, answer:  (C)
# ----------
# (C) 21학점
#
# Step-by-step justification:
#
# 1. The context provides information about Ewha University's policies regarding the acquisition of credits.
# 2. Article 35-2 states that students can acquire credits outside the university, with a maximum of 12 credits.
# 3. Article 35-3 states that credits earned in certain cases can be counted towards graduation requirements, up to half of the total required credits.
# 4. Article 35-4 mentions that credits can be earned for courses taken at the university's language education institute before admission.
# 5. Article 45 of the school regulations states that students who have maintained an average grade of 3.75 or higher in the previous semester can take up to 21 credits in one semester.
# 6. Based on this information, the correct answer is (C) 21학점.
# idx: 19 | generated answer: C, answer:  (C)
# ----------
# (C) 학기 중간에 전과를 신청한 경우
# idx: 20 | generated answer: C, answer:  (C)
# ----------
# (A) 하기방학
# idx: 21 | generated answer: A, answer:  (D)
# ----------
# (B) 제1전공의 졸업요건 학점을 충족해야 한다.
# idx: 22 | generated answer: B, answer:  (B)
# ----------
# 이화여자대학교 학칙 제45조(취득학점)에 따르면, 의과대학 의학과 학생이 한 학기에 취득할 수 있는 최대 학점은 21학점입니다. 따라서, 정답은 (B)입니다.
# idx: 23 | generated answer: B, answer:  (C)
# ----------
# (B) 시험 부정행위
#
# Step 1: Understand the context provided, which includes information about Ewha University policies and history.
# Step 2: Identify the relevant information, which in this case is the section related to disciplinary actions and the types of offenses that may lead to '유기정학' (suspension).
# Step 3: Analyze the options provided:
#     - (A) 수업 중 휴대폰 사용 (Using a mobile phone during class)
#     - (B) 시험 부정행위 (Cheating on exams)
#     - (C) 동아리 활동 불참 (Absence from club activities)
#     - (D) 졸업논문 제출 지연 (Delay in submitting the graduation thesis)
#     - (E) 교수와의 면담 거부 (Refusal to meet with a professor)
# Step 4: Match the options with the types of offenses that may lead to '유기정학' in the context provided.
# Step 5: Determine the correct answer based on the matching information.
#
# Answer: (B) 시험 부정행위 (Cheating on exams)
# idx: 24 | generated answer: B, answer:  (B)
# ----------
# (C) 2 이상의 전공을 자기설계전공이라 한다.
#
# 이유:
# 문맥에서 전공과목은 필수과목과 선택과목으로 구분되며, 그 종류와 학점은 소속 대학장의 제청에 따라 총장이 별도로 정한다고 언급되었습니다. 자기설계전공은 학생이 직접 2 이상의 전공을 선택하여 설계하는 것으로, 문맥에서 언급된 전공과목의 구분과 관련이 있습니다.
# idx: 25 | generated answer: C, answer:  (B)
# ----------
# (E) 등록금이 과오납된 경우에는 금액을 반환할 수 없다.
# idx: 26 | generated answer: E, answer:  (E)
# ----------
# (C) 필수과목과 선택과목
# idx: 27 | generated answer: C, answer:  (C)
# ----------
# (D) 전기, 후기, 학기말
#
# 설명: 주어진 문맥에서 졸업은 전기와 후기로 구분하고, 그 시기는 학기말로 한다고 언급되었습니다. 따라서, (D)가 올바른 답입니다.
# idx: 28 | generated answer: D, answer:  (D)
# ----------
# (C) 학칙의 개정은 총장이 행한다.
# idx: 29 | generated answer: C, answer:  (A)
# ----------
# The information provided does not include the specific numbers for the 2018학년도 admission quotas for the Department of Religion (Christianity) in the College of Humanities and the Department of Human-Machine Convergence in the College of Engineering. Therefore, it is not possible to determine the difference in admission quotas between these two departments based on the given context.
#
# Final Answer: (E) 차이 없음
# idx: 30 | generated answer: E, answer:  (B)
# ----------
# (C) 학칙 개정은 총장의 단독 결재로 진행된다.
# idx: 31 | generated answer: C, answer:  (C)
# ----------
# (A) ㄱ, ㄷ, ㅁ
#
# 설명:
# 주어진 문맥은 이화여자대학교의 학칙이며, 제10장 '학생활동'의 규정은 언급되지 않았습니다. 그러나 학칙에는 학생 단체의 조직과 운영에 관한 사항이 따로 정해지고, 학생 단체 또는 학생 간행물의 발간 및 배포에 관한 사항이 따로 정해지는 내용이 있습니다. 또한, 학생의 사회봉사활동 지원에 관한 사항도 총장이 정한 세부사항에 따라 이루어지는 내용이 있습니다. 따라서, 주어진 옵션 중 학칙의 내용과 일치하는 것은 (A) ㄱ, ㄷ, ㅁ입니다.
# idx: 32 | generated answer: A, answer:  (A)
# ----------
# (A) 수업연한 이상을 등록하고 훈련학점 4학점 및 72학점 이상을 취득한 학생은 의예과 수료로 인정받을 수 있다.
#
# 설명:
# 문맥에서는 제48조의4와 제48조의5에 대한 언급이 없습니다. 대신, 의예과 수료를 위한 조건에 대해 설명하고 있으며, 총 평균성적은 언급되지 않았습니다. 따라서, (B) 옵션은 옳지 않은 설명입니다.
# idx: 33 | generated answer: A, answer:  (C)
# ----------
# (C) ㄴ,ㄷ
# idx: 34 | generated answer: C, answer:  (D)
# ----------
# (C) 학생 C는 교과과정상의 필요에 따라 휴학 기간을 총 2년으로 연장하였다.
#
# 제26조(휴학) ③ 1회의 휴학기간은 1년 이내로 한다. 다만, 교과과정상의 필요에 따라 휴학기간을 연장할 수 있다.
#
# 주어진 규정에 따르면, 학생 C의 휴학 기간 연장(2년)은 규정에 어긋나므로 옳지 않습니다. 규정에서는 1회의 휴학기간은 1년 이내로 하며, 교과과정상의 필요에 따라 휴학기간을 연장할 수 있다고 명시되어 있습니다. 학생 C의 경우, 휴학 기간을 1년을 초과하여 연장하였으므로 규정에 어긋납니다.
# idx: 35 | generated answer: C, answer:  (D)
# ----------
# (B) 고등학교 졸업 성적은 입학전형자료로 사용될 수 없다.
# idx: 36 | generated answer: B, answer:  (B)
# ----------
# (B) 입학전형기획관리위원회는 본교 교직원 중에서 위원을 선정하며, 총장이 임명한다.
# idx: 37 | generated answer: B, answer:  (B)
# ----------
# 1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학생의 총 평점을 계산하면:
#
# 과목 1: A (4.0)
# 과목 2: B+ (3.5)
# 과목 3: C- (1.5)
# 과목 4: D+ (1.5)
# 과목 5: F (0.0)
#
# 총 평점 = (4.0 + 3.5 + 1.5 + 1.5) / 5 = 10.5 / 5 = 2.1
#
# 정답은: (C) 8.5 (하지만, 주어진 옵션 중 올바른 답은 없는 것 같습니다.)
# idx: 38 | generated answer: A, answer:  (A)
# ----------
# The provided context does not contain any information about the admission quotas for the colleges of Humanities, Natural Sciences, Engineering, and Music at Ewha University for the 2018 academic year. Therefore, it is not possible to determine the correct answer to the question based on the given context.
# extraction fail
# ----------
# (B) 첫 번째 교과목의 성적은 '미기록', 두 번째 교과목의 성적은 'U', 세 번째 교과목의 성적은 'F'로 기록된다.
# idx: 40 | generated answer: F, answer:  (B)
# ----------
# 학생 A는 졸업 요건을 충족하지 못했습니다. (B) 충족하지 못했다 (129학점 미달)
#
# 다음은 단계별 추론입니다:
#
# 1. 학생 A는 제1전공 85학점, 제2전공 34학점, 교양학점 15학점을 취득했습니다.
# 2. 교과과정 정상화로 인해 총장이 별도로 지정한 학점 5학점을 추가로 취득해야 합니다.
# 3. 학생 A가 취득한 총 학점은 85 + 34 + 15 + 5 = 139학점입니다.
# 4. 졸업 요건은 129학점 이상입니다 (학칙 제32조 1항).
# 5. 학생 A는 129학점 이상을 취득하지 못했으므로 졸업 요건을 충족하지 못했습니다.
# idx: 41 | generated answer: B, answer:  (A)
# acc: 61.904761904761905%
#
# 1st wrong: [5, 8, 9, 11, 19, 22, 24, 26, 30, 31, 34, 35, 36, 40, 41, 42]

# %%
wrongdf
# Out:
#    questionNum answer   1st_pred 2nd_pred
# 0            5    (C)          D     None
# 1            8    (D)          A     None
# 2            9    (C)          D     None
# 3           11    (B)          D     None
# 4           19    (C)          D     None
# 5           22    (D)          A     None
# 6           24    (C)          B     None
# 7           26    (B)          C     None
# 8           30    (A)          C     None
# 9           31    (B)          E     None
# 10          34    (C)          A     None
# 11          35    (D)          C     None
# 12          36    (D)          C     None
# 13          40    (A)       None        -
# 14          41    (B)          F     None
# 15          42    (A)          B     None
# 16           -      -  61.904762     None

# %%
############# Second PREDICTION ##########

from langchain_core.prompts import PromptTemplate
from langchain_upstage import ChatUpstage


llm = ChatUpstage(api_key = api_key)

prompt_template = PromptTemplate.from_template(
    '''
    
    You are an assistant with expertise in Ewha University policies and history. Use the provided context to answer accurately.
    Let's think step by step.

    Context: {context1} {context2}

    Question: {question}

    Final Answer:

    '''

)
chain2 = prompt_template | llm


response2 = []
for idx, row in nowtest.iterrows() : ############### 일단 지금은 100개 단위로 띄엄띄엄 test 중
    if idx not in wrong : continue
        
    response = chain2.invoke({"question": row.prompts, "context1": row.top1, "context2": row.top2}) # 선지 전까지 받아오기
    response2.append(response.content)
    nowtest.loc[idx, 'predict'] = response.content

response2
# Out:
# ['(D) 강남구',
#  '(E) 중대한 질병으로 인한 휴학: 총장의 판단에 따라 연장 가능',
#  '(B) 전공별 종합시험 합격',
#  '(C) 독립된 학과로 운영된다.',
#  '(B) 20학점\n\n해설: 학칙 제45조(취득학점)에 따르면, 직전 학기 평균성적 3.75 이상을 받은 학생은 18학점 이상을 취득할 수 있으며, 20학점까지 취득할 수 있습니다. 따라서, 정답은 (B) 20학점입니다.',
#  '(B) 제1전공의 졸업요건 학점을 충족해야 한다.',
#  '(B) 시험 부정행위',
#  '(E) 등록금이 과오납된 경우에는 금액을 반환할 수 없다.',
#  '(E) 차이 없음',
#  '(C) 학칙 개정은 총장의 단독 결재로 진행된다.',
#  '(A) ㄱ,ㄹ',
#  'D',
#  '(B) 고등학교 졸업 성적은 입학전형자료로 사용될 수 없다.\n\n단계별 추론:\n\n1. 문맥은 이화여자대학교 학칙에 대한 내용을 포함하고 있으며, 특히 입학전형에 대한 제17조와 관련된 내용을 다룹니다.\n2. 제17조(입학전형)에서는 고등학교 졸업 정도 등을 기준으로 한 입학전형자료에 대해 언급하고 있습니다.\n3. 고등학교 졸업 성적도 입학전형자료로 사용될 수 있다고 언급되어 있으므로, (B) 번 선택지는 문맥과 일치하지 않습니다.\n4. 따라서, 제17조(입학전형)에 관한 설명으로 옳지 않은 것은 (B) 번입니다.',
#  "(B) 첫 번째 과목의 성적은 '미기록', 두 번째 과목의 성적은 'U', 세 번째 과목의 성적은 'F'로 기록됩니다.",
#  '(A) 충족했다 (129학점 이상)']

# %%
######### 정답 2차 확인 + wrong 뽑아내기 ######

# print accuracy

cnt = 0
wrong2 = []
for idx, (answer, response) in enumerate(zip(answers, nowtest['predict'])):
    print("-"*10)
    generated_answer = extract_answer(response)
    print(response)
    # check
    if generated_answer:
        print(f"idx: {idx} | generated answer: {generated_answer}, answer: {answer}")
    else:
        print("extraction fail")

    if generated_answer == None:
        wrong2.append(idx+1)
        wrongdf.loc[wrongdf['questionNum']==idx+1, '2nd_pred'] = "-"
        continue
    
    if generated_answer in answer:
        cnt += 1
    else : 
        wrong2.append(idx+1)
        wrongdf.loc[wrongdf['questionNum']==idx+1, '2nd_pred'] = generated_answer
        

acc = cnt/len(answers)*100
print(f"acc: {acc}%")
print()
print("2nd wrong:", wrong2)
wrongdf.loc[len(wrongdf)-1, '2nd_pred'] = acc
# Out:
# ----------
# 영어 및 정보 등에 관하여 일정한 기준의 능력이나 자격을 취득한 경우 인정 받는 학점에 대한 정보는 제공된 문맥에서 명시적으로 언급되지 않았습니다. 따라서 주어진 선택지 (A) 인정 안됨, (B) 1학점, (C) 2학점, (D) 3학점 중 어느 것도 최종 답변으로 선택할 수 없습니다.
# idx: 0 | generated answer: D, answer: (D)
# ----------
# (E) 인공지능학사
# idx: 1 | generated answer: E, answer: (E)
# ----------
# (B) 구 학칙에 의하여 재학생이 졸업하는 연도까지 존속한다
# idx: 2 | generated answer: B, answer: (B)
# ----------
# B
# idx: 3 | generated answer: B, answer: (B)
# ----------
# 학칙 제1조(목적)에 따르면 이화여자대학교의 설립 목적에 해당하지 않는 것은 (D) 학술의 응용방법 연구입니다.
# idx: 4 | generated answer: D, answer: (C)
# ----------
# (D) 강남구
# idx: 5 | generated answer: D, answer:  (D)
# ----------
# (C) 학생총회 요청
# idx: 6 | generated answer: C, answer:  (C)
# ----------
# (A) 건축학과는 추가 설계 실습을 포함하므로 더 긴 연한이 필요하다.
# idx: 7 | generated answer: A, answer:  (D)
# ----------
# (E) 중대한 질병으로 인한 휴학: 총장의 판단에 따라 연장 가능
# idx: 8 | generated answer: E, answer:  (C)
# ----------
# (B) 전공별 종합시험 합격
# idx: 9 | generated answer: B, answer:  (B)
# ----------
# (D) 교과목 담당교수의 허가 없이 수강 취소
#
# 성적 F는 휴학 중이거나, 수업 시간의 6분의 1 이상 결석, 중간시험 및 기말시험 미응시, 과제 제출 기한 초과, 시험 부정행위 등의 경우에 처리됩니다. 그러나 교과목 담당교수의 허가 없이 수강을 취소한 경우, 성적이 F로 처리되지 않습니다.
# idx: 10 | generated answer: D, answer:  (B)
# ----------
# (C) 독립된 학과로 운영된다.
# idx: 11 | generated answer: C, answer:  (C)
# ----------
# (B) 연속 2회 학사경고를 받은 경우
# idx: 12 | generated answer: B, answer:  (B)
# ----------
# 정기휴업일에 해당하지 않는 날은 (E) 종강일입니다.
# idx: 13 | generated answer: E, answer:  (E)
# ----------
# (A) 신입생 첫 학기
# idx: 14 | generated answer: A, answer:  (A)
# ----------
# (C) 15시간 이상
# idx: 15 | generated answer: C, answer:  (C)
# ----------
# (E) 특정 종교 교리 확립
# idx: 16 | generated answer: E, answer:  (E)
# ----------
# (B) 통합된 모집단위는 대학장이 결정한다.
#
# Step 1: 학칙 제5조(입학정원)을 확인합니다.
# - 해당 조항에 따르면, 모집단위별 통합 모집은 입학정원의 일부를 통합 모집할 수 있으며, 전공 결정은 일정 학점 이수 후 이루어집니다.
#
# Step 2: 학칙 제18조(입학허가)를 확인합니다.
# - 해당 조항에 따르면, 입학(편입학 및 재입학 포함)은 해당 대학장의 제청으로 총장이 허가합니다.
#
# Step 3: 학칙에서 통합된 모집단위를 대학장이 결정한다는 내용은 없습니다.
# - 따라서, (B) 통합된 모집단위는 대학장이 결정한다.는 옳지 않은 조건입니다.
#
# Step 4: 최종 답변을 작성합니다.
# - 학칙에 따르면 (B)가 옳지 않은 조건이므로, 최종 답변은 (B)입니다.
# idx: 17 | generated answer: B, answer:  (B)
# ----------
# 학칙 제23조(수업연한)에 따라 다음 중 수업 연한이 4년으로 규정되지 않은 학과는 엘텍공과대학 건축학전공입니다. 따라서, 정답은 (D)입니다.
# idx: 18 | generated answer: D, answer:  (C)
# ----------
# (B) 20학점
#
# 해설: 학칙 제45조(취득학점)에 따르면, 직전 학기 평균성적 3.75 이상을 받은 학생은 18학점 이상을 취득할 수 있으며, 20학점까지 취득할 수 있습니다. 따라서, 정답은 (B) 20학점입니다.
# idx: 19 | generated answer: B, answer:  (C)
# ----------
# (C) 학기 중간에 전과를 신청한 경우
# idx: 20 | generated answer: C, answer:  (C)
# ----------
# (A) 하기방학
# idx: 21 | generated answer: A, answer:  (D)
# ----------
# (B) 제1전공의 졸업요건 학점을 충족해야 한다.
# idx: 22 | generated answer: B, answer:  (B)
# ----------
# 이화여자대학교 학칙 제45조(취득학점)에 따르면, 의과대학 의학과 학생이 한 학기에 취득할 수 있는 최대 학점은 21학점입니다. 따라서, 정답은 (B)입니다.
# idx: 23 | generated answer: B, answer:  (C)
# ----------
# (B) 시험 부정행위
# idx: 24 | generated answer: B, answer:  (B)
# ----------
# (C) 2 이상의 전공을 자기설계전공이라 한다.
#
# 이유:
# 문맥에서 전공과목은 필수과목과 선택과목으로 구분되며, 그 종류와 학점은 소속 대학장의 제청에 따라 총장이 별도로 정한다고 언급되었습니다. 자기설계전공은 학생이 직접 2 이상의 전공을 선택하여 설계하는 것으로, 문맥에서 언급된 전공과목의 구분과 관련이 있습니다.
# idx: 25 | generated answer: C, answer:  (B)
# ----------
# (E) 등록금이 과오납된 경우에는 금액을 반환할 수 없다.
# idx: 26 | generated answer: E, answer:  (E)
# ----------
# (C) 필수과목과 선택과목
# idx: 27 | generated answer: C, answer:  (C)
# ----------
# (D) 전기, 후기, 학기말
#
# 설명: 주어진 문맥에서 졸업은 전기와 후기로 구분하고, 그 시기는 학기말로 한다고 언급되었습니다. 따라서, (D)가 올바른 답입니다.
# idx: 28 | generated answer: D, answer:  (D)
# ----------
# (C) 학칙의 개정은 총장이 행한다.
# idx: 29 | generated answer: C, answer:  (A)
# ----------
# (E) 차이 없음
# idx: 30 | generated answer: E, answer:  (B)
# ----------
# (C) 학칙 개정은 총장의 단독 결재로 진행된다.
# idx: 31 | generated answer: C, answer:  (C)
# ----------
# (A) ㄱ, ㄷ, ㅁ
#
# 설명:
# 주어진 문맥은 이화여자대학교의 학칙이며, 제10장 '학생활동'의 규정은 언급되지 않았습니다. 그러나 학칙에는 학생 단체의 조직과 운영에 관한 사항이 따로 정해지고, 학생 단체 또는 학생 간행물의 발간 및 배포에 관한 사항이 따로 정해지는 내용이 있습니다. 또한, 학생의 사회봉사활동 지원에 관한 사항도 총장이 정한 세부사항에 따라 이루어지는 내용이 있습니다. 따라서, 주어진 옵션 중 학칙의 내용과 일치하는 것은 (A) ㄱ, ㄷ, ㅁ입니다.
# idx: 32 | generated answer: A, answer:  (A)
# ----------
# (A) 수업연한 이상을 등록하고 훈련학점 4학점 및 72학점 이상을 취득한 학생은 의예과 수료로 인정받을 수 있다.
#
# 설명:
# 문맥에서는 제48조의4와 제48조의5에 대한 언급이 없습니다. 대신, 의예과 수료를 위한 조건에 대해 설명하고 있으며, 총 평균성적은 언급되지 않았습니다. 따라서, (B) 옵션은 옳지 않은 설명입니다.
# idx: 33 | generated answer: A, answer:  (C)
# ----------
# (A) ㄱ,ㄹ
# idx: 34 | generated answer: A, answer:  (D)
# ----------
# D
# idx: 35 | generated answer: D, answer:  (D)
# ----------
# (B) 고등학교 졸업 성적은 입학전형자료로 사용될 수 없다.
#
# 단계별 추론:
#
# 1. 문맥은 이화여자대학교 학칙에 대한 내용을 포함하고 있으며, 특히 입학전형에 대한 제17조와 관련된 내용을 다룹니다.
# 2. 제17조(입학전형)에서는 고등학교 졸업 정도 등을 기준으로 한 입학전형자료에 대해 언급하고 있습니다.
# 3. 고등학교 졸업 성적도 입학전형자료로 사용될 수 있다고 언급되어 있으므로, (B) 번 선택지는 문맥과 일치하지 않습니다.
# 4. 따라서, 제17조(입학전형)에 관한 설명으로 옳지 않은 것은 (B) 번입니다.
# idx: 36 | generated answer: B, answer:  (B)
# ----------
# (B) 입학전형기획관리위원회는 본교 교직원 중에서 위원을 선정하며, 총장이 임명한다.
# idx: 37 | generated answer: B, answer:  (B)
# ----------
# 1980학년도 이전 입학생에 대한 제39조 제1항의 성적 평가 기준에 따라 해당 학생의 총 평점을 계산하면:
#
# 과목 1: A (4.0)
# 과목 2: B+ (3.5)
# 과목 3: C- (1.5)
# 과목 4: D+ (1.5)
# 과목 5: F (0.0)
#
# 총 평점 = (4.0 + 3.5 + 1.5 + 1.5) / 5 = 10.5 / 5 = 2.1
#
# 정답은: (C) 8.5 (하지만, 주어진 옵션 중 올바른 답은 없는 것 같습니다.)
# idx: 38 | generated answer: A, answer:  (A)
# ----------
# The provided context does not contain any information about the admission quotas for the colleges of Humanities, Natural Sciences, Engineering, and Music at Ewha University for the 2018 academic year. Therefore, it is not possible to determine the correct answer to the question based on the given context.
# extraction fail
# ----------
# (B) 첫 번째 과목의 성적은 '미기록', 두 번째 과목의 성적은 'U', 세 번째 과목의 성적은 'F'로 기록됩니다.
# idx: 40 | generated answer: F, answer:  (B)
# ----------
# (A) 충족했다 (129학점 이상)
# idx: 41 | generated answer: A, answer:  (A)
# acc: 64.28571428571429%
#
# 2nd wrong: [5, 8, 9, 11, 19, 20, 22, 24, 26, 30, 31, 34, 35, 40, 41]

# %%
wrongdf.set_index(keys=['questionNum'])
wrongdf
# Out:
#    questionNum answer   1st_pred   2nd_pred
# 0            5    (C)          D          D
# 1            8    (D)          A          A
# 2            9    (C)          D          E
# 3           11    (B)          D          D
# 4           19    (C)          D          D
# 5           22    (D)          A          A
# 6           24    (C)          B          B
# 7           26    (B)          C          C
# 8           30    (A)          C          C
# 9           31    (B)          E          E
# 10          34    (C)          A          A
# 11          35    (D)          C          A
# 12          36    (D)          C       None
# 13          40    (A)       None          -
# 14          41    (B)          F          F
# 15          42    (A)          B       None
# 16           -      -  61.904762  64.285714

# %% [markdown]
# ## groundedness check
#
# ### 질문할 때마다 답이 달라져서 안 할 거임

# %%
import os
from langchain_upstage import UpstageGroundednessCheck # langchain_upstage==0.1.3
 
groundedness_check = UpstageGroundednessCheck()
 
request_input = {
    "context": f"Mauna Kea is an inactive volcano on the island of Hawai'i. Its peak is 4,207.3 m above sea level, making it the highest point in Hawaii and second-highest peak of an island on Earth.",
    "answer": "Mauna Kea is 5,207.3 meters tall.",
}
response = groundedness_check.invoke(request_input)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 4
#       1 import os
#       2 from langchain_upstage import UpstageGroundednessCheck # langchain_upstage==0.1.3
# ----> 4 groundedness_check = UpstageGroundednessCheck()
#       6 request_input = {
#       7     "context": f"Mauna Kea is an inactive volcano on the island of Hawai'i. Its peak is 4,207.3 m above sea level, making it the highest point in Hawaii and second-highest peak of an island on Earth.",
#       8     "answer": "Mauna Kea is 5,207.3 meters tall.",
#       9 }
#      10 response = groundedness_check.invoke(request_input)
#
# File ~/anaconda3/envs/yoonnlp/lib/python3.10/site-packages/langchain_upstage/tools/groundedness_check.py:72, in UpstageGroundednessCheck.__init__(self, **kwargs)
#      65 upstage_api_key = convert_to_secret_str(upstage_api_key)
#      67 if (
#      68     not upstage_api_key
#      69     or not upstage_api_key.get_secret_value()
#      70     or upstage_api_key.get_secret_value() == ""
#      71 ):
# ---> 72     raise ValueError("UPSTAGE_API_KEY must be set or passed")
#      74 api_wrapper = ChatUpstage(
#      75     model="solar-1-mini-answer-verification",
#      76     api_key=upstage_api_key.get_secret_value(),
#      77 )
#      78 super().__init__(upstage_api_key=upstage_api_key, api_wrapper=api_wrapper)
#
# ValueError: UPSTAGE_API_KEY must be set or passed
